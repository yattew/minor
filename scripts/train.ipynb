# %%
import json
from pathlib import Path
import gensim
from gensim.models import Word2Vec

from stopstem import *
import os
 

path = "C://Users//ganes//Desktop//mini//reference"
dir_list = os.listdir(path)
#print(dir_list)
matrix=[]
for i in dir_list:
    with open("../reference/"+i,'r') as data_source:
        try:
            data1 = data_source.read()
            stemmed = tokenizeAndStem(data1)
            matrix.append(stemmed)
        except:
            print(i)
        
#print(matrix)
model1 = Word2Vec(matrix, min_count = 1, window = 5, sg=1,epochs = 20,vector_size=100)
# Out:
# 3.11.txt
# 3.2.txt
# 3.4.txt
# 3.5.txt
# 3.6.txt
# 3.7.txt
# 3.8.txt
# 3.9.txt
# changelog.txt
# decimal.txt
# instrumentation.txt
# logging-cookbook.txt
# math.txt
# nntplib.txt
# random.txt
# stable.txt
# unicode.txt

# %%
from cosines import cacCosine

print(model1.wv)
def sim(q1,q2):
    a1 = q1.split()
    import numpy as np
    v1 = np.array([0.0]*100)
    v2 = np.array([0.0]*100)
    c1=1
    for i in a1:
        try:
            v1+=model1.wv[i]
            c1+=1
        except:
            pass
    v1/=c1
    a2 = q2.split()
    c2=1
    for i in a2:
        try:
            v2+=model1.wv[i]
            c2+=1
        except:
            pass
    v2/=c2
    return cacCosine(list(v1),list(v2))
import os
BASE_DIR = Path(os.getcwd()).resolve().parent

def findSimilar(listOfDocs,query):
    #dic={stemmdtitle:[title,link,file]}
    dic={}
    maxi=[]
    for i in listOfDocs:
        if i[-4::]=='json':
            with open(BASE_DIR/('jsons/'+i)) as f:
                data=json.load(f)
                for j in data:
                    for k in data[j]['videos'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['videos'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
                    for k in data[j]['reading'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['reading'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
    return dic,maxi
# Out:
# KeyedVectors<vector_size=100, 29337 keys>

# %%
from pprint import pprint as p
l = os.listdir("C://Users//ganes//Desktop//mini//jsons")
q1 = "Python Program to Print Natural Numbers Using While and For Loop in Hindi - Tutorial #22"
q2 = "Print the first 10 natural numbers using for loop"
dic,maxi = findSimilar(l,"sum of first few integers")
p(sorted(maxi,reverse=True))
# Out:
# [[0.888315920160364,
#   'Python Program to Calculate and print sum of Even and Odd integers of first '
#   'Natural n Numbers #15',
#   'loop-while.json'],
#  [0.8404279508842025,
#   'Python Program to Print First 10 Natural Numbers',
#   'loop-while.json'],
#  [0.8349459529345034,
#   'Python program to calculate the sum of first N even numbers',
#   'loop-while.json'],
#  [0.8342352419047275,
#   'Print the first 10 natural numbers using for loop',
#   'loop-for.json'],
#  [0.8317584016399103,
#   'Program to Print First 10 Natural Numbers - In Hindi',
#   'loop-while.json'],
#  [0.8293130933847324, 'Find missing and repeating', 'array.json'],
#  [0.8285703438928504,
#   'Python Program to Print Sum of n Odd Natural Numbers | 1+3+5+7+..+n Series '
#   'Calculation in Python',
#   'loop-for.json'],
#  [0.8201452493663065,
#   'Frequently Asked Python Program 17: Multiply All Numbers in the List',
#   'loop-while.json'],
#  [0.8155348741416101,
#   'Frequently Asked Python Program 4: Print Fibonacci Series',
#   'loop-for.json'],
#  [0.8066087420678946,
#   'Python program to calculate the sum of all the odd numbers within the given '
#   'range',
#   'loop-for.json'],
#  [0.8056585135632215,
#   'Modules in Python Explained | Python Built in Modules | Python Tutorial for '
#   'Beginners | Simplilearn',
#   'module.json'],
#  [0.8021349709550475, 'Find missing number', 'array.json'],
#  [0.8004180033300659,
#   'Python program counts the number of even and odd numbers from a series of '
#   'numbers',
#   'loop-for.json'],
#  [0.7978335438807397,
#   '[Language skills Python] Exercise Lambda Expressions - Advanced [Tutorial]',
#   'function-lambda.json'],
#  [0.7969235974896381,
#   'Python Program to Count Total Odd and Even Numbers in List - In Hindi',
#   'loop-for.json'],
#  [0.7950480369306739,
#   'Python program to convert the month name to a number of days',
#   'loop-for.json'],
#  [0.7950480369306739,
#   'Python program to convert month name to a number of days',
#   'loop-for.json'],
#  [0.7906214885007372,
#   'Python Program to Print Multiplication Table of a Number ( User Input )',
#   'loop-for.json'],
#  [0.7884736779136675,
#   ' Professional Error Handling With Python',
#   'exception handling.json'],
#  [0.7868236277024264,
#   'Using Python External & Built In Modules | Python Tutorials For Absolute '
#   'Beginners In Hindi',
#   'module.json'],
#  [0.784791178853265,
#   'Advanced Python Series - Iterators Vs Generators',
#   'iterator-generator-decorator.json'],
#  [0.7833715308129434,
#   'Python program to print a multiplication table of a given number',
#   'loop-for.json'],
#  [0.7824431969916619,
#   'Python Tutorial: Itertools Module - Iterator Functions for Efficient '
#   'Looping',
#   'oops-magic method-itertools.json'],
#  [0.7745436390517828,
#   'Python program to display numbers from a list using a for loop.',
#   'loop-for.json'],
#  [0.7711017248254093, 'Count pairs with given sum', 'array.json'],
#  [0.769548092111104,
#   ' Advanced Python Series- Custom Exception Handling In Python',
#   'exception handling.json'],
#  [0.7687531585579253,
#   ' Exception Handling in Python | CUET Computer Science',
#   'exception handling.json'],
#  [0.7670697182539025,
#   'Python program to find all the prime numbers in the given range- by Mahesh '
#   'Huddar',
#   'loop-for.json'],
#  [0.7644657461597644,
#   'Python modules: Exercises, Practice, Solution',
#   'module.json'],
#  [0.7635333012896015,
#   'Python Intermediate Series: Python Modules',
#   'module.json'],
#  [0.7622463501289529,
#   'Find missing number in an array in python',
#   'array.json'],
#  [0.761783755580433,
#   'Python Program to find the sum of a Series 1/1! + 2/2! + 3/3! + 4/4! '
#   '+â€¦â€¦.+ n/n!',
#   'loop-while.json'],
#  [0.7612489432946777,
#   'How to Use Python Lambda Functions? 6 Comprehensive Aspects',
#   'function-lambda.json'],
#  [0.7603825326878939,
#   'Python Generators vs Iterators',
#   'iterator-generator-decorator.json'],
#  [0.7599186401170426,
#   ' Advanced Python- Exception Handling Detailed Explanation In Python',
#   'exception handling.json'],
#  [0.7594224110329924,
#   'Python Itertools Module & Its Iteration Tutorial #38',
#   'oops-magic method-itertools.json'],
#  [0.7570672354693905,
#   'Python Program to Print Natural Numbers Using While and For Loop in Hindi - '
#   'Tutorial #22',
#   'loop-for.json'],
#  [0.7569978024261205,
#   'What Are Python Modules? | Modules In Python | Python Tutorial For '
#   'Beginners | Edureka',
#   'module.json'],
#  [0.7566194335637023,
#   ' Python Functions Tutorial | Working With Functions In Python | Python '
#   'Training | Eâ€¦',
#   'function.json'],
#  [0.7547300284511048,
#   'Difference Between Iterator VS Generator',
#   'iterator-generator-decorator.json'],
#  [0.7542610240109834,
#   ' Exception Handling in Python || Syntax Error vs Runtime Error',
#   'exception handling.json'],
#  [0.7507940196527925,
#   ' Python Tutorial: Using Try/Except Blocks for Error Handling',
#   'exception handling.json'],
#  [0.74884811126051, 'Elif statement', 'condition-pass.json'],
#  [0.74884811126051, 'Elif statement', 'condition-pass.json'],
#  [0.7487482203029978,
#   'Python Advanced Modules Made Easy â€” Part 1',
#   'module.json'],
#  [0.747268449215419,
#   'Python Programming - Calculate the Number of Digits and Letters in a String '
#   '- Updated 2021',
#   'loop-for.json'],
#  [0.7465313604510282,
#   'Advanced Python: Itertools Library â€” The Gem Of Python Language',
#   'oops-magic method-itertools.json'],
#  [0.7461558819716175,
#   'Python program that accepts a string and calculates the number of digits '
#   'and letters',
#   'loop-for.json'],
#  [0.7460040272525497,
#   'Python program to print all the even numbers within the given range',
#   'loop-for.json'],
#  [0.74573723338503,
#   'Python Program to Reverse of a Number - In Hindi',
#   'loop-while.json'],
#  [0.7454752651630738,
#   'Write a program to cyclically rotate an array by one| Love Babbar DSA Sheet',
#   'array.json'],
#  [0.7440612017671648,
#   'Python program to find the factorial of a given number',
#   'loop-for.json'],
#  [0.7432125656940964,
#   'Advance Python Modules - How to Create & Import with dir Function',
#   'module.json'],
#  [0.7421150025519452,
#   ' Lambda Expressions & Anonymous Functions || Python Tutorial || Learn Pâ€¦',
#   'function-lambda.json'],
#  [0.7417073931915953,
#   'Python Iterators | Iterables and Iterators in Python | Python Tutorial for '
#   'Beginners | Edureka',
#   'iterator-generator-decorator.json'],
#  [0.7416946965135206,
#   ' Try Except Exception Handling In Python | Python Tutorials For Absolute '
#   'Bâ€¦ ',
#   'exception handling.json'],
#  [0.7415678265532933, 'Python Modules Inbuilt', 'module.json'],
#  [0.7409504070252113,
#   ' finally keyword in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.7400823617419372, 'Python Modules | Learn Coding', 'module.json'],
#  [0.7392581819315226,
#   'Reverse a Number in Python using While Loop',
#   'loop-while.json'],
#  [0.7390966735710145,
#   'Pair with the given sum in a sorted array',
#   'array.json'],
#  [0.7388956309960688,
#   'Program to find the product of the given number of consecutive elements',
#   'loop-while.json'],
#  [0.7386350218761918,
#   'Itertools in Python3',
#   'oops-magic method-itertools.json'],
#  [0.7379838727088224, 'Subarray with given sum', 'array.json'],
#  [0.7372883764220812, 'Top 18 Most Useful Python Modules', 'module.json'],
#  [0.736779322055158,
#   'Using Modules & Pip In Python | Python Tutorials For Absolute Beginners In '
#   'Hindi #3',
#   'module.json'],
#  [0.7362631225259851,
#   '. Python Programming Tutorial | Exception Handling in Python | '
#   'GeeksforGeâ€¦',
#   'exception handling.json'],
#  [0.7360372089400692,
#   'Working with Own Modules - Python Advanced Tutorial Series - 37',
#   'module.json'],
#  [0.7359709186076291,
#   'Understanding Python: Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.735935825397571,
#   'Python Tutorial: Iterators and Iterables - What Are They and How Do They '
#   'Work?',
#   'iterator-generator-decorator.json'],
#  [0.7316301453266596,
#   'Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.7316301453266596,
#   ' Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.7309735523207909,
#   'What is Modules in Python - Python Tutorials for Beginners',
#   'module.json'],
#  [0.7304497657383155,
#   'Python program to display all numbers within a range except the prime '
#   'numbers',
#   'loop-for.json'],
#  [0.7302501665644973,
#   'Frequently Asked Python Program 20:Check String is Palindrome or Not',
#   'loop-for.json'],
#  [0.7297402206169147, 'Python : Advance built in modules', 'module.json'],
#  [0.7292935687288039,
#   'Python Itertools For Advanced Iteration',
#   'oops-magic method-itertools.json'],
#  [0.7260938629499315,
#   'Python Itertools | Hindi | Part 1 | Python for Beginner to Expert | In '
#   'Detail Explanation',
#   'oops-magic method-itertools.json'],
#  [0.7260067720978965,
#   'Python Modules and Packages - An Introduction',
#   'module.json'],
#  [0.7259740380808631,
#   'How to print even numbers in the given range in Python',
#   'loop-for.json'],
#  [0.7257930775214948,
#   'Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials',
#   'iterator-generator-decorator.json'],
#  [0.7247159477630978,
#   "Python's Magical Itertools Module",
#   'oops-magic method-itertools.json'],
#  [0.7244231141594397, ' Max sum path in two arrays', 'array.json'],
#  [0.7242995422241436,
#   '[Hindi] Iterators, Iterables and Generators in python explained | Advanced '
#   'python tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.7242995422241436,
#   ' Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.7229155137884651,
#   '5 Advanced Functions in Itertools To Simplify Iterations in Python',
#   'oops-magic method-itertools.json'],
#  [0.7211991220673485,
#   '#45 Python Tutorial for Beginners | Modules',
#   'module.json'],
#  [0.7209293416321781,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.7209293416321781,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.7204506725909132,
#   '. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.7204506725909132,
#   ' Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.7199674358530939,
#   'Function arguments in detail - Advanced Python 18 - Programming Tutorial',
#   'function.json'],
#  [0.7185090677783693,
#   ' Anonymous/Lambda Functions In Python | Python Tutorials For Absolute Bâ€¦',
#   'function-lambda.json'],
#  [0.7183766539362663,
#   ' 8. Exception handling â€” Advance Python Tutorials documentation',
#   'exception handling.json'],
#  [0.7180476459507802,
#   ' Day 24: Advanced Exception Handling and Raising Exceptions',
#   'exception handling.json'],
#  [0.7163155641833473,
#   'Python program to check the validity of password input by users',
#   'loop-for.json'],
#  [0.7129670178815274,
#   ' 30. Errors and Exception Handling | Python Tutorial',
#   'exception handling.json'],
#  [0.7104588467948881,
#   'Python Tutorial: Decorators - Dynamically Alter The Functionality Of Your '
#   'Functions',
#   'iterator-generator-decorator.json'],
#  [0.710051833307644, 'Find duplicates in an array', 'array.json'],
#  [0.7100204806253578,
#   'Lambda Operator, filter, reduce and map',
#   'function-lambda.json'],
#  [0.709664296040816,
#   'Functions creating iterators for efficient loopingÂ¶',
#   'oops-magic method-itertools.json'],
#  [0.7092982988225478,
#   'Find the minimum and maximum element in an array',
#   'array.json'],
#  [0.7091454248163678,
#   ' Python Exception Handling - GeeksforGeeks',
#   'exception handling.json'],
#  [0.7087869987747016,
#   'Creating One Dimensional Array using Numpy',
#   'array.json'],
#  [0.7080905977366925,
#   'Python Tutorials - Namespace and Variable Scope',
#   'iterator-generator-decorator.json'],
#  [0.7071394243945494,
#   ' NZEC error in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.7063115730686949,
#   'Lambda in Python - Advanced Python 08 - Programming Tutorial - Map Filter '
#   'Reduce',
#   'function-lambda.json'],
#  [0.7060223463905934,
#   'Python Programming Tutorial - Iterators (Part-1)',
#   'iterator-generator-decorator.json'],
#  [0.7054396315804491,
#   'Comparison of Iterators and Generators in python',
#   'iterator-generator-decorator.json'],
#  [0.7049557706985551,
#   'INTRODUCTION TO EXCEPTION HANDLING IN PYTHON ',
#   'exception handling.json'],
#  [0.7046548060671781,
#   'Top 5 Python Modules You Should Know in 2023',
#   'module.json'],
#  [0.7018460058154279, 'Create and Import Python Modules', 'module.json'],
#  [0.7016605944654963,
#   'Python program to get the Fibonacci series between 0 to 50',
#   'loop-for.json'],
#  [0.7002664105162291,
#   '#61 Python Tutorial for Beginners | Iterator',
#   'iterator-generator-decorator.json'],
#  [0.6999210165628039, 'Module in Python (Hindi)', 'module.json'],
#  [0.6988500745858591, 'How to add an item to a list in Python', 'list.json'],
#  [0.6985383097294976,
#   'Iterator And Generator In Python | Python Generators And Iterators '
#   'Explained | Python | Simplilearn',
#   'iterator-generator-decorator.json'],
#  [0.6979897849578734,
#   'Exception Handling in Python in Hindi | Python Exception Handling',
#   'exception handling.json'],
#  [0.6962564299816211,
#   'Building Lambda functions with Python',
#   'function-lambda.json'],
#  [0.6961291694303686, 'Python Modules', 'module.json'],
#  [0.6961291694303686, 'Python Modules', 'module.json'],
#  [0.6961291694303686, 'Python - Modules', 'module.json'],
#  [0.6953285424524873,
#   'Functions And Docstrings | Python Tutorials For Absolute Beginners In Hindi '
#   '#23',
#   'function.json'],
#  [0.693881166008517, 'Sort an array using Quicksort Algorithm', 'array.json'],
#  [0.6937230624929626,
#   'Python program to check if a given number is an Armstrong number',
#   'loop-for.json'],
#  [0.6898953322007617,
#   'How to Use Python Lambda Functions',
#   'function-lambda.json'],
#  [0.6890233655732038,
#   'Python: Lambda, Map, Filter, Reduce Functions',
#   'function-lambda.json'],
#  [0.6890042594434702,
#   'Python Itertools | Itertools in Python | Python Tutorial for Beginners | '
#   'Edureka',
#   'oops-magic method-itertools.json'],
#  [0.6882584959983388,
#   'Exception Handling in Python',
#   'exception handling.json'],
#  [0.6871916224044682,
#   'Immediate Python- Functions, Modules, Classes and Exceptions',
#   'oops-class.json'],
#  [0.6868243062532139,
#   'What are Modules in Python and How to Define Modules in Python with '
#   'Examples',
#   'module.json'],
#  [0.6859545972485892,
#   '  #63 Python Tutorial for Beginners | Exception Handling',
#   'exception handling.json'],
#  [0.6840424683607548,
#   'Decorators In Python | Python Tutorials For Absolute Beginners In Hindi #51',
#   'iterator-generator-decorator.json'],
#  [0.6839033703886048,
#   'Hindi Magic/Dunder Methods In Python? | Object Oriented Programming Using '
#   'Python Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.6823476945409885,
#   'Lambda Expressions - Python Tips and Tricks #5',
#   'function-lambda.json'],
#  [0.6819418794787846,
#   'Python Lambda Function | Anonymous Function In Python | Python Tutorial | '
#   'Edureka',
#   'function-lambda.json'],
#  [0.6813429618876232,
#   'Write a program to cyclically rotate an array by one',
#   'array.json'],
#  [0.6802749219699306, 'Python Iterators', 'iterator-generator-decorator.json'],
#  [0.6800142317148815,
#   'Python Program for Series Calculation 1*1 + 2*2 + 3*3 +..+n | Series '
#   'Calculation Program in Python',
#   'loop-while.json'],
#  [0.6785242388776678,
#   'Iterators and Generators',
#   'iterator-generator-decorator.json'],
#  [0.6785242388776678,
#   'Iterators & Generators',
#   'iterator-generator-decorator.json'],
#  [0.6785242388776678,
#   'Generators and Iterators',
#   'iterator-generator-decorator.json'],
#  [0.6777415317912511, 'Arrays in python: Array Advance Game', 'array.json'],
#  [0.6774631719722395,
#   'Python Program to check Armstrong Number',
#   'loop-while.json'],
#  [0.6774631719722395,
#   'Python Program to Check Armstrong Number',
#   'loop-while.json'],
#  [0.6774631719722395,
#   'Python Program to Check Armstrong Number',
#   'loop-for.json'],
#  [0.6764875592512367,
#   'Advanced Functional Programming in Python: lambda',
#   'function-lambda.json'],
#  [0.6735294397859252,
#   '6. INTRODUCTION TO EXCEPTION HANDLING IN PYTHON',
#   'exception handling.json'],
#  [0.6731242670878878, 'Advanced features of Python Functions', 'function.json'],
#  [0.6731242670878878,
#   'Advanced Features in Python Functions | Python Functions Advanced',
#   'function.json'],
#  [0.6727491822864032,
#   'ANONYMOUS FUNCTIONS (LAMBDA) - PYTHON PROGRAMMING',
#   'function-lambda.json'],
#  [0.672031299996161,
#   'Generators and Iterators in python | python tutorial',
#   'iterator-generator-decorator.json'],
#  [0.6714728777405299, 'Shorthand statement', 'condition-pass.json'],
#  [0.6714728777405299, 'Shorthand if statement', 'condition-pass.json'],
#  [0.6712225935686593,
#   'Itertools in Python - Advanced Python 07 - Programming Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.6711363283068787,
#   '4. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.6693379979912851,
#   'Decorators in Python - Advanced Python 13 - Programming Tutorial',
#   'iterator-generator-decorator.json'],
#  [0.6690976842308177,
#   'Accessing List using for Loop in Python (Hindi)',
#   'loop-for.json'],
#  [0.6686216004172256,
#   'Exceptions in Python || Python Tutorial || Learn Python Programming',
#   'exception handling.json'],
#  [0.6660242126915047, 'What is Modular Programming?', 'module.json'],
#  [0.66577846270806,
#   'Check the validity of a Password in Python',
#   'loop-for.json'],
#  [0.6644185429943913,
#   'Lambda Expression : Python tutorial 150',
#   'function-lambda.json'],
#  [0.6630300602700415,
#   'Top 10 Most Popular Python Libraries | Yaswanth | GeeksforGeeks',
#   'module.json'],
#  [0.6624747093994307,
#   '[Hindi] Lambda functions in python in Hindi | Advanced python in Hindi',
#   'function-lambda.json'],
#  [0.6623809724347917,
#   'Lambda Functions with Practical Examples in Python',
#   'function-lambda.json'],
#  [0.6622976658055707,
#   'Python Programming for Intermediate programmer',
#   'oops-class.json'],
#  [0.6615438785924594, 'Introduction to if else', 'condition-pass.json'],
#  [0.6615438785924594, 'Introduction to if else', 'condition-pass.json'],
#  [0.6602181189639268, 'High order functions in Python', 'function.json'],
#  [0.6590885284835135, 'Merge two dictionaries', 'dictionary.json'],
#  [0.6590885284835135, 'Merge two dictionaries', 'dictionary.json'],
#  [0.6589859980568191,
#   'Advanced indexing Operations in Numpy Arrays',
#   'array.json'],
#  [0.6586540965800173,
#   '#44 Python Tutorial for Beginners | Decorators',
#   'iterator-generator-decorator.json'],
#  [0.6584989437570414,
#   'Python 3 Programming Tutorial | #1 Introduction of Python Lambda and '
#   'Anonymous Function',
#   'function-lambda.json'],
#  [0.6572887928036598,
#   'Advance Python Series- Magic Methods',
#   'oops-class.json'],
#  [0.6530303520712395,
#   '#42 Python Tutorial for Beginners | Anonymous Functions | Lambda',
#   'function-lambda.json'],
#  [0.6530275789593952, ' Add list items', 'list.json'],
#  [0.652400531270877, 'Expert Python Tutorial', 'oops-class.json'],
#  [0.6517410345048235, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.6517410345048235, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.650496134374481, 'Pass statement', 'condition-pass.json'],
#  [0.650496134374481, 'Pass statement', 'condition-pass.json'],
#  [0.650496134374481, 'Pass statement', 'condition-pass.json'],
#  [0.650496134374481, 'Pass statement', 'condition-pass.json'],
#  [0.649296854428706,
#   'Python Intermediate: Lambda Functions',
#   'function-lambda.json'],
#  [0.648793057065849,
#   'Generators In Python | Python Tutorials For Absolute Beginners In Hindi #72',
#   'iterator-generator-decorator.json'],
#  [0.6478450407751785,
#   'Python Lambda | Advanced Python | Tutorial 18',
#   'function-lambda.json'],
#  [0.6471591835644076,
#   'Python Lambda/Anonymous Functions ',
#   'function-lambda.json'],
#  [0.6471203956443622,
#   '#3: Python lambda (anonymous) Functions | Python Best Practices',
#   'function-lambda.json'],
#  [0.6463593216356751,
#   'What are Python Iterators and Generators?',
#   'iterator-generator-decorator.json'],
#  [0.6463593216356751,
#   'PYTHON ITERATORS AND GENERATORS',
#   'iterator-generator-decorator.json'],
#  [0.6463593216356751,
#   'Iterators and Generators in Python',
#   'iterator-generator-decorator.json'],
#  [0.6463593216356751,
#   'Generators & Iterators in python',
#   'iterator-generator-decorator.json'],
#  [0.6460204393826754,
#   'Python OOP Tutorial 5: Special (Magic/Dunder) Methods',
#   'oops-magic method-itertools.json'],
#  [0.6459681442153309,
#   'Python Programs - Factorial Program Using for loop',
#   'loop-for.json'],
#  [0.644290962316402, 'Advanced Python for Data Science', 'oops-class.json'],
#  [0.6433027965349254,
#   'Itertools - Advanced Python 07',
#   'oops-magic method-itertools.json'],
#  [0.6431024770486024, 'Stock buy and sell Problem', 'array.json'],
#  [0.6425836613058826,
#   'Intermediate Python Tutorial #5 - Lambda Functions',
#   'function-lambda.json'],
#  [0.6419180181402818,
#   'Lambda Function in Python - In Hindi',
#   'function-lambda.json'],
#  [0.6418054060384789,
#   'Expert Python Tutorial #2 - Dunder/Magic Methods & The Python Data Model',
#   'oops-magic method-itertools.json'],
#  [0.6410820556961546,
#   'Explore the magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.6408480645890839,
#   'Tutorial: Lambda Functions in Python',
#   'function-lambda.json'],
#  [0.6395926506586975,
#   'Lambda Functions - Advanced Python 08',
#   'function-lambda.json'],
#  [0.6394494840412636,
#   ' Exception handling tips in Python âš\xa0 Write better Python code part 7',
#   'exception handling.json'],
#  [0.6380586566611653,
#   'How To Use Functions In Python (Python Tutorial #3)',
#   'function.json'],
#  [0.637954196998267,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'oops-magic method-itertools.json'],
#  [0.637954196998267,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'function.json'],
#  [0.6375149609365077,
#   ' Python Functions | Python Tutorial for Absolute Beginners #1',
#   'function.json'],
#  [0.6361534700677025, 'Python Immediate Tutorial #1', 'oops-class.json'],
#  [0.634103525204042,
#   "HINDI BIT-PY Beginner's Python Course | Part #36 | Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.6337946262092563,
#   'Python Programming 19 - Remove Elements From List within for Loop',
#   'list.json'],
#  [0.6317455990981642, 'Python Lambda Expressions', 'function-lambda.json'],
#  [0.6313923455233649,
#   'Magic Methods in Python, by example | Using Magic Methods In Our Class '
#   'Design',
#   'oops-magic method-itertools.json'],
#  [0.6299540731345281, 'Write a program to sort the given array', 'array.json'],
#  [0.6298357134176558,
#   'Lambda and filter in Python Examples',
#   'function-lambda.json'],
#  [0.6298020423104357,
#   ' Exceptions in Python - Advanced Python 09 - Programming Tutorial',
#   'exception handling.json'],
#  [0.627585405531505,
#   'Function Decorator in Python (Hindi)',
#   'iterator-generator-decorator.json'],
#  [0.627139952539562, 'PythonDocs Python Function', 'function.json'],
#  [0.625690109567075,
#   'Lambda Functions in Python | Python Tutorial #37',
#   'function-lambda.json'],
#  [0.6253976996316647, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.6253976996316647, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.6239410386030311,
#   'Lambda Function in Python -     Example Syntax',
#   'function-lambda.json'],
#  [0.6223502771357813,
#   ' User-defined Exceptions in Python with Examples - GeeksforGeeks',
#   'exception handling.json'],
#  [0.6221518080402226, 'Pop dictionary method', 'dictionary.json'],
#  [0.6221518080402226, 'Pop dictionary method', 'dictionary.json'],
#  [0.6217242684679235, 'Intermediate Programming with Python', 'module.json'],
#  [0.6211706711158144, 'Immediate Python Programming', 'oops-class.json'],
#  [0.620558015205148,
#   'Introducing Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.619267332389556, 'Python Functions Advanced', 'function.json'],
#  [0.619267332389556, 'Python Advanced Functions', 'function.json'],
#  [0.618706400996853,
#   '#62 Python Tutorial for Beginners | Generators',
#   'iterator-generator-decorator.json'],
#  [0.618510381627207, '#27 Python Tutorial for Beginners', 'array.json'],
#  [0.618510381627207, ' #26 Python Tutorial for Beginners', 'array.json'],
#  [0.6180509324802723,
#   "A Guide to Python's Secret Superpower: Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.6171503910878671, 'Get dictionary method', 'dictionary.json'],
#  [0.6171503910878671, 'Get dictionary method', 'dictionary.json'],
#  [0.614306759585784, 'Maximum Index', 'array.json'],
#  [0.6135392749530789,
#   'Advanced Python: What Are Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.6135138039562302,
#   'Puthon OOP Tutorial 1: Classes and Instances',
#   'oops-class.json'],
#  [0.6135104554402669,
#   ' Accessing elements of a nested dictionary',
#   'dictionary.json'],
#  [0.6135104554402669,
#   ' Accessing elements of a nested Dictionary',
#   'dictionary.json'],
#  [0.6124598400820714, 'Peak Element', 'array.json'],
#  [0.6121686366380515, 'Sort lists', 'list.json'],
#  [0.6121686366380515, ' Sort list', 'list.json'],
#  [0.6109714338744445,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.6109714338744445,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.6087791738519095,
#   'How to Change/Replace/Update List Items ? | List tutorial in python',
#   'list.json'],
#  [0.6083531806459512, 'Copy lists', 'list.json'],
#  [0.6083531806459512, 'Copy list', 'list.json'],
#  [0.6080272186239398, ' Copy dictionary method', 'dictionary.json'],
#  [0.6080272186239398, ' Copy dictionary method', 'dictionary.json'],
#  [0.6063899002847487,
#   'Classes & Objects in Python | Python OOP Tutorial | Python for Beginners',
#   'oops-class.json'],
#  [0.6058872329938475,
#   'Python Try Except - GeeksforGeeks',
#   'exception handling.json'],
#  [0.6053602601297474,
#   'Advance Python Series-Magic Methods In Classes',
#   'oops-magic method-itertools.json'],
#  [0.6047740193560089,
#   " Python Functions (The Only Guide You'll Need) #12",
#   'function.json'],
#  [0.6028322105562188, 'Python Functions Edureka ', 'function.json'],
#  [0.602109718984693,
#   'Python Itertools javapoint',
#   'oops-magic method-itertools.json'],
#  [0.6019885568350137, 'Using classes in Python', 'oops-class.json'],
#  [0.6004833204180094,
#   ' #32 Python Tutorial for Beginners | Functions in Python',
#   'function.json'],
#  [0.5981873650824543,
#   '@Decorators in Python (Advanced)',
#   'iterator-generator-decorator.json'],
#  [0.5973456765701419, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.5973456765701419, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.5965548008708941,
#   'Python program to check if a string is a palindrome or not',
#   'loop-for.json'],
#  [0.595651641096783,
#   '#20 Python Tutorial for Beginners | While Loop in Python',
#   'loop-while.json'],
#  [0.5954639850459428,
#   'Python Itertools gfg',
#   'oops-magic method-itertools.json'],
#  [0.5952155066979306,
#   '#49 Python Tutorial for Beginners| Class and Object',
#   'oops-class.json'],
#  [0.5944425253483165, 'Write a program to reverse an array', 'array.json'],
#  [0.5937734860796355, 'TutorialsPoint Python Functions ', 'function.json'],
#  [0.5918084143945745, 'Lambda Functions', 'function-lambda.json'],
#  [0.5898129293663499,
#   'Itertools in Python 3, By Example',
#   'oops-magic method-itertools.json'],
#  [0.5873974419478749, 'Python Classes and Obejcts', 'oops-class.json'],
#  [0.5858011113125556, ' Python Lambda', 'function-lambda.json'],
#  [0.5844704892356419,
#   "A Guide to Python's Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.5829898252292528, 'Join lists', 'list.json'],
#  [0.5829898252292528, 'Join Lists', 'list.json'],
#  [0.580808169839582, 'Nested if Condtion', 'condition-pass.json'],
#  [0.5781003952096102, 'Reversing lists', 'list.json'],
#  [0.5781003952096102, ' Reversing the lists', 'list.json'],
#  [0.5777338787176031, 'GFG Python Functions ', 'function.json'],
#  [0.5749840708674552, 'Checking for membership in lists', 'list.json'],
#  [0.5749840708674552, ' Checking for membership in lists', 'list.json'],
#  [0.5749513909334315, 'LearnPython Python Functions', 'function.json'],
#  [0.5746790841557864,
#   'Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.5746790841557864,
#   'Python - Magic Methods ',
#   'oops-magic method-itertools.json'],
#  [0.5716258495609321, 'Programiz Python Functions ', 'function.json'],
#  [0.5701922198315996, 'Accessing elements of a dictionary', 'dictionary.json'],
#  [0.5701922198315996,
#   '. Accessing elements of a dictionary',
#   'dictionary.json'],
#  [0.5676036354090281, 'JavaPoint Python Functions ', 'function.json'],
#  [0.5630538941651038,
#   'Python - Magic or Dunder Methods',
#   'oops-magic method-itertools.json'],
#  [0.5630538941651038,
#   'Dunder or magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.5629409181699052, 'Python Decorators', 'iterator-generator-decorator.json'],
#  [0.5629409181699052, 'Python Decorator', 'iterator-generator-decorator.json'],
#  [0.5629409181699052,
#   'Decorators in Python',
#   'iterator-generator-decorator.json'],
#  [0.5610460544685736, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.5610460544685736, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.5603310800328786,
#   'Object Oriented Porgramming in Python',
#   'oops-class.json'],
#  [0.5597150510150146, 'Arrays in python| Python for beginners', 'array.json'],
#  [0.5581950067856556, 'Python programming', 'oops-class.json'],
#  [0.5570282542121531, ' Access list items', 'list.json'],
#  [0.5550061712975438, 'Python Conditions', 'condition-pass.json'],
#  [0.5550061712975438, 'Python Condition', 'condition-pass.json'],
#  [0.5540574843181431, 'Arrays in Python Programming', 'array.json'],
#  [0.5538865885217243, 'Advanced Python classes', 'oops-class.json'],
#  [0.550446216966625, 'Python Functions ', 'function.json'],
#  [0.5462472859309186, 'Python Programming | Classes', 'oops-class.json'],
#  [0.545568240162107, 'Python While Loops', 'loop-while.json'],
#  [0.5450009813150246, 'List comprehension', 'list.json'],
#  [0.5450009813150246, ' List comprehension', 'list.json'],
#  [0.5412010505317435, 'Define CLasses in Python', 'oops-class.json'],
#  [0.5369663699845857, ' exceptions.Exception', 'exception handling.json'],
#  [0.536019603872262, 'Clear dictionary method', 'dictionary.json'],
#  [0.536019603872262, 'Clear dictionary method', 'dictionary.json'],
#  [0.5332272550247016, 'Nested if condition', 'condition-pass.json'],
#  [0.527009802719995, 'Filtering the lists', 'list.json'],
#  [0.527009802719995, ' Filtering the lists', 'list.json'],
#  [0.5216350224150599, 'Change list items', 'list.json'],
#  [0.5211045827976647, ' Remove list items', 'list.json'],
#  [0.520378708993722, 'Nested Dictionaries', 'dictionary.json'],
#  [0.520378708993722, ' Nested Dictionaries', 'dictionary.json'],
#  [0.517870103320334, ' Update dictionary method', 'dictionary.json'],
#  [0.517870103320334, ' Update dictionary method', 'dictionary.json'],
#  [0.5106662829500865, 'Loop lists', 'list.json'],
#  [0.5106662829500865, ' Loop lists', 'list.json'],
#  [0.507223223355907, 'Python Classes', 'oops-class.json'],
#  [0.5059085333612832, 'What Are Access Lists? ', 'list.json'],
#  [0.5010289801289476, 'Python Generators', 'iterator-generator-decorator.json'],
#  [0.5005592279061525, 'Python Objects and Classes', 'oops-class.json'],
#  [0.5005592279061525, 'Python Classes and Objects', 'oops-class.json'],
#  [0.5005592279061525, 'Classes and Objects in python', 'oops-class.json'],
#  [0.5005592279061525, 'Classes and Objects in Python', 'oops-class.json'],
#  [0.49998465049649354, 'Indentation', 'condition-pass.json'],
#  [0.49998465049649354, 'Indentation', 'condition-pass.json'],
#  [0.49717071556149284, 'List methods', 'list.json'],
#  [0.49717071556149284, 'List methods', 'list.json'],
#  [0.49327173635193544, 'Data model', 'oops-magic method-itertools.json'],
#  [0.48198020988283385, '384 Shuffle an array', 'array.json'],
#  [0.46952350748088983, 'Magic Methods', 'oops-magic method-itertools.json'],
#  [0.44656902287718214, 'Classes and Objects (OOPS)', 'oops-class.json'],
#  [0.4189730689881805, 'Creating a dictionary-', 'dictionary.json'],
#  [0.4189730689881805, 'Creating a dictionary', 'dictionary.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json']]

# %%
import json
from pathlib import Path
import gensim
from gensim.models import Word2Vec

from stopstem import *
import os
 

path = "C://Users//ganes//Desktop//mini//reference"
dir_list = os.listdir(path)
#print(dir_list)
matrix=[]
for i in dir_list:
    with open("../reference/"+i,'r') as data_source:
        try:
            data1 = data_source.read()
            stemmed = tokenizeAndStem(data1)
            matrix.append(stemmed)
        except:
            print(i)
        
#print(matrix)
model1 = Word2Vec(matrix, min_count = 1, window = 5, sg=1,epochs = 20,vector_size=100)
# Out:
# 3.11.txt
# 3.2.txt
# 3.4.txt
# 3.5.txt
# 3.6.txt
# 3.7.txt
# 3.8.txt
# 3.9.txt
# changelog.txt
# decimal.txt
# instrumentation.txt
# logging-cookbook.txt
# math.txt
# nntplib.txt
# random.txt
# stable.txt
# unicode.txt

# %%
from cosines import cacCosine

print(model1.wv)
def sim(q1,q2):
    a1 = q1.split()
    import numpy as np
    v1 = np.array([0.0]*100)
    v2 = np.array([0.0]*100)
    c1=1
    for i in a1:
        try:
            v1+=model1.wv[i]
            c1+=1
        except:
            pass
    v1/=c1
    a2 = q2.split()
    c2=1
    for i in a2:
        try:
            v2+=model1.wv[i]
            c2+=1
        except:
            pass
    v2/=c2
    return cacCosine(list(v1),list(v2))
import os
BASE_DIR = Path(os.getcwd()).resolve().parent

def findSimilar(listOfDocs,query):
    #dic={stemmdtitle:[title,link,file]}
    dic={}
    maxi=[]
    for i in listOfDocs:
        if i[-4::]=='json':
            with open(BASE_DIR/('jsons/'+i)) as f:
                data=json.load(f)
                for j in data:
                    for k in data[j]['videos'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['videos'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
                    for k in data[j]['reading'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['reading'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
    return dic,maxi
# Out:
# KeyedVectors<vector_size=100, 29337 keys>

# %%
from pprint import pprint as p
l = os.listdir("C://Users//ganes//Desktop//mini//jsons")
q1 = "Python Program to Print Natural Numbers Using While and For Loop in Hindi - Tutorial #22"
q2 = "Print the first 10 natural numbers using for loop"
dic,maxi = findSimilar(l,"sum of first few integers numbers")
p(sorted(maxi,reverse=True))
# Out:
# [[0.8760710451699374,
#   'Python Program to Calculate and print sum of Even and Odd integers of first '
#   'Natural n Numbers #15',
#   'loop-while.json'],
#  [0.8754141662306484,
#   'Program to Print First 10 Natural Numbers - In Hindi',
#   'loop-while.json'],
#  [0.8580410112124816,
#   'Python Program to Print First 10 Natural Numbers',
#   'loop-while.json'],
#  [0.8555697564521721,
#   'Print the first 10 natural numbers using for loop',
#   'loop-for.json'],
#  [0.8544192060179443, 'Find missing number', 'array.json'],
#  [0.8541024059167315,
#   'Python program to calculate the sum of first N even numbers',
#   'loop-while.json'],
#  [0.8432211313014276,
#   'Python program to convert the month name to a number of days',
#   'loop-for.json'],
#  [0.8432211313014276,
#   'Python program to convert month name to a number of days',
#   'loop-for.json'],
#  [0.8259738312826667,
#   'Frequently Asked Python Program 17: Multiply All Numbers in the List',
#   'loop-while.json'],
#  [0.8218675962385145,
#   'Python program to calculate the sum of all the odd numbers within the given '
#   'range',
#   'loop-for.json'],
#  [0.8144307538000608,
#   'Python program counts the number of even and odd numbers from a series of '
#   'numbers',
#   'loop-for.json'],
#  [0.8118632673201854,
#   'Python program to find all the prime numbers in the given range- by Mahesh '
#   'Huddar',
#   'loop-for.json'],
#  [0.8118420366579311,
#   'Program to find the product of the given number of consecutive elements',
#   'loop-while.json'],
#  [0.8066583743774488,
#   'Python program to print a multiplication table of a given number',
#   'loop-for.json'],
#  [0.798901337624018, 'Find missing and repeating', 'array.json'],
#  [0.7982611807685793,
#   'Python Program to Count Total Odd and Even Numbers in List - In Hindi',
#   'loop-for.json'],
#  [0.797482211284448,
#   'Python Program to Print Sum of n Odd Natural Numbers | 1+3+5+7+..+n Series '
#   'Calculation in Python',
#   'loop-for.json'],
#  [0.7950003137334403,
#   'Python Program to Print Multiplication Table of a Number ( User Input )',
#   'loop-for.json'],
#  [0.7873937488503241,
#   ' Professional Error Handling With Python',
#   'exception handling.json'],
#  [0.786414007017111,
#   'Python Program to Reverse of a Number - In Hindi',
#   'loop-while.json'],
#  [0.7805701272413529,
#   'Python program to display numbers from a list using a for loop.',
#   'loop-for.json'],
#  [0.777768569510593,
#   'Python program to find the factorial of a given number',
#   'loop-for.json'],
#  [0.7761216688811945,
#   'Frequently Asked Python Program 4: Print Fibonacci Series',
#   'loop-for.json'],
#  [0.7741613239552734,
#   ' Exception Handling in Python | CUET Computer Science',
#   'exception handling.json'],
#  [0.7709097061222857,
#   'Python program that accepts a string and calculates the number of digits '
#   'and letters',
#   'loop-for.json'],
#  [0.7700858280336086,
#   ' Exception Handling in Python || Syntax Error vs Runtime Error',
#   'exception handling.json'],
#  [0.7696129327976374,
#   'Find missing number in an array in python',
#   'array.json'],
#  [0.768671945189733,
#   'Python program to print all the even numbers within the given range',
#   'loop-for.json'],
#  [0.7676493185180205,
#   'Write a program to cyclically rotate an array by one| Love Babbar DSA Sheet',
#   'array.json'],
#  [0.766958826885222,
#   ' Advanced Python- Exception Handling Detailed Explanation In Python',
#   'exception handling.json'],
#  [0.7664383447220401,
#   'Python program to display all numbers within a range except the prime '
#   'numbers',
#   'loop-for.json'],
#  [0.7649404478984128,
#   'Advance Python Modules - How to Create & Import with dir Function',
#   'module.json'],
#  [0.7603147300758821,
#   ' Advanced Python Series- Custom Exception Handling In Python',
#   'exception handling.json'],
#  [0.7591466085408843,
#   'Using Python External & Built In Modules | Python Tutorials For Absolute '
#   'Beginners In Hindi',
#   'module.json'],
#  [0.7572042163337798,
#   'Python Programming - Calculate the Number of Digits and Letters in a String '
#   '- Updated 2021',
#   'loop-for.json'],
#  [0.7570599083951991,
#   'Python Program to Print Natural Numbers Using While and For Loop in Hindi - '
#   'Tutorial #22',
#   'loop-for.json'],
#  [0.751168618461655,
#   'Python program to check if a given number is an Armstrong number',
#   'loop-for.json'],
#  [0.7507474934414965,
#   'Reverse a Number in Python using While Loop',
#   'loop-while.json'],
#  [0.75015181974087, 'Count pairs with given sum', 'array.json'],
#  [0.7495245203023984,
#   'How to print even numbers in the given range in Python',
#   'loop-for.json'],
#  [0.7444731284520966,
#   'Python Tutorial: Itertools Module - Iterator Functions for Efficient '
#   'Looping',
#   'oops-magic method-itertools.json'],
#  [0.7399423425319231,
#   '[Language skills Python] Exercise Lambda Expressions - Advanced [Tutorial]',
#   'function-lambda.json'],
#  [0.7395484464968614, 'Python Modules | Learn Coding', 'module.json'],
#  [0.7366698078115302,
#   'Modules in Python Explained | Python Built in Modules | Python Tutorial for '
#   'Beginners | Simplilearn',
#   'module.json'],
#  [0.7316685918257305,
#   '. Python Programming Tutorial | Exception Handling in Python | '
#   'GeeksforGeâ€¦',
#   'exception handling.json'],
#  [0.7305207226876111,
#   'Difference Between Iterator VS Generator',
#   'iterator-generator-decorator.json'],
#  [0.7301634690236511,
#   'Advanced Python Series - Iterators Vs Generators',
#   'iterator-generator-decorator.json'],
#  [0.7299858991503086,
#   ' Python Exception Handling - GeeksforGeeks',
#   'exception handling.json'],
#  [0.7288590921658812,
#   'Python Program to check Armstrong Number',
#   'loop-while.json'],
#  [0.7288590921658812,
#   'Python Program to Check Armstrong Number',
#   'loop-while.json'],
#  [0.7288590921658812,
#   'Python Program to Check Armstrong Number',
#   'loop-for.json'],
#  [0.7285773619144795,
#   'Understanding Python: Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.7234258820781646,
#   ' Python Tutorial: Using Try/Except Blocks for Error Handling',
#   'exception handling.json'],
#  [0.7229046098904373,
#   'Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.7229046098904373,
#   ' Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.7228753178826075,
#   '. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.7228753178826075,
#   ' Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.7207412474541066,
#   ' Day 24: Advanced Exception Handling and Raising Exceptions',
#   'exception handling.json'],
#  [0.7202116571896958,
#   'Write a program to cyclically rotate an array by one',
#   'array.json'],
#  [0.7191403853935746, 'Subarray with given sum', 'array.json'],
#  [0.7189957836370686,
#   'Frequently Asked Python Program 20:Check String is Palindrome or Not',
#   'loop-for.json'],
#  [0.715457355625591,
#   'Creating One Dimensional Array using Numpy',
#   'array.json'],
#  [0.7128218195234765,
#   'Itertools in Python3',
#   'oops-magic method-itertools.json'],
#  [0.7126050989624476,
#   'Python Intermediate Series: Python Modules',
#   'module.json'],
#  [0.7122071975356278,
#   'Python Itertools Module & Its Iteration Tutorial #38',
#   'oops-magic method-itertools.json'],
#  [0.711739581090162,
#   'Functions creating iterators for efficient loopingÂ¶',
#   'oops-magic method-itertools.json'],
#  [0.7117156292055364,
#   ' Try Except Exception Handling In Python | Python Tutorials For Absolute '
#   'Bâ€¦ ',
#   'exception handling.json'],
#  [0.7107269336923966,
#   'INTRODUCTION TO EXCEPTION HANDLING IN PYTHON ',
#   'exception handling.json'],
#  [0.7106483197528453,
#   'Exception Handling in Python in Hindi | Python Exception Handling',
#   'exception handling.json'],
#  [0.7085122068055041,
#   ' Python Functions Tutorial | Working With Functions In Python | Python '
#   'Training | Eâ€¦',
#   'function.json'],
#  [0.7076644233319542, 'Create and Import Python Modules', 'module.json'],
#  [0.7040993171926214,
#   'Pair with the given sum in a sorted array',
#   'array.json'],
#  [0.7040492632985844,
#   'Advanced Python: Itertools Library â€” The Gem Of Python Language',
#   'oops-magic method-itertools.json'],
#  [0.7035568131488986,
#   ' Lambda Expressions & Anonymous Functions || Python Tutorial || Learn Pâ€¦',
#   'function-lambda.json'],
#  [0.7029372481549592,
#   'Python Advanced Modules Made Easy â€” Part 1',
#   'module.json'],
#  [0.7028216556046507,
#   'Exception Handling in Python',
#   'exception handling.json'],
#  [0.7024649497083651,
#   'Python program to check the validity of password input by users',
#   'loop-for.json'],
#  [0.7023656094580583,
#   ' 8. Exception handling â€” Advance Python Tutorials documentation',
#   'exception handling.json'],
#  [0.7018032828024755,
#   ' 30. Errors and Exception Handling | Python Tutorial',
#   'exception handling.json'],
#  [0.7014244210018918,
#   'Using Modules & Pip In Python | Python Tutorials For Absolute Beginners In '
#   'Hindi #3',
#   'module.json'],
#  [0.7011634060778988, 'Elif statement', 'condition-pass.json'],
#  [0.7011634060778988, 'Elif statement', 'condition-pass.json'],
#  [0.7007141801137236,
#   'Function arguments in detail - Advanced Python 18 - Programming Tutorial',
#   'function.json'],
#  [0.6963540463376497,
#   'Python Generators vs Iterators',
#   'iterator-generator-decorator.json'],
#  [0.6940155321078144,
#   "Python's Magical Itertools Module",
#   'oops-magic method-itertools.json'],
#  [0.693051219411871,
#   'Python Program to find the sum of a Series 1/1! + 2/2! + 3/3! + 4/4! '
#   '+â€¦â€¦.+ n/n!',
#   'loop-while.json'],
#  [0.6918836835219836,
#   '  #63 Python Tutorial for Beginners | Exception Handling',
#   'exception handling.json'],
#  [0.6908846272089553,
#   'How to Use Python Lambda Functions? 6 Comprehensive Aspects',
#   'function-lambda.json'],
#  [0.6904091643548553,
#   'What Are Python Modules? | Modules In Python | Python Tutorial For '
#   'Beginners | Edureka',
#   'module.json'],
#  [0.6901357095952927,
#   '5 Advanced Functions in Itertools To Simplify Iterations in Python',
#   'oops-magic method-itertools.json'],
#  [0.6899489098672811, 'Python Modules Inbuilt', 'module.json'],
#  [0.6891906075623551,
#   'Working with Own Modules - Python Advanced Tutorial Series - 37',
#   'module.json'],
#  [0.6887272406919436,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.6887272406919436,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.6877525054750814,
#   'Python modules: Exercises, Practice, Solution',
#   'module.json'],
#  [0.6862704797237947,
#   'Python Itertools | Hindi | Part 1 | Python for Beginner to Expert | In '
#   'Detail Explanation',
#   'oops-magic method-itertools.json'],
#  [0.6838212134297592,
#   ' finally keyword in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.6836467148205614,
#   'Python Modules and Packages - An Introduction',
#   'module.json'],
#  [0.6833401050207728, 'Top 18 Most Useful Python Modules', 'module.json'],
#  [0.6806040415112403,
#   ' Anonymous/Lambda Functions In Python | Python Tutorials For Absolute Bâ€¦',
#   'function-lambda.json'],
#  [0.6789424918271738,
#   'Find the minimum and maximum element in an array',
#   'array.json'],
#  [0.6778734136209345,
#   '#45 Python Tutorial for Beginners | Modules',
#   'module.json'],
#  [0.6776482777491919, 'Python : Advance built in modules', 'module.json'],
#  [0.6773129498931442,
#   'Python Tutorial: Iterators and Iterables - What Are They and How Do They '
#   'Work?',
#   'iterator-generator-decorator.json'],
#  [0.6767283857146302,
#   'Python Tutorials - Namespace and Variable Scope',
#   'iterator-generator-decorator.json'],
#  [0.6716003238967281,
#   'Top 5 Python Modules You Should Know in 2023',
#   'module.json'],
#  [0.6705580782878063,
#   'What is Modules in Python - Python Tutorials for Beginners',
#   'module.json'],
#  [0.6704170993688431,
#   'Functions And Docstrings | Python Tutorials For Absolute Beginners In Hindi '
#   '#23',
#   'function.json'],
#  [0.6681900115175785,
#   'Python Itertools For Advanced Iteration',
#   'oops-magic method-itertools.json'],
#  [0.6672133297723692,
#   'Python Programming Tutorial - Iterators (Part-1)',
#   'iterator-generator-decorator.json'],
#  [0.6668175149617563,
#   'Python Iterators | Iterables and Iterators in Python | Python Tutorial for '
#   'Beginners | Edureka',
#   'iterator-generator-decorator.json'],
#  [0.6666471164071451,
#   '6. INTRODUCTION TO EXCEPTION HANDLING IN PYTHON',
#   'exception handling.json'],
#  [0.6647687253470532, 'Peak Element', 'array.json'],
#  [0.6639959235659009, ' Max sum path in two arrays', 'array.json'],
#  [0.6627029031684266, 'What is Modular Programming?', 'module.json'],
#  [0.6622358962483099,
#   '4. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.6619704593447795, 'Find duplicates in an array', 'array.json'],
#  [0.6619636586411342,
#   ' NZEC error in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.660952427482791,
#   'Python Tutorial: Decorators - Dynamically Alter The Functionality Of Your '
#   'Functions',
#   'iterator-generator-decorator.json'],
#  [0.6594381705781335,
#   'Python program to get the Fibonacci series between 0 to 50',
#   'loop-for.json'],
#  [0.6563927620534445,
#   'Hindi Magic/Dunder Methods In Python? | Object Oriented Programming Using '
#   'Python Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.6561253797389432,
#   'Lambda in Python - Advanced Python 08 - Programming Tutorial - Map Filter '
#   'Reduce',
#   'function-lambda.json'],
#  [0.6552017509879211,
#   'Advanced Functional Programming in Python: lambda',
#   'function-lambda.json'],
#  [0.6546747873404928, 'Advanced features of Python Functions', 'function.json'],
#  [0.6546747873404928,
#   'Advanced Features in Python Functions | Python Functions Advanced',
#   'function.json'],
#  [0.6546422376182651,
#   'Exceptions in Python || Python Tutorial || Learn Python Programming',
#   'exception handling.json'],
#  [0.6541639832906062,
#   'What are Modules in Python and How to Define Modules in Python with '
#   'Examples',
#   'module.json'],
#  [0.6541569155803852, 'Arrays in python: Array Advance Game', 'array.json'],
#  [0.6534510191715769,
#   'ANONYMOUS FUNCTIONS (LAMBDA) - PYTHON PROGRAMMING',
#   'function-lambda.json'],
#  [0.6514366110336698, 'Shorthand statement', 'condition-pass.json'],
#  [0.6514366110336698, 'Shorthand if statement', 'condition-pass.json'],
#  [0.6509681117861589,
#   '#61 Python Tutorial for Beginners | Iterator',
#   'iterator-generator-decorator.json'],
#  [0.6496017564319556,
#   '[Hindi] Iterators, Iterables and Generators in python explained | Advanced '
#   'python tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.6496017564319556,
#   ' Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.6495180129458525,
#   'Decorators In Python | Python Tutorials For Absolute Beginners In Hindi #51',
#   'iterator-generator-decorator.json'],
#  [0.6480139774614824,
#   'Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials',
#   'iterator-generator-decorator.json'],
#  [0.6472094976475983, 'Write a program to sort the given array', 'array.json'],
#  [0.6453809779779249,
#   'Immediate Python- Functions, Modules, Classes and Exceptions',
#   'oops-class.json'],
#  [0.6452291002879352,
#   ' Exception handling tips in Python âš\xa0 Write better Python code part 7',
#   'exception handling.json'],
#  [0.6414464096626191,
#   'Lambda Operator, filter, reduce and map',
#   'function-lambda.json'],
#  [0.6413751358945862,
#   'Check the validity of a Password in Python',
#   'loop-for.json'],
#  [0.6383547745229544,
#   'Python Lambda Function | Anonymous Function In Python | Python Tutorial | '
#   'Edureka',
#   'function-lambda.json'],
#  [0.6369961349262282,
#   'Python 3 Programming Tutorial | #1 Introduction of Python Lambda and '
#   'Anonymous Function',
#   'function-lambda.json'],
#  [0.6368869761924523,
#   'Expert Python Tutorial #2 - Dunder/Magic Methods & The Python Data Model',
#   'oops-magic method-itertools.json'],
#  [0.6368758635917704,
#   'How to Use Python Lambda Functions',
#   'function-lambda.json'],
#  [0.6357010472113298, 'Module in Python (Hindi)', 'module.json'],
#  [0.6356817683126286,
#   'Advanced indexing Operations in Numpy Arrays',
#   'array.json'],
#  [0.6327942602890294,
#   'Decorators in Python - Advanced Python 13 - Programming Tutorial',
#   'iterator-generator-decorator.json'],
#  [0.6307359329718079,
#   'Python: Lambda, Map, Filter, Reduce Functions',
#   'function-lambda.json'],
#  [0.6306840576127899,
#   'Python Program for Series Calculation 1*1 + 2*2 + 3*3 +..+n | Series '
#   'Calculation Program in Python',
#   'loop-while.json'],
#  [0.6301278828823494,
#   'Itertools in Python - Advanced Python 07 - Programming Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.628664556529779,
#   'Building Lambda functions with Python',
#   'function-lambda.json'],
#  [0.6276604383879473,
#   'Python Programming for Intermediate programmer',
#   'oops-class.json'],
#  [0.6275449981359326, 'Sort an array using Quicksort Algorithm', 'array.json'],
#  [0.6273015868621673,
#   '#3: Python lambda (anonymous) Functions | Python Best Practices',
#   'function-lambda.json'],
#  [0.6268183677696545,
#   'Explore the magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.6265846069957517,
#   "A Guide to Python's Secret Superpower: Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.6264568342690794,
#   '#42 Python Tutorial for Beginners | Anonymous Functions | Lambda',
#   'function-lambda.json'],
#  [0.6261914589360559,
#   'Lambda Functions with Practical Examples in Python',
#   'function-lambda.json'],
#  [0.625900249281942, 'Python Modules', 'module.json'],
#  [0.625900249281942, 'Python Modules', 'module.json'],
#  [0.625900249281942, 'Python - Modules', 'module.json'],
#  [0.6256587843700815,
#   '[Hindi] Lambda functions in python in Hindi | Advanced python in Hindi',
#   'function-lambda.json'],
#  [0.6253176522041389, 'Nested if Condtion', 'condition-pass.json'],
#  [0.6248185217635559,
#   'Advance Python Series- Magic Methods',
#   'oops-class.json'],
#  [0.6247554754584391,
#   "HINDI BIT-PY Beginner's Python Course | Part #36 | Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.6237989334948414,
#   'Top 10 Most Popular Python Libraries | Yaswanth | GeeksforGeeks',
#   'module.json'],
#  [0.6217267234539109,
#   'Lambda Expressions - Python Tips and Tricks #5',
#   'function-lambda.json'],
#  [0.6185840020775557, 'Merge two dictionaries', 'dictionary.json'],
#  [0.6185840020775557, 'Merge two dictionaries', 'dictionary.json'],
#  [0.6184057601108742,
#   'Python Programs - Factorial Program Using for loop',
#   'loop-for.json'],
#  [0.6182855039893341,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'oops-magic method-itertools.json'],
#  [0.6182855039893341,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'function.json'],
#  [0.6182144838406387,
#   'Python OOP Tutorial 5: Special (Magic/Dunder) Methods',
#   'oops-magic method-itertools.json'],
#  [0.617003431877002,
#   'Intermediate Python Tutorial #5 - Lambda Functions',
#   'function-lambda.json'],
#  [0.61699078699847, 'Introduction to if else', 'condition-pass.json'],
#  [0.61699078699847, 'Introduction to if else', 'condition-pass.json'],
#  [0.6158666477455054, 'Write a program to reverse an array', 'array.json'],
#  [0.615196051985729,
#   'Python Intermediate: Lambda Functions',
#   'function-lambda.json'],
#  [0.61422313081831,
#   '#44 Python Tutorial for Beginners | Decorators',
#   'iterator-generator-decorator.json'],
#  [0.6141544073652503,
#   ' Python Functions | Python Tutorial for Absolute Beginners #1',
#   'function.json'],
#  [0.6140952185853624,
#   'Python Itertools | Itertools in Python | Python Tutorial for Beginners | '
#   'Edureka',
#   'oops-magic method-itertools.json'],
#  [0.6128264147909205, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.6128264147909205, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.610740131533928,
#   'Python Lambda/Anonymous Functions ',
#   'function-lambda.json'],
#  [0.6104387576035537, 'Pass statement', 'condition-pass.json'],
#  [0.6104387576035537, 'Pass statement', 'condition-pass.json'],
#  [0.6104387576035537, 'Pass statement', 'condition-pass.json'],
#  [0.6104387576035537, 'Pass statement', 'condition-pass.json'],
#  [0.6103739709312049,
#   'Comparison of Iterators and Generators in python',
#   'iterator-generator-decorator.json'],
#  [0.6102046789429796, 'High order functions in Python', 'function.json'],
#  [0.6101563674647639, 'Stock buy and sell Problem', 'array.json'],
#  [0.6097503463366002, 'How to add an item to a list in Python', 'list.json'],
#  [0.6076283856034495,
#   'Python Programming 19 - Remove Elements From List within for Loop',
#   'list.json'],
#  [0.6065667533703903,
#   ' Accessing elements of a nested dictionary',
#   'dictionary.json'],
#  [0.6065667533703903,
#   ' Accessing elements of a nested Dictionary',
#   'dictionary.json'],
#  [0.6060694648292166,
#   'Iterator And Generator In Python | Python Generators And Iterators '
#   'Explained | Python | Simplilearn',
#   'iterator-generator-decorator.json'],
#  [0.6049708330356234,
#   'Magic Methods in Python, by example | Using Magic Methods In Our Class '
#   'Design',
#   'oops-magic method-itertools.json'],
#  [0.6022913416869782,
#   'Accessing List using for Loop in Python (Hindi)',
#   'loop-for.json'],
#  [0.6007744428369053,
#   'How To Use Functions In Python (Python Tutorial #3)',
#   'function.json'],
#  [0.60056646148121,
#   'Iterators and Generators',
#   'iterator-generator-decorator.json'],
#  [0.60056646148121,
#   'Iterators & Generators',
#   'iterator-generator-decorator.json'],
#  [0.60056646148121,
#   'Generators and Iterators',
#   'iterator-generator-decorator.json'],
#  [0.5984923967933987, 'Get dictionary method', 'dictionary.json'],
#  [0.5984923967933987, 'Get dictionary method', 'dictionary.json'],
#  [0.5978858878439803, 'Advanced Python for Data Science', 'oops-class.json'],
#  [0.5978615448005347,
#   'Lambda Functions - Advanced Python 08',
#   'function-lambda.json'],
#  [0.5971316815167714, 'Intermediate Programming with Python', 'module.json'],
#  [0.5964924243284204,
#   'Lambda Function in Python - In Hindi',
#   'function-lambda.json'],
#  [0.5961954142092738,
#   ' Exceptions in Python - Advanced Python 09 - Programming Tutorial',
#   'exception handling.json'],
#  [0.5958961382080318,
#   'Generators In Python | Python Tutorials For Absolute Beginners In Hindi #72',
#   'iterator-generator-decorator.json'],
#  [0.5950078563084339, 'Expert Python Tutorial', 'oops-class.json'],
#  [0.5948356823304755,
#   'Lambda Function in Python -     Example Syntax',
#   'function-lambda.json'],
#  [0.594355517937555, 'Python Iterators', 'iterator-generator-decorator.json'],
#  [0.5939483325857782,
#   'Tutorial: Lambda Functions in Python',
#   'function-lambda.json'],
#  [0.593943188384404,
#   " Python Functions (The Only Guide You'll Need) #12",
#   'function.json'],
#  [0.5932577224386631,
#   "A Guide to Python's Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.5926254468046886,
#   'Lambda Functions in Python | Python Tutorial #37',
#   'function-lambda.json'],
#  [0.59191546513964,
#   'Introducing Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.5913202368010196, 'Nested if condition', 'condition-pass.json'],
#  [0.5904546279415246,
#   'Python Lambda | Advanced Python | Tutorial 18',
#   'function-lambda.json'],
#  [0.5885182973790992,
#   'Function Decorator in Python (Hindi)',
#   'iterator-generator-decorator.json'],
#  [0.5874626054559179,
#   'Lambda Expression : Python tutorial 150',
#   'function-lambda.json'],
#  [0.5873913358937991, 'Lambda Functions', 'function-lambda.json'],
#  [0.5871630173212364,
#   'Python program to check if a string is a palindrome or not',
#   'loop-for.json'],
#  [0.5870896072096874, ' Add list items', 'list.json'],
#  [0.586592664545112,
#   'Advanced Python: What Are Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.5864923798337607,
#   'Generators and Iterators in python | python tutorial',
#   'iterator-generator-decorator.json'],
#  [0.5858826125147415, ' Copy dictionary method', 'dictionary.json'],
#  [0.5858826125147415, ' Copy dictionary method', 'dictionary.json'],
#  [0.5858260608689612,
#   ' User-defined Exceptions in Python with Examples - GeeksforGeeks',
#   'exception handling.json'],
#  [0.584189788582784, 'Pop dictionary method', 'dictionary.json'],
#  [0.584189788582784, 'Pop dictionary method', 'dictionary.json'],
#  [0.5837610276132648,
#   'Lambda and filter in Python Examples',
#   'function-lambda.json'],
#  [0.5837150326205381, 'Python Functions Advanced', 'function.json'],
#  [0.5837150326205381, 'Python Advanced Functions', 'function.json'],
#  [0.5807243394380975,
#   'Itertools - Advanced Python 07',
#   'oops-magic method-itertools.json'],
#  [0.5799430822958478, 'Python Immediate Tutorial #1', 'oops-class.json'],
#  [0.5794173086859565,
#   'Advance Python Series-Magic Methods In Classes',
#   'oops-magic method-itertools.json'],
#  [0.5778612063315178, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.5778612063315178, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.5766163168706641,
#   'Puthon OOP Tutorial 1: Classes and Instances',
#   'oops-class.json'],
#  [0.5765366558397239, 'Maximum Index', 'array.json'],
#  [0.5764603458664015,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.5764603458664015,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.5741863305055609, 'Immediate Python Programming', 'oops-class.json'],
#  [0.5720679226140534,
#   ' #32 Python Tutorial for Beginners | Functions in Python',
#   'function.json'],
#  [0.5699901491576548, '#27 Python Tutorial for Beginners', 'array.json'],
#  [0.5699901491576548, ' #26 Python Tutorial for Beginners', 'array.json'],
#  [0.567824034835452, 'PythonDocs Python Function', 'function.json'],
#  [0.5659423352960115, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.5659423352960115, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.5621987272817625,
#   '#20 Python Tutorial for Beginners | While Loop in Python',
#   'loop-while.json'],
#  [0.5594307767109215,
#   'Classes & Objects in Python | Python OOP Tutorial | Python for Beginners',
#   'oops-class.json'],
#  [0.556291024307638,
#   '#49 Python Tutorial for Beginners| Class and Object',
#   'oops-class.json'],
#  [0.5558462575772622, 'Copy lists', 'list.json'],
#  [0.5558462575772622, 'Copy list', 'list.json'],
#  [0.5549788618734955, 'Checking for membership in lists', 'list.json'],
#  [0.5549788618734955, ' Checking for membership in lists', 'list.json'],
#  [0.5532706482584159,
#   'What are Python Iterators and Generators?',
#   'iterator-generator-decorator.json'],
#  [0.5532706482584159,
#   'PYTHON ITERATORS AND GENERATORS',
#   'iterator-generator-decorator.json'],
#  [0.5532706482584159,
#   'Iterators and Generators in Python',
#   'iterator-generator-decorator.json'],
#  [0.5532706482584159,
#   'Generators & Iterators in python',
#   'iterator-generator-decorator.json'],
#  [0.553225382828036,
#   '#62 Python Tutorial for Beginners | Generators',
#   'iterator-generator-decorator.json'],
#  [0.5471994582093251, 'Python Functions Edureka ', 'function.json'],
#  [0.5466557734306151, 'Python Lambda Expressions', 'function-lambda.json'],
#  [0.5464537042890194,
#   'How to Change/Replace/Update List Items ? | List tutorial in python',
#   'list.json'],
#  [0.5441952530892896, 'TutorialsPoint Python Functions ', 'function.json'],
#  [0.5405331541851771,
#   'Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.5405331541851771,
#   'Python - Magic Methods ',
#   'oops-magic method-itertools.json'],
#  [0.5394874656127521,
#   'Itertools in Python 3, By Example',
#   'oops-magic method-itertools.json'],
#  [0.5359086338611885, 'Accessing elements of a dictionary', 'dictionary.json'],
#  [0.5359086338611885,
#   '. Accessing elements of a dictionary',
#   'dictionary.json'],
#  [0.5346758434504633, 'Clear dictionary method', 'dictionary.json'],
#  [0.5346758434504633, 'Clear dictionary method', 'dictionary.json'],
#  [0.5338782258843422,
#   'Python Try Except - GeeksforGeeks',
#   'exception handling.json'],
#  [0.533372660095216,
#   'Python - Magic or Dunder Methods',
#   'oops-magic method-itertools.json'],
#  [0.533372660095216,
#   'Dunder or magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.5326768297265727,
#   '@Decorators in Python (Advanced)',
#   'iterator-generator-decorator.json'],
#  [0.5326106970092005,
#   'Python Itertools javapoint',
#   'oops-magic method-itertools.json'],
#  [0.5313549485349283, 'Join lists', 'list.json'],
#  [0.5313549485349283, 'Join Lists', 'list.json'],
#  [0.5309147229876152, 'JavaPoint Python Functions ', 'function.json'],
#  [0.5303878689508266, 'LearnPython Python Functions', 'function.json'],
#  [0.5291771587338082, 'Using classes in Python', 'oops-class.json'],
#  [0.529104552264277, 'Arrays in Python Programming', 'array.json'],
#  [0.5289678910057818, 'GFG Python Functions ', 'function.json'],
#  [0.5233047553678497, 'Programiz Python Functions ', 'function.json'],
#  [0.5220658978445575, 'Nested Dictionaries', 'dictionary.json'],
#  [0.5220658978445575, ' Nested Dictionaries', 'dictionary.json'],
#  [0.5196593597620822, 'Python programming', 'oops-class.json'],
#  [0.5194231666601217, 'Reversing lists', 'list.json'],
#  [0.5194231666601217, ' Reversing the lists', 'list.json'],
#  [0.5189619258767754, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.5189619258767754, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.518622377793916, 'Sort lists', 'list.json'],
#  [0.518622377793916, ' Sort list', 'list.json'],
#  [0.5139159186710823,
#   'Python Itertools gfg',
#   'oops-magic method-itertools.json'],
#  [0.5125902173183708, 'Data model', 'oops-magic method-itertools.json'],
#  [0.507897192234619, 'Python Conditions', 'condition-pass.json'],
#  [0.507897192234619, 'Python Condition', 'condition-pass.json'],
#  [0.5067004415670746, ' Python Lambda', 'function-lambda.json'],
#  [0.5063293326305961, 'Python Programming | Classes', 'oops-class.json'],
#  [0.5051812132901268, 'Arrays in python| Python for beginners', 'array.json'],
#  [0.5051651774616502, 'Python Classes and Obejcts', 'oops-class.json'],
#  [0.5048009822813511, ' exceptions.Exception', 'exception handling.json'],
#  [0.5045708550526511, 'Python Functions ', 'function.json'],
#  [0.49735652773053435, 'Advanced Python classes', 'oops-class.json'],
#  [0.49734169164548797,
#   'Object Oriented Porgramming in Python',
#   'oops-class.json'],
#  [0.4948493818523187, ' Access list items', 'list.json'],
#  [0.49420828721345755, ' Update dictionary method', 'dictionary.json'],
#  [0.49420828721345755, ' Update dictionary method', 'dictionary.json'],
#  [0.4910709185831785, 'Python Decorators', 'iterator-generator-decorator.json'],
#  [0.4910709185831785, 'Python Decorator', 'iterator-generator-decorator.json'],
#  [0.4910709185831785,
#   'Decorators in Python',
#   'iterator-generator-decorator.json'],
#  [0.4899387096812009, 'Magic Methods', 'oops-magic method-itertools.json'],
#  [0.48945417129828567, 'Python While Loops', 'loop-while.json'],
#  [0.48249694543171884, 'Define CLasses in Python', 'oops-class.json'],
#  [0.48198334948018356, 'List methods', 'list.json'],
#  [0.48198334948018356, 'List methods', 'list.json'],
#  [0.48173291367564314, 'Loop lists', 'list.json'],
#  [0.48173291367564314, ' Loop lists', 'list.json'],
#  [0.4794882417712609, ' Remove list items', 'list.json'],
#  [0.47887855183754424, 'Indentation', 'condition-pass.json'],
#  [0.47887855183754424, 'Indentation', 'condition-pass.json'],
#  [0.4780156582859629, 'List comprehension', 'list.json'],
#  [0.4780156582859629, ' List comprehension', 'list.json'],
#  [0.4770721205427255, 'Change list items', 'list.json'],
#  [0.4765842353602568, 'Filtering the lists', 'list.json'],
#  [0.4765842353602568, ' Filtering the lists', 'list.json'],
#  [0.4489670443705207, '384 Shuffle an array', 'array.json'],
#  [0.44602889284737635, 'Python Objects and Classes', 'oops-class.json'],
#  [0.44602889284737635, 'Python Classes and Objects', 'oops-class.json'],
#  [0.44602889284737635, 'Classes and Objects in python', 'oops-class.json'],
#  [0.44602889284737635, 'Classes and Objects in Python', 'oops-class.json'],
#  [0.44184711046414665, 'What Are Access Lists? ', 'list.json'],
#  [0.43598305433861945, 'Classes and Objects (OOPS)', 'oops-class.json'],
#  [0.4292764399617042, 'Python Classes', 'oops-class.json'],
#  [0.40565754938605186,
#   'Python Generators',
#   'iterator-generator-decorator.json'],
#  [0.39662071438473473, 'Creating a dictionary-', 'dictionary.json'],
#  [0.39662071438473473, 'Creating a dictionary', 'dictionary.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json']]

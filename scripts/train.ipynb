# %%
import json
from pathlib import Path
import gensim
from gensim.models import Word2Vec

from stopstem import *

# %%
import os
 

path = "C://Users//ganes//Desktop//mini//reference"
dir_list = os.listdir(path)

# %%
print(dir_list)
# Out:
# ['2.0.txt', '2.1.txt', '2.2.txt', '2.3.txt', '2.4.txt', '2.5.txt', '2.6.txt', '2.7.txt', '2to3.txt', '3.0.txt', '3.1.txt', '3.10.txt', '3.11.txt', '3.2.txt', '3.3.txt', '3.4.txt', '3.5.txt', '3.6.txt', '3.7.txt', '3.8.txt', '3.9.txt', 'abc.txt', 'abstract.txt', 'aifc.txt', 'allocation.txt', 'allos.txt', 'annotations.txt', 'apiabiversion.txt', 'apiref.txt', 'archiving.txt', 'arg.txt', 'argparse.txt', 'array.txt', 'ast.txt', 'asynchat.txt', 'asyncio-api-index.txt', 'asyncio-dev.txt', 'asyncio-eventloop.txt', 'asyncio-exceptions.txt', 'asyncio-extending.txt', 'asyncio-future.txt', 'asyncio-llapi-index.txt', 'asyncio-platforms.txt', 'asyncio-policy.txt', 'asyncio-protocol.txt', 'asyncio-queue.txt', 'asyncio-runner.txt', 'asyncio-stream.txt', 'asyncio-subprocess.txt', 'asyncio-sync.txt', 'asyncio-task.txt', 'asyncio.txt', 'asyncore.txt', 'atexit.txt', 'audioop.txt', 'audit_events.txt', 'base64.txt', 'bdb.txt', 'binary.txt', 'binascii.txt', 'bisect.txt', 'bool.txt', 'buffer.txt', 'building.txt', 'builtdist.txt', 'builtins.txt', 'bytearray.txt', 'bytes.txt', 'bz2.txt', 'calendar.txt', 'call.txt', 'capsule.txt', 'cell.txt', 'cgi.txt', 'cgitb.txt', 'changelog.txt', 'chunk.txt', 'clinic.txt', 'cmath.txt', 'cmd.txt', 'code.txt', 'codec.txt', 'codecs.txt', 'codeop.txt', 'collections.abc.txt', 'collections.txt', 'colorsys.txt', 'commandref.txt', 'compileall.txt', 'complex.txt', 'compound_stmts.txt', 'concrete.txt', 'concurrency.txt', 'concurrent.futures.txt', 'concurrent.txt', 'configfile.txt', 'configparser.txt', 'constants.txt', 'contextlib.txt', 'contextvars.txt', 'conversion.txt', 'copy.txt', 'copyreg.txt', 'coro.txt', 'cporting.txt', 'crypt.txt', 'crypto.txt', 'csv.txt', 'ctypes.txt', 'curses.ascii.txt', 'curses.panel.txt', 'curses.txt', 'custominterp.txt', 'dataclasses.txt', 'datamodel.txt', 'datatypes.txt', 'datetime.txt', 'dbm.txt', 'debug.txt', 'decimal.txt', 'descriptor.txt', 'design.txt', 'development.txt', 'devmode.txt', 'dialog.txt', 'dict.txt', 'difflib.txt', 'dis.txt', 'distribution.txt', 'distutils.txt', 'doctest.txt', 'email.charset.txt', 'email.compat32-message.txt', 'email.contentmanager.txt', 'email.encoders.txt', 'email.errors.txt', 'email.examples.txt', 'email.generator.txt', 'email.header.txt', 'email.headerregistry.txt', 'email.iterators.txt', 'email.message.txt', 'email.mime.txt', 'email.parser.txt', 'email.policy.txt', 'email.txt', 'email.utils.txt', 'embedding.txt', 'ensurepip.txt', 'enum.txt', 'errno.txt', 'examples.txt', 'exceptions.txt', 'executionmodel.txt', 'expressions.txt', 'extending.txt', 'faulthandler.txt', 'fcntl.txt', 'file.txt', 'filecmp.txt', 'fileformats.txt', 'fileinput.txt', 'filesys.txt', 'float.txt', 'fnmatch.txt', 'fractions.txt', 'frame.txt', 'frameworks.txt', 'ftplib.txt', 'function.txt', 'functional.txt', 'functions.txt', 'functools.txt', 'gc.txt', 'gcsupport.txt', 'gen.txt', 'general.txt', 'getopt.txt', 'getpass.txt', 'gettext.txt', 'glob.txt', 'grammar.txt', 'graphlib.txt', 'grp.txt', 'gui.txt', 'gzip.txt', 'hashlib.txt', 'heapq.txt', 'hmac.txt', 'html.entities.txt', 'html.parser.txt', 'html.txt', 'http.client.txt', 'http.cookiejar.txt', 'http.cookies.txt', 'http.server.txt', 'http.txt', 'i18n.txt', 'idle.txt', 'imaplib.txt', 'imghdr.txt', 'imp.txt', 'import.txt', 'importlib.metadata.txt', 'importlib.resources.abc.txt', 'importlib.resources.txt', 'importlib.txt', 'index.txt', 'init.txt', 'init_config.txt', 'inspect.txt', 'installed.txt', 'instrumentation.txt', 'internet.txt', 'intro.txt', 'io.txt', 'ipaddress.txt', 'ipc.txt', 'isolating-extensions.txt', 'iter.txt', 'iterator.txt', 'itertools.txt', 'json.txt', 'keyword.txt', 'language.txt', 'lexical_analysis.txt', 'library.txt', 'linecache.txt', 'list.txt', 'locale.txt', 'logging-cookbook.txt', 'logging.config.txt', 'logging.handlers.txt', 'logging.txt', 'long.txt', 'lzma.txt', 'mailbox.txt', 'mailcap.txt', 'mapping.txt', 'markup.txt', 'marshal.txt', 'math.txt', 'memory.txt', 'memoryview.txt', 'method.txt', 'mimetypes.txt', 'mm.txt', 'mmap ...

# %%
matrix=[]
for i in dir_list:
    with open("../reference/"+i,'r') as data_source:
        try:
            data1 = data_source.read()
            stemmed = tokenizeAndStem(data1)
            matrix.append(stemmed)
        except:
            print(i)
        
print(matrix)
# Out:
# 3.11.txt
# 3.2.txt
# 3.4.txt
# 3.5.txt
# 3.6.txt
# 3.7.txt
# 3.8.txt
# 3.9.txt
# changelog.txt
# decimal.txt
# instrumentation.txt
# logging-cookbook.txt
# math.txt
# nntplib.txt
# random.txt
# stable.txt
# unicode.txt
# [['pep', 'fix', 'lockstep', 'short', 'offset', 'makefil', 'minim', 'pull', 'help', 'long-await', 'exist', 'recent', 'kw', 'slightli', 'variabl', 'natur', 'limit', 'substr', 'add', 'whose', 'distutils.cor', 'modern', 'curs', 'mani', 'project', 'bdist_rpm', 'whitespac', 'layer', 'becom', 'macmillan', 'environ', 'slant', 'devic', 'obtain', 'fred', 'recommend', 'ncurs', 'do', 'java', 'consensu', 'sourc', 'nameerror', 'n.valu', 'write', 'know', 'earli', 'along', 'bounc', 'softwar', 'root.removechild', 'setcontenthandl', 'search', 'non-default', 'mosh', 's.endswith', 'xint', 'map', "c'", 'remark', 'treat', 'david', 'thoma', 'let', 'version', 'slice', 'mechan', 'properti', 'breakag', '_winreg', 'expect', 'getelementsbytagnam', 'design', 'int-digit', 'xml_n', 'special', 'affair', 'modul', 'long', 'endswith', 'bosch', 'future-proof', 'readlin', 'first', 'base', 'inspir', 'inaccess', 'compat', 'afford', 'actual', 'wart', 'paid', 'sdist', 'statu', 'drake', 'offer', 'jeremi', "it'll", 'line', 'fundament', 'key', 'pose', 'notif', 'somewhat', 'via', 'catalog', 'int-el', 'patch-by-patch', 'stand', 'trashcan', 'time', 'elementwis', 'gnu', 'replac', 'wildli', 'charl', 'ship', 'g', 'similarli', 'went', 'submit', 'septemb', 'embed', 'updat', "sig'", 'pyos_getsig', 'isomorph', 'repr', 'pass', 'foo-int.int.tar.gz', 'audio', 'immut', 'allow', 'tricki', 'sunaudiodev', 'throughout', 'local', 'pyxml', 'overview', 'fill', 'see', '|=', 'buggi', 'exec', 'achiev', 'late', 'parser.pars', 'pick', 'vote', 'claus', ':/', 'convent', 'x', 'slight', 'arduou', 'ip', 'content', 'program', 'explod', 'tell', 'len', 'nest', '):', 'hauser', "sourceforge'", 'float', 'handl', 'futur', 'pyarg_parsetupl', 'import', 'capit', 'contribut', 'henstridg', 'guido', 'iter', 'sever', 'develop', 'easier', 'docstr', 'setattr', 'count', 'wouter', 'queue', 'zip', 'overhead', 'skip', 'automat', 'awk', "they'r", 'hewlett', 'object', 'hylton', 'remov', 'action', 'file', 'tobi', 'spam', 'mostli', 'titl', 'good', 'simplehandl', 'continu', "fulton'", 'xml.parsers.pyexpat', 'pythonlab', 'top', '</tagint>', 'written', 'fast', 'sys.path', 'vari', 'abl', 'differ', 'quot', 'nice', 'indiffer', 'strip', 'stricter', 's.startswith', 'obvious', 'shepherd', 'confus', 'string.find', 'persona', 'therefor', 'string.join', 'statement', 'print', 'find_recursionlimit', 'pre-int.int', 'maximum', 'decis', 'non', 'often-stormi', 'ose', 'respect', 'widget', 'lack', 'gener', 'mail', 'distribut', 'eric', 'forgiv', 'rais', 'come', 'dump', 'eas', 'lu', 'revis', 'applic', 'perform', 'symmetri', 'readm', 'flurri', 'forward-compat', 'command-lin', 'fact', 'instruct', 'packag', 'packard', 'full', 'benchmark', 'large-fil', 'fool', 'alway', 'turn', 'common', 'stage', 'imputil', 'round', 'up-to', 'van', 'end', 'store', 'paragraph', 'within', 'encod', 'utfint_streamread', 'cv', 'lot', 'encount', 'digit', 'intff', 'scalabl', 'port', 'shift', 'improv', 'arg', 'deepli', 'difficulti', 'pymem', 'charact', 'stop', 'explan', 'eight', 'return', 'encrypt', 'part', 'cycle-gc', 'create_polygon', 'section', 'bsd', 'leav', 'mous', 'better', 'syntaxerror', 'algorithm', 'took', 'measur', "what'", 'hook', 'directli', "andrich'", 'revers', 'set', 'length', 'fall', 'bytecod', 'later', 'objectwis', 'true', 'switch', 'relev', "u'a", 'decreas', 'socket', 'host', 'mullend', 'test', 'fetchabl', '__init__', 'regular', 'https://pythonce.sourceforge.net/', 'child', 'current', 'self', 'second', 'int.int.int', "that'", 'explain', 'instance.myself', 'b.append', 'either', 'avoid', 'shell', 'robotpars', 'gotten', 'everi', 'appropri', 'string', 'gone', 'dom', 'littl', 'zip-format', 'note', 'lose', 'lab', 'fffd', 'simpli', 'mass', 'denmark', 'taberror', 'default', 'random', 'listobject', 'cost', 'mark', 'look', 'editori', 'ugli', 'job', 'intth', 'son', 'ctrl-fint', 'ssl', 'dictat', 'socket.bind', 'independ', 'none', 'tighten', 'tupl', 'cmpcach', 'scope', 'stream', 'separ', 'evolut', 'hostnam', 'place', 'gusi', 'fourfold', 'ide', "there'", 'column', 'quest ...

# %%
model1 = Word2Vec(matrix, min_count = 1, window = 5, sg=0)

# %%
from cosines import cacCosine

# %%
q1 = "Python Program to Print Natural Numbers Using While and For Loop in Hindi - Tutorial #22"
q2 = "Print the first 10 natural numbers using for loop"
print(model1.wv)
def sim(q1,q2):
    a1 = q1.split()
    import numpy as np
    v1 = np.array([0.0]*100)
    v2 = np.array([0.0]*100)
    c1=1
    for i in a1:
        try:
            v1+=model1.wv[i]
            c1+=1
        except:
            pass
    v1/=c1
    a2 = q2.split()
    c2=1
    for i in a2:
        try:
            v2+=model1.wv[i]
            c2+=1
        except:
            pass
    v2/=c2
    return cacCosine(list(v1),list(v2))
# Out:
# KeyedVectors<vector_size=100, 29264 keys>

# %%
import os
BASE_DIR = Path(os.getcwd()).resolve().parent
f = open(BASE_DIR/'jsons/loop-for.json')
def findSimilar(listOfDocs,query):
    #dic={stemmdtitle:[title,link,file]}
    dic={}
    maxi=[]
    for i in listOfDocs:
        if i[-4::]=='json':
            with open(BASE_DIR/('jsons/'+i)) as f:
                data=json.load(f)
                for j in data:
                    for k in data[j]['videos'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['videos'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
                    for k in data[j]['reading'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['reading'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
    return dic,maxi

# %%
from pprint import pprint as p
path = "C://Users//ganes//Desktop//mini//jsons"
l = os.listdir(path)
print(l)
dic,maxi = findSimilar(l,"how to mak dictionary")
p(sorted(maxi,reverse=True))
# Out:
# ['array.json', 'condition-pass.json', 'dictionary.json', 'exception handling.json', 'function-lambda.json', 'function.json', 'iterator-generator-decorator.json', 'list.json', 'loop-for.json', 'loop-while.json', 'module.json', 'oops-class.json', 'oops-magic method-itertools.json', 'oops-operator-overloading.lehson', 'oops-operator-overloading.pdf', 'pdfs', 'regularexpression.pdf', 'set.pdf', 'string.pdf', 'syllabus.pdf', 'template.json', 'threading.pdf', 'tree.pdf', 'tuple.pdf']
# [[0.9908802950665472, '384 Shuffle an array', 'array.json'],
#  [0.961841723338662, 'Nested Dictionaries', 'dictionary.json'],
#  [0.961841723338662, ' Nested Dictionaries', 'dictionary.json'],
#  [0.9264917394613397, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.9264917394613397, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.9247380866636489, 'Accessing elements of a dictionary', 'dictionary.json'],
#  [0.9247380866636489,
#   '. Accessing elements of a dictionary',
#   'dictionary.json'],
#  [0.9059515905980133,
#   ' Accessing elements of a nested dictionary',
#   'dictionary.json'],
#  [0.9059515905980133,
#   ' Accessing elements of a nested Dictionary',
#   'dictionary.json'],
#  [0.8840358122349663,
#   'Python Lambda | Advanced Python | Tutorial 18',
#   'function-lambda.json'],
#  [0.8643179166146595, 'Creating a dictionary-', 'dictionary.json'],
#  [0.8643179166146595, 'Creating a dictionary', 'dictionary.json'],
#  [0.8518596701791357, 'Merge two dictionaries', 'dictionary.json'],
#  [0.8518596701791357, 'Merge two dictionaries', 'dictionary.json'],
#  [0.8426100693095304, ' Update dictionary method', 'dictionary.json'],
#  [0.8426100693095304, ' Update dictionary method', 'dictionary.json'],
#  [0.8243694942385787, 'Maximum Index', 'array.json'],
#  [0.8172880098966636, 'Nested if condition', 'condition-pass.json'],
#  [0.8141609770519161, ' Copy dictionary method', 'dictionary.json'],
#  [0.8141609770519161, ' Copy dictionary method', 'dictionary.json'],
#  [0.8097097088572991, 'Pop dictionary method', 'dictionary.json'],
#  [0.8048591084455179,
#   'Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.7605731338640211,
#   'Advanced indexing Operations in Numpy Arrays',
#   'array.json'],
#  [0.7530641934735303, 'Get dictionary method', 'dictionary.json'],
#  [0.671623555310723, 'Pass statement', 'condition-pass.json'],
#  [0.671623555310723, 'Pass statement', 'condition-pass.json'],
#  [0.6702527618894786, 'Stock buy and sell Problem', 'array.json'],
#  [0.6629052525926448, 'Indentation', 'condition-pass.json'],
#  [0.6629052525926448, 'Indentation', 'condition-pass.json'],
#  [0.657828793343932,
#   'Find the minimum and maximum element in an array',
#   'array.json'],
#  [0.6510854364429194, 'Write a program to reverse an array', 'array.json'],
#  [0.6452340478755872, 'Peak Element', 'array.json'],
#  [0.6433269194704381, 'Write a program to sort the given array', 'array.json'],
#  [0.6320524424845089,
#   'Write a program to cyclically rotate an array by one| Love Babbar DSA Sheet',
#   'array.json'],
#  [0.6317096491938133, 'Find missing and repeating', 'array.json'],
#  [0.631226598813611,
#   'Write a program to cyclically rotate an array by one',
#   'array.json'],
#  [0.628246873338364, 'Pair with the given sum in a sorted array', 'array.json'],
#  [0.6223256774907477, 'Find duplicates in an array', 'array.json'],
#  [0.6149802633865372, 'Introduction to if else', 'condition-pass.json'],
#  [0.6149802633865372, 'Introduction to if else', 'condition-pass.json'],
#  [0.6104426319391357, ' Max sum path in two arrays', 'array.json'],
#  [0.6087625616666458, 'Python Conditions', 'condition-pass.json'],
#  [0.6087625616666458, 'Python Condition', 'condition-pass.json'],
#  [0.5997500063967284, 'Sort an array using Quicksort Algorithm', 'array.json'],
#  [0.5960924671800429, 'Count pairs with given sum', 'array.json'],
#  [0.5899571010981316, 'Find missing number', 'array.json'],
#  [0.5858848353524735,
#   'Find missing number in an array in python',
#   'array.json'],
#  [0.579933179789598, 'Nested if Condtion', 'condition-pass.json'],
#  [0.5757775346871329, '#27 Python Tutorial for Beginners', 'array.json'],
#  [0.5757775346871329, ' #26 Python Tutorial for Beginners', 'array.json'],
#  [0.5757744388575092,
#   'Creating One Dimensional Array using Numpy',
#   'array.json'],
#  [0.5722137877362135, 'Arrays in python: Array Advance Game', 'array.json'],
#  [0.5581865820031905, 'Arrays in Python Programming', 'array.json'],
#  [0.5366720374289911, 'Elif statement', 'condition-pass.json'],
#  [0.5366720374289911, 'Elif statement', 'condition-pass.json'],
#  [0.5288613906300917, 'Subarray with given sum', 'array.json'],
#  [0.5224151836629986, 'Arrays in python| Python for beginners', 'array.json'],
#  [0.5102467309388049, 'Shorthand statement', 'condition-pass.json'],
#  [0.5102467309388049, 'Shorthand if statement', 'condition-pass.json'],
#  [nan, ' exceptions.Exception', 'exception handling.json'],
#  [0.9812023157240588, 'Change list items', 'list.json'],
#  [0.979849391506862, 'List comprehension', 'list.json'],
#  [0.979849391506862, ' List comprehension', 'list.json'],
#  [0.9759008848588572, ' Remove list items', 'list.json'],
#  [0.9742455628538441, 'Filtering the lists', 'list.json'],
#  [0.9742455628538441, ' Filtering the lists', 'list.json'],
#  [0.9728023318445337, 'Reversing lists', 'list.json'],
#  [0.9728023318445337, ' Reversing the lists', 'list.json'],
#  [0.9712456435795248, 'Join lists', 'list.json'],
#  [0.9712456435795248, 'Join Lists', 'list.json'],
#  [0.9643377636371635, 'What Are Access Lists? ', 'list.json'],
#  [0.9635795233575332, 'Copy lists', 'list.json'],
#  [0.9635795233575332, 'Copy list', 'list.json'],
#  [0.961425376638455, 'Loop lists', 'list.json'],
#  [0.961425376638455, ' Loop lists', 'list.json'],
#  [0.959172725323679, 'Sort lists', 'list.json'],
#  [0.959172725323679, ' Sort list', 'list.json'],
#  [0.9351924957516027,
#   'How to Change/Replace/Update List Items ? | List tutorial in python',
#   'list.json'],
#  [0.9298309803570521, 'Checking for membership in lists', 'list.json'],
#  [0.9298309803570521, ' Checking for membership in lists', 'list.json'],
#  [0.929745300048216, ' Access list items', 'list.json'],
#  [0.9190239260968571,
#   'Python Programming 19 - Remove Elements From List within for Loop',
#   'list.json'],
#  [0.9057170527148246, ' Add list items', 'list.json'],
#  [0.8906051791504421, 'Classes and Objects (OOPS)', 'oops-class.json'],
#  [0.8777633542119709,
#   'Itertools - Advanced Python 07',
#   'oops-magic method-itertools.json'],
#  [0.8722282492171346,
#   'Top 10 Most Popular Python Libraries | Yaswanth | GeeksforGeeks',
#   'module.json'],
#  [0.871702762191415,
#   'Python Itertools | Hindi | Part 1 | Python for Beginner to Expert | In '
#   'Detail Explanation',
#   'oops-magic method-itertools.json'],
#  [0.8684604734961866,
#   'Frequently Asked Python Program 17: Multiply All Numbers in the List',
#   'loop-while.json'],
#  [0.8664459111961754,
#   'Puthon OOP Tutorial 1: Classes and Instances',
#   'oops-class.json'],
#  [0.8663897502648485,
#   'Object Oriented Porgramming in Python',
#   'oops-class.json'],
#  [0.8574973658512415,
#   'Python Program for Series Calculation 1*1 + 2*2 + 3*3 +..+n | Series '
#   'Calculation Program in Python',
#   'loop-while.json'],
#  [0.8564418583412393, 'List methods', 'list.json'],
#  [0.8564418583412393, 'List methods', 'list.json'],
#  [0.8539148344402749,
#   'Lambda Expression : Python tutorial 150',
#   'function-lambda.json'],
#  [0.840036835090242,
#   'Itertools in Python - Advanced Python 07 - Programming Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.8398930725278096,
#   'Decorators in Python - Advanced Python 13 - Programming Tutorial',
#   'iterator-generator-decorator.json'],
#  [0.8394913961631569,
#   '4. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.8389356164583938,
#   'Lambda Functions - Advanced Python 08',
#   'function-lambda.json'],
#  [0.837163233431846,
#   '#49 Python Tutorial for Beginners| Class and Object',
#   'oops-class.json'],
#  [0.8363619168348665,
#   'Python OOP Tutorial 5: Special (Magic/Dunder) Methods',
#   'oops-magic method-itertools.json'],
#  [0.8355118633487247,
#   'Classes & Objects in Python | Python OOP Tutorial | Python for Beginners',
#   'oops-class.json'],
#  [0.8350518646643255, 'How to add an item to a list in Python', 'list.json'],
#  [0.8316505169270677,
#   '5 Advanced Functions in Itertools To Simplify Iterations in Python',
#   'oops-magic method-itertools.json'],
#  [0.831456380520461,
#   ' Exception handling tips in Python âš\xa0 Write better Python code part 7',
#   'exception handling.json'],
#  [0.828951713237947,
#   'Python Advanced Modules Made Easy â€” Part 1',
#   'module.json'],
#  [0.8281300910780992, 'Python Objects and Classes', 'oops-class.json'],
#  [0.8281300910780992, 'Python Classes and Objects', 'oops-class.json'],
#  [0.8281300910780992, 'Classes and Objects in python', 'oops-class.json'],
#  [0.8281300910780992, 'Classes and Objects in Python', 'oops-class.json'],
#  [0.8279916887810287,
#   'Python Program to find the sum of a Series 1/1! + 2/2! + 3/3! + 4/4! '
#   '+â€¦â€¦.+ n/n!',
#   'loop-while.json'],
#  [0.8267365382607124,
#   ' Day 24: Advanced Exception Handling and Raising Exceptions',
#   'exception handling.json'],
#  [0.8264184189414634,
#   '6. INTRODUCTION TO EXCEPTION HANDLING IN PYTHON',
#   'exception handling.json'],
#  [0.8244470720047569,
#   'Lambda in Python - Advanced Python 08 - Programming Tutorial - Map Filter '
#   'Reduce',
#   'function-lambda.json'],
#  [0.8226697192875823,
#   ' Exceptions in Python - Advanced Python 09 - Programming Tutorial',
#   'exception handling.json'],
#  [0.820718733639765,
#   'Python 3 Programming Tutorial | #1 Introduction of Python Lambda and '
#   'Anonymous Function',
#   'function-lambda.json'],
#  [0.8203643288632373,
#   'Top 5 Python Modules You Should Know in 2023',
#   'module.json'],
#  [0.8146509318631384,
#   'Working with Own Modules - Python Advanced Tutorial Series - 37',
#   'module.json'],
#  [0.8116104945533609,
#   'Frequently Asked Python Program 20:Check String is Palindrome or Not',
#   'loop-for.json'],
#  [0.8101970000467195, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.8101970000467195, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.8100807292148781,
#   ' 30. Errors and Exception Handling | Python Tutorial',
#   'exception handling.json'],
#  [0.8097097088572991, 'Pop dictionary method', 'dictionary.json'],
#  [0.8068063336655277,
#   'Python program to get the Fibonacci series between 0 to 50',
#   'loop-for.json'],
#  [0.8048591084455179,
#   ' Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.802709720038368,
#   'Frequently Asked Python Program 4: Print Fibonacci Series',
#   'loop-for.json'],
#  [0.8003933903767263,
#   'Python Programming - Calculate the Number of Digits and Letters in a String '
#   '- Updated 2021',
#   'loop-for.json'],
#  [0.7935342150142756,
#   'Python Program to Print Sum of n Odd Natural Numbers | 1+3+5+7+..+n Series '
#   'Calculation in Python',
#   'loop-for.json'],
#  [0.7925324427507824, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.7925324427507824, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.7905937878761838, 'Clear dictionary method', 'dictionary.json'],
#  [0.7905937878761838, 'Clear dictionary method', 'dictionary.json'],
#  [0.7894411579570924,
#   ' 8. Exception handling â€” Advance Python Tutorials documentation',
#   'exception handling.json'],
#  [0.7889816512255259,
#   'Itertools in Python 3, By Example',
#   'oops-magic method-itertools.json'],
#  [0.7886563911384561,
#   'Accessing List using for Loop in Python (Hindi)',
#   'loop-for.json'],
#  [0.7780306596031082, 'Define CLasses in Python', 'oops-class.json'],
#  [0.7770541032743669,
#   'Program to Print First 10 Natural Numbers - In Hindi',
#   'loop-while.json'],
#  [0.7736705840583781,
#   'Function arguments in detail - Advanced Python 18 - Programming Tutorial',
#   'function.json'],
#  [0.7726285954056976,
#   'How to Use Python Lambda Functions? 6 Comprehensive Aspects',
#   'function-lambda.json'],
#  [0.7530641934735303, 'Get dictionary method', 'dictionary.json'],
#  [0.7518891922387386,
#   'Hindi Magic/Dunder Methods In Python? | Object Oriented Programming Using '
#   'Python Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.7484803189020921, 'Top 18 Most Useful Python Modules', 'module.json'],
#  [0.7440320257175093,
#   'Python Program to Print First 10 Natural Numbers',
#   'loop-while.json'],
#  [0.7372099863410195,
#   'Python Program to Count Total Odd and Even Numbers in List - In Hindi',
#   'loop-for.json'],
#  [0.733497932952515,
#   'Print the first 10 natural numbers using for loop',
#   'loop-for.json'],
#  [0.7278901095022157,
#   'Python program to display numbers from a list using a for loop.',
#   'loop-for.json'],
#  [0.7106467060884882,
#   'What are Modules in Python and How to Define Modules in Python with '
#   'Examples',
#   'module.json'],
#  [0.6999523859763225,
#   'Itertools in Python3',
#   'oops-magic method-itertools.json'],
#  [0.6998709695243137,
#   "HINDI BIT-PY Beginner's Python Course | Part #36 | Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.6769479057556191,
#   'Lambda Operator, filter, reduce and map',
#   'function-lambda.json'],
#  [0.671623555310723, 'Pass statement', 'condition-pass.json'],
#  [0.671623555310723, 'Pass statement', 'condition-pass.json'],
#  [0.6681760590042113,
#   'Difference Between Iterator VS Generator',
#   'iterator-generator-decorator.json'],
#  [0.6526715041415718,
#   'Python Tutorial: Itertools Module - Iterator Functions for Efficient '
#   'Looping',
#   'oops-magic method-itertools.json'],
#  [0.6495929971612386,
#   'Functions And Docstrings | Python Tutorials For Absolute Beginners In Hindi '
#   '#23',
#   'function.json'],
#  [0.6462442559538754,
#   'Expert Python Tutorial #2 - Dunder/Magic Methods & The Python Data Model',
#   'oops-magic method-itertools.json'],
#  [0.6456817500029658,
#   ' Anonymous/Lambda Functions In Python | Python Tutorials For Absolute Bâ€¦',
#   'function-lambda.json'],
#  [0.6450557998771091,
#   '#3: Python lambda (anonymous) Functions | Python Best Practices',
#   'function-lambda.json'],
#  [0.6449834106290456,
#   '#20 Python Tutorial for Beginners | While Loop in Python',
#   'loop-while.json'],
#  [0.6447185121181706,
#   'Python program that accepts a string and calculates the number of digits '
#   'and letters',
#   'loop-for.json'],
#  [0.6440315906517744,
#   'Python: Lambda, Map, Filter, Reduce Functions',
#   'function-lambda.json'],
#  [0.643152515034049,
#   '#61 Python Tutorial for Beginners | Iterator',
#   'iterator-generator-decorator.json'],
#  [0.641123555943971,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'oops-magic method-itertools.json'],
#  [0.641123555943971,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'function.json'],
#  [0.6396791938966041,
#   'Python Program to Calculate and print sum of Even and Odd integers of first '
#   'Natural n Numbers #15',
#   'loop-while.json'],
#  [0.639296076091538,
#   ' Exception Handling in Python || Syntax Error vs Runtime Error',
#   'exception handling.json'],
#  [0.6384699761151462,
#   'Python program to check the validity of password input by users',
#   'loop-for.json'],
#  [0.6383296260769512,
#   '. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.6383296260769512,
#   ' Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.6381827056296071,
#   'Decorators In Python | Python Tutorials For Absolute Beginners In Hindi #51',
#   'iterator-generator-decorator.json'],
#  [0.6377160780708488,
#   'Python program to display all numbers within a range except the prime '
#   'numbers',
#   'loop-for.json'],
#  [0.6372888217731583,
#   ' Lambda Expressions & Anonymous Functions || Python Tutorial || Learn Pâ€¦',
#   'function-lambda.json'],
#  [0.636781071299072,
#   ' Python Functions Tutorial | Working With Functions In Python | Python '
#   'Training | Eâ€¦',
#   'function.json'],
#  [0.6363533946503934,
#   ' Python Functions | Python Tutorial for Absolute Beginners #1',
#   'function.json'],
#  [0.6353368847587486,
#   'Python Tutorial: Iterators and Iterables - What Are They and How Do They '
#   'Work?',
#   'iterator-generator-decorator.json'],
#  [0.635319160612693,
#   ' Advanced Python Series- Custom Exception Handling In Python',
#   'exception handling.json'],
#  [0.634211276082766,
#   '#42 Python Tutorial for Beginners | Anonymous Functions | Lambda',
#   'function-lambda.json'],
#  [0.6334114451430991,
#   '[Language skills Python] Exercise Lambda Expressions - Advanced [Tutorial]',
#   'function-lambda.json'],
#  [0.6331172386069717,
#   'Python Tutorials - Namespace and Variable Scope',
#   'iterator-generator-decorator.json'],
#  [0.6328657319801614,
#   'Program to find the product of the given number of consecutive elements',
#   'loop-while.json'],
#  [0.6324911735458734,
#   'Functions creating iterators for efficient loopingÂ¶',
#   'oops-magic method-itertools.json'],
#  [0.6324632464753622,
#   'Intermediate Python Tutorial #5 - Lambda Functions',
#   'function-lambda.json'],
#  [0.6323144739862177,
#   'Advance Python Series- Magic Methods',
#   'oops-class.json'],
#  [0.631720676064906,
#   'Lambda Functions in Python | Python Tutorial #37',
#   'function-lambda.json'],
#  [0.6307012608957199,
#   ' Try Except Exception Handling In Python | Python Tutorials For Absolute '
#   'Bâ€¦ ',
#   'exception handling.json'],
#  [0.6303552703157749,
#   'Python Tutorial: Decorators - Dynamically Alter The Functionality Of Your '
#   'Functions',
#   'iterator-generator-decorator.json'],
#  [0.6277431385934273,
#   'Python program to calculate the sum of all the odd numbers within the given '
#   'range',
#   'loop-for.json'],
#  [0.6274801705301364,
#   'Python Itertools Module & Its Iteration Tutorial #38',
#   'oops-magic method-itertools.json'],
#  [0.6258188494223453,
#   'Python Programming Tutorial - Iterators (Part-1)',
#   'iterator-generator-decorator.json'],
#  [0.6254861826065192,
#   '. Python Programming Tutorial | Exception Handling in Python | '
#   'GeeksforGeâ€¦',
#   'exception handling.json'],
#  [0.6251865461917837, 'High order functions in Python', 'function.json'],
#  [0.6251119795207821,
#   '  #63 Python Tutorial for Beginners | Exception Handling',
#   'exception handling.json'],
#  [0.6248038167802618,
#   'Python Iterators | Iterables and Iterators in Python | Python Tutorial for '
#   'Beginners | Edureka',
#   'iterator-generator-decorator.json'],
#  [0.6243896280633123,
#   'Python modules: Exercises, Practice, Solution',
#   'module.json'],
#  [0.6232664080534569,
#   'Python Lambda Function | Anonymous Function In Python | Python Tutorial | '
#   'Edureka',
#   'function-lambda.json'],
#  [0.62247867466201,
#   'Exceptions in Python || Python Tutorial || Learn Python Programming',
#   'exception handling.json'],
#  [0.6224359450135256,
#   'Building Lambda functions with Python',
#   'function-lambda.json'],
#  [0.6208376049279111,
#   'Iterators and Generators',
#   'iterator-generator-decorator.json'],
#  [0.6208376049279111,
#   'Iterators & Generators',
#   'iterator-generator-decorator.json'],
#  [0.6208376049279111,
#   'Generators and Iterators',
#   'iterator-generator-decorator.json'],
#  [0.620661671325896,
#   'Immediate Python- Functions, Modules, Classes and Exceptions',
#   'oops-class.json'],
#  [0.6201277086820683,
#   'Tutorial: Lambda Functions in Python',
#   'function-lambda.json'],
#  [0.6199491712249605,
#   'Python program to check if a string is a palindrome or not',
#   'loop-for.json'],
#  [0.6194859975840455,
#   'Python program to calculate the sum of first N even numbers',
#   'loop-while.json'],
#  [0.619324263930591,
#   'Python Program to Print Multiplication Table of a Number ( User Input )',
#   'loop-for.json'],
#  [0.6193127894384438,
#   ' Advanced Python- Exception Handling Detailed Explanation In Python',
#   'exception handling.json'],
#  [0.619262880405516,
#   'Check the validity of a Password in Python',
#   'loop-for.json'],
#  [0.6186977673226948,
#   "A Guide to Python's Secret Superpower: Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.6185295186922011,
#   'Advanced Functional Programming in Python: lambda',
#   'function-lambda.json'],
#  [0.6182967938833405,
#   'Advanced Python: Itertools Library â€” The Gem Of Python Language',
#   'oops-magic method-itertools.json'],
#  [0.6178396135429388,
#   'Python program to print a multiplication table of a given number',
#   'loop-for.json'],
#  [0.6172117879677455,
#   ' Python Tutorial: Using Try/Except Blocks for Error Handling',
#   'exception handling.json'],
#  [0.6167744442419737,
#   'Python Itertools For Advanced Iteration',
#   'oops-magic method-itertools.json'],
#  [0.6161471573630642, 'Advanced features of Python Functions', 'function.json'],
#  [0.6161471573630642,
#   'Advanced Features in Python Functions | Python Functions Advanced',
#   'function.json'],
#  [0.6159773116111646,
#   'Python program to check if a given number is an Armstrong number',
#   'loop-for.json'],
#  [0.6135274198775053,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.6135274198775053,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.6122572568301633,
#   ' #32 Python Tutorial for Beginners | Functions in Python',
#   'function.json'],
#  [0.6112125667200881,
#   '[Hindi] Iterators, Iterables and Generators in python explained | Advanced '
#   'python tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.6112125667200881,
#   'Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials',
#   'iterator-generator-decorator.json'],
#  [0.6112125667200881,
#   ' Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.6111075719653095,
#   ' finally keyword in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.6101310192581207,
#   '[Hindi] Lambda functions in python in Hindi | Advanced python in Hindi',
#   'function-lambda.json'],
#  [0.6100101972843731,
#   'ANONYMOUS FUNCTIONS (LAMBDA) - PYTHON PROGRAMMING',
#   'function-lambda.json'],
#  [0.6099776898525751,
#   'Advanced Python Series - Iterators Vs Generators',
#   'iterator-generator-decorator.json'],
#  [0.609894987042602,
#   'Advance Python Modules - How to Create & Import with dir Function',
#   'module.json'],
#  [0.6084563148615598,
#   ' Exception Handling in Python | CUET Computer Science',
#   'exception handling.json'],
#  [0.6075964683939374,
#   '#44 Python Tutorial for Beginners | Decorators',
#   'iterator-generator-decorator.json'],
#  [0.6073613789747379,
#   'INTRODUCTION TO EXCEPTION HANDLING IN PYTHON ',
#   'exception handling.json'],
#  [0.6066158537232483,
#   'Python Programming for Intermediate programmer',
#   'oops-class.json'],
#  [0.6063297285602284,
#   'Python program to find all the prime numbers in the given range- by Mahesh '
#   'Huddar',
#   'loop-for.json'],
#  [0.6062988310185077,
#   'Lambda Functions with Practical Examples in Python',
#   'function-lambda.json'],
#  [0.606187968552939,
#   'Python program to print all the even numbers within the given range',
#   'loop-for.json'],
#  [0.6060753055592689,
#   'Python program counts the number of even and odd numbers from a series of '
#   'numbers',
#   'loop-for.json'],
#  [0.6024976742528351,
#   'Python program to find the factorial of a given number',
#   'loop-for.json'],
#  [0.601527883278873,
#   'Modules in Python Explained | Python Built in Modules | Python Tutorial for '
#   'Beginners | Simplilearn',
#   'module.json'],
#  [0.6002499299906803,
#   'Introducing Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.5989380086049866,
#   ' User-defined Exceptions in Python with Examples - GeeksforGeeks',
#   'exception handling.json'],
#  [0.5985155732846522,
#   'Understanding Python: Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.5981798374541121,
#   'Python Program to Print Natural Numbers Using While and For Loop in Hindi - '
#   'Tutorial #22',
#   'loop-for.json'],
#  [0.5967543617701074,
#   'Advanced Python: What Are Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.5951436298996312,
#   'Explore the magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.5950175745751182,
#   'Python Program to check Armstrong Number',
#   'loop-while.json'],
#  [0.5950175745751182,
#   'Python Program to Check Armstrong Number',
#   'loop-while.json'],
#  [0.5950175745751182,
#   'Python Program to Check Armstrong Number',
#   'loop-for.json'],
#  [0.5947165893255089,
#   'Advance Python Series-Magic Methods In Classes',
#   'oops-magic method-itertools.json'],
#  [0.5944492062242133, 'Data model', 'oops-magic method-itertools.json'],
#  [0.593918173507564,
#   ' Professional Error Handling With Python',
#   'exception handling.json'],
#  [0.5937644400150353,
#   'Python Lambda/Anonymous Functions ',
#   'function-lambda.json'],
#  [0.5937430648665593,
#   " Python Functions (The Only Guide You'll Need) #12",
#   'function.json'],
#  [0.5921729684198275,
#   'Python Intermediate: Lambda Functions',
#   'function-lambda.json'],
#  [0.5905869597502819,
#   'Python - Magic or Dunder Methods',
#   'oops-magic method-itertools.json'],
#  [0.5905869597502819,
#   'Dunder or magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.5897192986344538, 'Python Immediate Tutorial #1', 'oops-class.json'],
#  [0.5893485383808363,
#   'Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.5893485383808363,
#   'Python - Magic Methods ',
#   'oops-magic method-itertools.json'],
#  [0.5893327144956234, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.5893327144956234, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.5893327144956234,
#   'Lambda Function in Python - In Hindi',
#   'function-lambda.json'],
#  [0.588397307845181,
#   '#45 Python Tutorial for Beginners | Modules',
#   'module.json'],
#  [0.5875238213879839,
#   'Generators and Iterators in python | python tutorial',
#   'iterator-generator-decorator.json'],
#  [0.5873344879484135,
#   'Exception Handling in Python in Hindi | Python Exception Handling',
#   'exception handling.json'],
#  [0.5873344879484135,
#   'Exception Handling in Python',
#   'exception handling.json'],
#  [0.5873344879484135,
#   ' Python Exception Handling - GeeksforGeeks',
#   'exception handling.json'],
#  [0.5871573850441837,
#   'How to print even numbers in the given range in Python',
#   'loop-for.json'],
#  [0.5871151840699899, 'Python Functions Advanced', 'function.json'],
#  [0.5871151840699899, 'Python Advanced Functions', 'function.json'],
#  [0.5870526554412886,
#   'Lambda Function in Python -     Example Syntax',
#   'function-lambda.json'],
#  [0.5869096902197619, 'Python Modules | Learn Coding', 'module.json'],
#  [0.5867581883987656,
#   'How To Use Functions In Python (Python Tutorial #3)',
#   'function.json'],
#  [0.5865873177718691,
#   'Function Decorator in Python (Hindi)',
#   'iterator-generator-decorator.json'],
#  [0.5865267584338251,
#   "A Guide to Python's Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.5853640666998294, 'Create and Import Python Modules', 'module.json'],
#  [0.5852665608965183,
#   'Python Program to Reverse of a Number - In Hindi',
#   'loop-while.json'],
#  [0.5842706111911495,
#   'Lambda Expressions - Python Tips and Tricks #5',
#   'function-lambda.json'],
#  [0.582957123376599,
#   'Python Intermediate Series: Python Modules',
#   'module.json'],
#  [0.5814705471341834,
#   'Generators In Python | Python Tutorials For Absolute Beginners In Hindi #72',
#   'iterator-generator-decorator.json'],
#  [0.5814298296104923,
#   'Magic Methods in Python, by example | Using Magic Methods In Our Class '
#   'Design',
#   'oops-magic method-itertools.json'],
#  [0.5813485499371961,
#   'Python program to convert the month name to a number of days',
#   'loop-for.json'],
#  [0.5813485499371961,
#   'Python program to convert month name to a number of days',
#   'loop-for.json'],
#  [0.5813186963376288, 'Advanced Python classes', 'oops-class.json'],
#  [0.5794144176588059,
#   'Reverse a Number in Python using While Loop',
#   'loop-while.json'],
#  [0.5786678232454608,
#   'Using Python External & Built In Modules | Python Tutorials For Absolute '
#   'Beginners In Hindi',
#   'module.json'],
#  [0.5781333273509511, 'Python Iterators', 'iterator-generator-decorator.json'],
#  [0.5778786129840733, 'Python While Loops', 'loop-while.json'],
#  [0.5760330020372623,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.5760330020372623,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.5745394532944461, 'Advanced Python for Data Science', 'oops-class.json'],
#  [0.5736925398521567,
#   'Using Modules & Pip In Python | Python Tutorials For Absolute Beginners In '
#   'Hindi #3',
#   'module.json'],
#  [0.5727035955549649,
#   'Python Try Except - GeeksforGeeks',
#   'exception handling.json'],
#  [0.5719837641414196,
#   'Comparison of Iterators and Generators in python',
#   'iterator-generator-decorator.json'],
#  [0.5708885534136136,
#   'What is Modules in Python - Python Tutorials for Beginners',
#   'module.json'],
#  [0.5708885534136136,
#   'What Are Python Modules? | Modules In Python | Python Tutorial For '
#   'Beginners | Edureka',
#   'module.json'],
#  [0.5704304600283198,
#   'How to Use Python Lambda Functions',
#   'function-lambda.json'],
#  [0.5685561826314051, 'Python : Advance built in modules', 'module.json'],
#  [0.5679612488975403,
#   'Python Programs - Factorial Program Using for loop',
#   'loop-for.json'],
#  [0.5667925724072433,
#   'Iterator And Generator In Python | Python Generators And Iterators '
#   'Explained | Python | Simplilearn',
#   'iterator-generator-decorator.json'],
#  [0.5659252408264278, 'Python Classes and Obejcts', 'oops-class.json'],
#  [0.5659252408264278, 'Python Classes', 'oops-class.json'],
#  [0.5652650725962491,
#   ' NZEC error in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.5614479095949672, 'PythonDocs Python Function', 'function.json'],
#  [0.5612069965653974, 'TutorialsPoint Python Functions ', 'function.json'],
#  [0.5612069965653974, 'Python Functions Edureka ', 'function.json'],
#  [0.5612069965653974, 'Python Functions ', 'function.json'],
#  [0.5612069965653974, 'Programiz Python Functions ', 'function.json'],
#  [0.5612069965653974, 'LearnPython Python Functions', 'function.json'],
#  [0.5612069965653974, 'JavaPoint Python Functions ', 'function.json'],
#  [0.5612069965653974, 'GFG Python Functions ', 'function.json'],
#  [0.560853003339524,
#   'Python Itertools | Itertools in Python | Python Tutorial for Beginners | '
#   'Edureka',
#   'oops-magic method-itertools.json'],
#  [0.5602893809644384, 'Python Programming | Classes', 'oops-class.json'],
#  [0.5588245649955402,
#   'Python Generators vs Iterators',
#   'iterator-generator-decorator.json'],
#  [0.5570781858557432,
#   'Python Modules and Packages - An Introduction',
#   'module.json'],
#  [0.5543637165369,
#   'What are Python Iterators and Generators?',
#   'iterator-generator-decorator.json'],
#  [0.5543637165369,
#   'PYTHON ITERATORS AND GENERATORS',
#   'iterator-generator-decorator.json'],
#  [0.5543637165369,
#   'Iterators and Generators in Python',
#   'iterator-generator-decorator.json'],
#  [0.5543637165369,
#   'Generators & Iterators in python',
#   'iterator-generator-decorator.json'],
#  [0.5539318983620404, 'Lambda Functions', 'function-lambda.json'],
#  [0.5502585564046126, 'Immediate Python Programming', 'oops-class.json'],
#  [0.5486043111208918,
#   '#62 Python Tutorial for Beginners | Generators',
#   'iterator-generator-decorator.json'],
#  [0.5486000410888513,
#   'Lambda and filter in Python Examples',
#   'function-lambda.json'],
#  [0.546928736193357, 'Using classes in Python', 'oops-class.json'],
#  [0.5458136029498705, 'Python Lambda Expressions', 'function-lambda.json'],
#  [0.5456111851535497, 'Expert Python Tutorial', 'oops-class.json'],
#  [0.5357313174838755, 'Intermediate Programming with Python', 'module.json'],
#  [0.5325312865666961,
#   "Python's Magical Itertools Module",
#   'oops-magic method-itertools.json'],
#  [0.5322008526521282, 'What is Modular Programming?', 'module.json'],
#  [0.5291208638600247, 'Python Modules Inbuilt', 'module.json'],
#  [0.5291208638600247, 'Python Modules', 'module.json'],
#  [0.5291208638600247, 'Python Modules', 'module.json'],
#  [0.5291208638600247, 'Python - Modules', 'module.json'],
#  [0.5291208638600247, 'Module in Python (Hindi)', 'module.json'],
#  [0.5220874321542189, ' Python Lambda', 'function-lambda.json'],
#  [0.5207927622002486, 'Python programming', 'oops-class.json'],
#  [0.5175583343202492,
#   '@Decorators in Python (Advanced)',
#   'iterator-generator-decorator.json'],
#  [0.5174887609755535, 'Python Decorators', 'iterator-generator-decorator.json'],
#  [0.5174887609755535, 'Python Decorator', 'iterator-generator-decorator.json'],
#  [0.5174887609755535,
#   'Decorators in Python',
#   'iterator-generator-decorator.json'],
#  [0.5136425817542593, 'Magic Methods', 'oops-magic method-itertools.json'],
#  [0.48708150047722903,
#   'Python Itertools javapoint',
#   'oops-magic method-itertools.json'],
#  [0.48708150047722903,
#   'Python Itertools gfg',
#   'oops-magic method-itertools.json'],
#  [0.478553562879841, 'Python Generators', 'iterator-generator-decorator.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json']]

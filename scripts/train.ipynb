# %%
import json
from pathlib import Path
import gensim
from gensim.models import Word2Vec

from stopstem import *
import os
 

path = "C://Users//ganes//Desktop//mini//reference"
dir_list = os.listdir(path)
#print(dir_list)
matrix=[]
for i in dir_list:
    with open("../reference/"+i,'r') as data_source:
        try:
            data1 = data_source.read()
            stemmed = tokenizeAndStem(data1)
            matrix.append(stemmed)
        except:
            print(i)
        
#print(matrix)
model1 = Word2Vec(matrix, min_count = 1, window = 5, sg=1,epochs = 20,vector_size=100)
# Out:
# 3.11.txt
# 3.2.txt
# 3.4.txt
# 3.5.txt
# 3.6.txt
# 3.7.txt
# 3.8.txt
# 3.9.txt
# changelog.txt
# decimal.txt
# instrumentation.txt
# logging-cookbook.txt
# math.txt
# nntplib.txt
# random.txt
# stable.txt
# unicode.txt

# %%
from cosines import cacCosine

print(model1.wv)
def sim(q1,q2):
    a1 = q1.split()
    import numpy as np
    v1 = np.array([0.0]*100)
    v2 = np.array([0.0]*100)
    c1=1
    for i in a1:
        try:
            v1+=model1.wv[i]
            c1+=1
        except:
            pass
    v1/=c1
    a2 = q2.split()
    c2=1
    for i in a2:
        try:
            v2+=model1.wv[i]
            c2+=1
        except:
            pass
    v2/=c2
    return cacCosine(list(v1),list(v2))
import os
BASE_DIR = Path(os.getcwd()).resolve().parent

def findSimilar(listOfDocs,query):
    #dic={stemmdtitle:[title,link,file]}
    dic={}
    maxi=[]
    for i in listOfDocs:
        if i[-4::]=='json':
            with open(BASE_DIR/('jsons/'+i)) as f:
                data=json.load(f)
                for j in data:
                    for k in data[j]['videos'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['videos'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
                    for k in data[j]['reading'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['reading'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
    return dic,maxi
# Out:
# <gensim.models.keyedvectors.KeyedVectors object at 0x0000029185BE6130>

# %%
from pprint import pprint as p
l = os.listdir("C://Users//ganes//Desktop//mini//jsons")
q1 = "Python Program to Print Natural Numbers Using While and For Loop in Hindi - Tutorial #22"
q2 = "Print the first 10 natural numbers using for loop"
dic,maxi = findSimilar(l,"tuple in python")
p(sorted(maxi,reverse=True))
# Out:
# [[0.9407264123443966, 'LearnPython Python Functions', 'function.json'],
#  [0.9406222826008889,
#   ' NZEC error in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.9397399947299152, 'Python Functions Edureka ', 'function.json'],
#  [0.9355488191458292, 'JavaPoint Python Functions ', 'function.json'],
#  [0.932744807620615, 'Programiz Python Functions ', 'function.json'],
#  [0.930032345513361, 'Python Functions ', 'function.json'],
#  [0.9270762898113609, 'GFG Python Functions ', 'function.json'],
#  [0.9266688301362161, 'Immediate Python Programming', 'oops-class.json'],
#  [0.9224152270809748, 'PythonDocs Python Function', 'function.json'],
#  [0.9221900286740521,
#   'Function Decorator in Python (Hindi)',
#   'iterator-generator-decorator.json'],
#  [0.9186195138032611, 'TutorialsPoint Python Functions ', 'function.json'],
#  [0.9114588268153974,
#   'Python Tutorial: Decorators - Dynamically Alter The Functionality Of Your '
#   'Functions',
#   'iterator-generator-decorator.json'],
#  [0.9053182229671431, 'Python Functions Advanced', 'function.json'],
#  [0.9053182229671431, 'Python Advanced Functions', 'function.json'],
#  [0.9038670454908827, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.9038670454908827, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.8990833980762009, 'Variables in string', 'string.json'],
#  [0.8990833980762009, 'Variables in string', 'string.json'],
#  [0.8982580012615283, 'Python Conditions', 'condition-pass.json'],
#  [0.8982580012615283, 'Python Condition', 'condition-pass.json'],
#  [0.8980107381053754,
#   'Python Lambda/Anonymous Functions ',
#   'function-lambda.json'],
#  [0.8978532965432011,
#   'Lambda Function in Python - In Hindi',
#   'function-lambda.json'],
#  [0.8891517457561756,
#   ' Python Functions | Python Tutorial for Absolute Beginners #1',
#   'function.json'],
#  [0.8863012680908376,
#   'Python Intermediate: Lambda Functions',
#   'function-lambda.json'],
#  [0.8829774434924123, 'Python Decorators', 'iterator-generator-decorator.json'],
#  [0.8829774434924123, 'Python Decorator', 'iterator-generator-decorator.json'],
#  [0.8829774434924123,
#   'Decorators in Python',
#   'iterator-generator-decorator.json'],
#  [0.8818670375488644,
#   'Python Programming for Intermediate programmer',
#   'oops-class.json'],
#  [0.8780714291156514,
#   'ANONYMOUS FUNCTIONS (LAMBDA) - PYTHON PROGRAMMING',
#   'function-lambda.json'],
#  [0.8773774871289202,
#   'Python program to check if a string is a palindrome or not',
#   'loop-for.json'],
#  [0.8770594736845012,
#   'Python Itertools gfg',
#   'oops-magic method-itertools.json'],
#  [0.8749931510073811,
#   'Python Itertools javapoint',
#   'oops-magic method-itertools.json'],
#  [0.873212138852868,
#   'Immediate Python- Functions, Modules, Classes and Exceptions',
#   'oops-class.json'],
#  [0.8720811851119025,
#   '[Hindi] Lambda functions in python in Hindi | Advanced python in Hindi',
#   'function-lambda.json'],
#  [0.87069431706749,
#   'Decorators In Python | Python Tutorials For Absolute Beginners In Hindi #51',
#   'iterator-generator-decorator.json'],
#  [0.8706055168555743,
#   'Python Tutorial: Itertools Module - Iterator Functions for Efficient '
#   'Looping',
#   'oops-magic method-itertools.json'],
#  [0.8679703677175675,
#   'Functions And Docstrings | Python Tutorials For Absolute Beginners In Hindi '
#   '#23',
#   'function.json'],
#  [0.866538541897302, 'Reversing a string in python', 'string.json'],
#  [0.866538541897302, ' Reversing a string in python', 'string.json'],
#  [0.8654904273339177, 'String slicing in python', 'string.json'],
#  [0.8654904273339177, ' String slicing in python', 'string.json'],
#  [0.8629120644012007,
#   'Advanced Functional Programming in Python: lambda',
#   'function-lambda.json'],
#  [0.8621933582015913, 'Advanced features of Python Functions', 'function.json'],
#  [0.8621933582015913,
#   'Advanced Features in Python Functions | Python Functions Advanced',
#   'function.json'],
#  [0.8594452087434244, 'High order functions in Python', 'function.json'],
#  [0.8584622451194744,
#   ' #32 Python Tutorial for Beginners | Functions in Python',
#   'function.json'],
#  [0.8574345865366332,
#   'Building Lambda functions with Python',
#   'function-lambda.json'],
#  [0.8534640192449756,
#   ' Anonymous/Lambda Functions In Python | Python Tutorials For Absolute Bâ€¦',
#   'function-lambda.json'],
#  [0.8435379717768259,
#   'Tutorial: Lambda Functions in Python',
#   'function-lambda.json'],
#  [0.8391384051586724,
#   'Python Lambda Function | Anonymous Function In Python | Python Tutorial | '
#   'Edureka',
#   'function-lambda.json'],
#  [0.8387975559653057,
#   ' finally keyword in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.835778587762213,
#   'Python program to get the Fibonacci series between 0 to 50',
#   'loop-for.json'],
#  [0.8352783262109664,
#   'How to Use Python Lambda Functions',
#   'function-lambda.json'],
#  [0.8291113491041445,
#   'Python Programming Tutorial - Iterators (Part-1)',
#   'iterator-generator-decorator.json'],
#  [0.8280598461210862,
#   'Lambda Expressions - Python Tips and Tricks #5',
#   'function-lambda.json'],
#  [0.8260200104011458,
#   'Check the validity of a Password in Python',
#   'loop-for.json'],
#  [0.8256037344350846, ' Python Tutorials for Beginners', 'array.json'],
#  [0.8250227609762528,
#   '#42 Python Tutorial for Beginners | Anonymous Functions | Lambda',
#   'function-lambda.json'],
#  [0.8239365405945971,
#   '#44 Python Tutorial for Beginners | Decorators',
#   'iterator-generator-decorator.json'],
#  [0.8229187095508446,
#   ' Professional Error Handling With Python',
#   'exception handling.json'],
#  [0.822328178544849,
#   ' Python Functions Tutorial | Working With Functions In Python | Python '
#   'Training | Eâ€¦',
#   'function.json'],
#  [0.8217847675431954,
#   'Generators In Python | Python Tutorials For Absolute Beginners In Hindi #72',
#   'iterator-generator-decorator.json'],
#  [0.8181488600503354,
#   'Lambda Functions in Python | Python Tutorial #37',
#   'function-lambda.json'],
#  [0.8160550640095161,
#   'Lambda Functions - Advanced Python 08',
#   'function-lambda.json'],
#  [0.813509048594537, ' Python Lambda', 'function-lambda.json'],
#  [0.8103858676308733,
#   'Python Program to Check Armstrong Number',
#   'loop-for.json'],
#  [0.8088971764516933,
#   'Python Programming - Calculate the Number of Digits and Letters in a String '
#   '- Updated 2021',
#   'loop-for.json'],
#  [0.8064396983884186,
#   'Lambda Function in Python -     Example Syntax',
#   'function-lambda.json'],
#  [0.8061619257476885,
#   'Intermediate Python Tutorial #5 - Lambda Functions',
#   'function-lambda.json'],
#  [0.8037481373963953,
#   'Python program to check if a given number is an Armstrong number',
#   'loop-for.json'],
#  [0.8036993165320384,
#   " Python Functions (The Only Guide You'll Need) #12",
#   'function.json'],
#  [0.8027746261816311,
#   'Frequently Asked Python Program 20:Check String is Palindrome or Not',
#   'loop-for.json'],
#  [0.8017364580751583,
#   'How To Use Functions In Python (Python Tutorial #3)',
#   'function.json'],
#  [0.799590016440684,
#   '@Decorators in Python (Advanced)',
#   'iterator-generator-decorator.json'],
#  [0.799146373622912,
#   ' Lambda Expressions & Anonymous Functions || Python Tutorial || Learn Pâ€¦',
#   'function-lambda.json'],
#  [0.7947925144722452,
#   'Python: Lambda, Map, Filter, Reduce Functions',
#   'function-lambda.json'],
#  [0.7944988123830952,
#   'Comparison of Iterators and Generators in python',
#   'iterator-generator-decorator.json'],
#  [0.7924788081839161,
#   '#3: Python lambda (anonymous) Functions | Python Best Practices',
#   'function-lambda.json'],
#  [0.7914022814970572, 'Get dictionary method', 'dictionary.json'],
#  [0.7914022814970572, 'Get dictionary method', 'dictionary.json'],
#  [0.7885881304710268, 'How to add an item to a list in Python', 'list.json'],
#  [0.7875659731299643,
#   'Function arguments in detail - Advanced Python 18 - Programming Tutorial',
#   'function.json'],
#  [0.7873033143812215, '#27 Python Tutorial for Beginners', 'array.json'],
#  [0.7858916904241721, 'Python Iterators', 'iterator-generator-decorator.json'],
#  [0.78447636375603,
#   'Python Tutorials - Namespace and Variable Scope',
#   'iterator-generator-decorator.json'],
#  [0.7840515847468716,
#   'Lambda Functions with Practical Examples in Python',
#   'function-lambda.json'],
#  [0.7836649759374319,
#   'How to Change/Replace/Update List Items ? | List tutorial in python',
#   'list.json'],
#  [0.7824947712188258,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.7824947712188258,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.7816171291069647, 'Arrays in python| Python for beginners', 'array.json'],
#  [0.7812941818094704,
#   'Python Iterators | Iterables and Iterators in Python | Python Tutorial for '
#   'Beginners | Edureka',
#   'iterator-generator-decorator.json'],
#  [0.7809607870631977, 'Arrays in Python Programming', 'array.json'],
#  [0.7804350584303792,
#   'Python Try Except - GeeksforGeeks',
#   'exception handling.json'],
#  [0.7797227568738208,
#   'Python 3 Programming Tutorial | #1 Introduction of Python Lambda and '
#   'Anonymous Function',
#   'function-lambda.json'],
#  [0.7789276620187644,
#   'Decorators in Python - Advanced Python 13 - Programming Tutorial',
#   'iterator-generator-decorator.json'],
#  [0.7763491022076466, 'Arrays in python: Array Advance Game', 'array.json'],
#  [0.776145234284062,
#   'How to Use Python Lambda Functions? 6 Comprehensive Aspects',
#   'function-lambda.json'],
#  [0.7743551473842943,
#   '#61 Python Tutorial for Beginners | Iterator',
#   'iterator-generator-decorator.json'],
#  [0.7671711639095465, 'Python Lambda Expressions', 'function-lambda.json'],
#  [0.7654414876116225,
#   'Python Program to Count Total Odd and Even Numbers in List - In Hindi',
#   'loop-for.json'],
#  [0.7648183627495779,
#   'Exceptions in Python || Python Tutorial || Learn Python Programming',
#   'exception handling.json'],
#  [0.7641112549452008,
#   'Python program counts the number of even and odd numbers from a series of '
#   'numbers',
#   'loop-for.json'],
#  [0.7612281824422698,
#   ' Python Exception Handling - GeeksforGeeks',
#   'exception handling.json'],
#  [0.7575448729490923,
#   'Python program to find all the prime numbers in the given range- by Mahesh '
#   'Huddar',
#   'loop-for.json'],
#  [0.756196374334573,
#   'Python Tutorial: Iterators and Iterables - What Are They and How Do They '
#   'Work?',
#   'iterator-generator-decorator.json'],
#  [0.7554662467329599,
#   ' Advanced Python Series- Custom Exception Handling In Python',
#   'exception handling.json'],
#  [0.755279265872194, 'Python Generators', 'iterator-generator-decorator.json'],
#  [0.7548089566420887,
#   ' Try Except Exception Handling In Python | Python Tutorials For Absolute '
#   'Bâ€¦ ',
#   'exception handling.json'],
#  [0.7531550422649995,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'function.json'],
#  [0.7526082406993707, 'Lambda Functions', 'function-lambda.json'],
#  [0.745636981330749,
#   'Generators and Iterators in python | python tutorial',
#   'iterator-generator-decorator.json'],
#  [0.7447876261448608,
#   'Python Program to Print Sum of n Odd Natural Numbers | 1+3+5+7+..+n Series '
#   'Calculation in Python',
#   'loop-for.json'],
#  [0.7439738116812928,
#   'Python program to calculate the sum of all the odd numbers within the given '
#   'range',
#   'loop-for.json'],
#  [0.7374901705664922,
#   'Python program to print a multiplication table of a given number',
#   'loop-for.json'],
#  [0.736820697881128,
#   'Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials',
#   'iterator-generator-decorator.json'],
#  [0.7368032166425837, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.7368032166425837, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.7348393333036269,
#   '#62 Python Tutorial for Beginners | Generators',
#   'iterator-generator-decorator.json'],
#  [0.7340522865901756,
#   'What are Python Iterators and Generators?',
#   'iterator-generator-decorator.json'],
#  [0.7340522865901756,
#   'PYTHON ITERATORS AND GENERATORS',
#   'iterator-generator-decorator.json'],
#  [0.7340522865901756,
#   'Iterators and Generators in Python',
#   'iterator-generator-decorator.json'],
#  [0.7340522865901756,
#   'Generators & Iterators in python',
#   'iterator-generator-decorator.json'],
#  [0.7339155704649398,
#   'Python program to display all numbers within a range except the prime '
#   'numbers',
#   'loop-for.json'],
#  [0.7289717114126679,
#   ' Exception Handling in Python || Syntax Error vs Runtime Error',
#   'exception handling.json'],
#  [0.7286095432641087,
#   '[Hindi] Iterators, Iterables and Generators in python explained | Advanced '
#   'python tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.7286095432641087,
#   ' Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.7280269288840306,
#   'Python Programs - Factorial Program Using for loop',
#   'loop-for.json'],
#  [0.7269646036223192, 'Stock buy and sell Problem', 'array.json'],
#  [0.7266368344995519,
#   'Advanced Python Series - Iterators Vs Generators',
#   'iterator-generator-decorator.json'],
#  [0.7243070535132161,
#   'Iterator And Generator In Python | Python Generators And Iterators '
#   'Explained | Python | Simplilearn',
#   'iterator-generator-decorator.json'],
#  [0.7242407706388505,
#   ' Exception Handling in Python | CUET Computer Science',
#   'exception handling.json'],
#  [0.7200970613895096,
#   'Exception Handling in Python',
#   'exception handling.json'],
#  [0.7200570535671568,
#   ' 30. Errors and Exception Handling | Python Tutorial',
#   'exception handling.json'],
#  [0.7196475332965125,
#   'Python Generators vs Iterators',
#   'iterator-generator-decorator.json'],
#  [0.7136869073688961,
#   'How to print even numbers in the given range in Python',
#   'loop-for.json'],
#  [0.7132209835751854,
#   'Python Program to Print Multiplication Table of a Number ( User Input )',
#   'loop-for.json'],
#  [0.7122394693617096,
#   'Python program to print all the even numbers within the given range',
#   'loop-for.json'],
#  [0.7111204758329218,
#   'Python program to convert month name to a number of days',
#   'loop-for.json'],
#  [0.7084757744517319,
#   '  #63 Python Tutorial for Beginners | Exception Handling',
#   'exception handling.json'],
#  [0.7076924880551725,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.7076924880551725,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.705281245404008,
#   'Python Lambda | Advanced Python | Tutorial 18',
#   'function-lambda.json'],
#  [0.702928668292403,
#   '[Language skills Python] Exercise Lambda Expressions - Advanced [Tutorial]',
#   'function-lambda.json'],
#  [0.7020423398175653,
#   'Lambda Expression : Python tutorial 150',
#   'function-lambda.json'],
#  [0.7012446455982234,
#   'Accessing List using for Loop in Python (Hindi)',
#   'loop-for.json'],
#  [0.6993339110304293,
#   ' Exceptions in Python - Advanced Python 09 - Programming Tutorial',
#   'exception handling.json'],
#  [0.6978983445753117,
#   '. Python Programming Tutorial | Exception Handling in Python | '
#   'GeeksforGeâ€¦',
#   'exception handling.json'],
#  [0.6966080257469177,
#   'Lambda and filter in Python Examples',
#   'function-lambda.json'],
#  [0.6958640987076157,
#   ' Exception handling tips in Python âš\xa0 Write better Python code part 7',
#   'exception handling.json'],
#  [0.6951863048878337, ' Copy dictionary method', 'dictionary.json'],
#  [0.6951863048878337, ' Copy dictionary method', 'dictionary.json'],
#  [0.6942264120941561,
#   'Python program to display numbers from a list using a for loop.',
#   'loop-for.json'],
#  [0.6928016547733591,
#   'Find missing number in an array in python',
#   'array.json'],
#  [0.6924190306181972, 'Clear dictionary method', 'dictionary.json'],
#  [0.6924190306181972, 'Clear dictionary method', 'dictionary.json'],
#  [0.6909286481812529,
#   'Exception Handling in Python in Hindi | Python Exception Handling',
#   'exception handling.json'],
#  [0.69082309852015,
#   'Python Program to Print Natural Numbers Using While and For Loop in Hindi - '
#   'Tutorial #22',
#   'loop-for.json'],
#  [0.6896359959313099, 'Change list items', 'list.json'],
#  [0.6857434321724812,
#   'Lambda in Python - Advanced Python 08 - Programming Tutorial - Map Filter '
#   'Reduce',
#   'function-lambda.json'],
#  [0.685486321284019,
#   ' Python Tutorial: Using Try/Except Blocks for Error Handling',
#   'exception handling.json'],
#  [0.6813961122008755,
#   'Frequently Asked Python Program 4: Print Fibonacci Series',
#   'loop-for.json'],
#  [0.6718689571815782,
#   ' Advanced Python- Exception Handling Detailed Explanation In Python',
#   'exception handling.json'],
#  [0.670967587411991,
#   ' 8. Exception handling â€” Advance Python Tutorials documentation',
#   'exception handling.json'],
#  [0.6680397804746538, ' Max sum path in two arrays', 'array.json'],
#  [0.6668466874226767,
#   ' User-defined Exceptions in Python with Examples - GeeksforGeeks',
#   'exception handling.json'],
#  [0.6630390839486966,
#   'INTRODUCTION TO EXCEPTION HANDLING IN PYTHON ',
#   'exception handling.json'],
#  [0.6593686565533347, ' Update dictionary method', 'dictionary.json'],
#  [0.6593686565533347, ' Update dictionary method', 'dictionary.json'],
#  [0.6571225424804544, 'Count pairs with given sum', 'array.json'],
#  [0.652612919473954,
#   '. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.652612919473954,
#   ' Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.6504688797805402, 'List methods', 'list.json'],
#  [0.6504688797805402, 'List methods', 'list.json'],
#  [0.650388281330689, 'Pop dictionary method', 'dictionary.json'],
#  [0.650388281330689, 'Pop dictionary method', 'dictionary.json'],
#  [0.6401421916603959, 'Nested if condition', 'condition-pass.json'],
#  [0.6373637342689608,
#   'Python Programming 19 - Remove Elements From List within for Loop',
#   'list.json'],
#  [0.632776238836869,
#   '4. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.6293436357528055,
#   '6. INTRODUCTION TO EXCEPTION HANDLING IN PYTHON',
#   'exception handling.json'],
#  [0.6182467904623418, ' Add list items', 'list.json'],
#  [0.6134362394696037, 'Elif statement', 'condition-pass.json'],
#  [0.6134362394696037, 'Elif statement', 'condition-pass.json'],
#  [0.6072107550089916, ' Access list items', 'list.json'],
#  [0.6059261662166551,
#   'Difference Between Iterator VS Generator',
#   'iterator-generator-decorator.json'],
#  [0.5912752819640911, 'Checking for membership in lists', 'list.json'],
#  [0.5912752819640911, ' Checking for membership in lists', 'list.json'],
#  [0.5814287474432045, 'Pass statement', 'condition-pass.json'],
#  [0.5814287474432045, 'Pass statement', 'condition-pass.json'],
#  [0.5814287474432045, 'Pass statement', 'condition-pass.json'],
#  [0.5814287474432045, 'Pass statement', 'condition-pass.json'],
#  [0.5751973964630652,
#   'Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.5751973964630652,
#   ' Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.570526158213115, 'Find missing and repeating', 'array.json'],
#  [0.5629394339377491, 'Write a program to sort the given array', 'array.json'],
#  [0.5581450620138069, 'Subarray with given sum', 'array.json'],
#  [0.5423332673121487,
#   ' Accessing elements of a nested dictionary',
#   'dictionary.json'],
#  [0.5423332673121487,
#   ' Accessing elements of a nested Dictionary',
#   'dictionary.json'],
#  [0.5415695338085785, 'Find missing number', 'array.json'],
#  [0.540526618073385, 'Copy lists', 'list.json'],
#  [0.540526618073385, 'Copy list', 'list.json'],
#  [0.5346826109712696,
#   'Pair with the given sum in a sorted array',
#   'array.json'],
#  [0.5328937466785011,
#   'Write a program to cyclically rotate an array by one| Love Babbar DSA Sheet',
#   'array.json'],
#  [0.5264246650896274, 'Merge two dictionaries', 'dictionary.json'],
#  [0.5264246650896274, 'Merge two dictionaries', 'dictionary.json'],
#  [0.5260625934675206, 'Shorthand statement', 'condition-pass.json'],
#  [0.5260625934675206, 'Shorthand if statement', 'condition-pass.json'],
#  [0.5237760924992203,
#   'Lambda Operator, filter, reduce and map',
#   'function-lambda.json'],
#  [0.516725297046386, 'Write a program to reverse an array', 'array.json'],
#  [0.5107098681241726,
#   'Print the first 10 natural numbers using for loop',
#   'loop-for.json'],
#  [0.5094018243273529, 'Nested if Condtion', 'condition-pass.json'],
#  [0.5038854672123189,
#   'Write a program to cyclically rotate an array by one',
#   'array.json'],
#  [0.4972822310562251, 'Introduction to if else', 'condition-pass.json'],
#  [0.4972822310562251, 'Introduction to if else', 'condition-pass.json'],
#  [0.49638663648255277, 'What Are Access Lists? ', 'list.json'],
#  [0.4899486300516849, ' exceptions.Exception', 'exception handling.json'],
#  [0.48981921598789196, 'Accessing elements of a dictionary', 'dictionary.json'],
#  [0.48981921598789196,
#   '. Accessing elements of a dictionary',
#   'dictionary.json'],
#  [0.4881197920302442, 'Find duplicates in an array', 'array.json'],
#  [0.48468093889718156, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.48468093889718156, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.47533440975469887, 'List comprehension', 'list.json'],
#  [0.47533440975469887, ' List comprehension', 'list.json'],
#  [0.4751182624237396, 'Nested Dictionaries', 'dictionary.json'],
#  [0.4751182624237396, ' Nested Dictionaries', 'dictionary.json'],
#  [0.46700541526830525,
#   'Iterators and Generators',
#   'iterator-generator-decorator.json'],
#  [0.46700541526830525,
#   'Iterators & Generators',
#   'iterator-generator-decorator.json'],
#  [0.46700541526830525,
#   'Generators and Iterators',
#   'iterator-generator-decorator.json'],
#  [0.45558219576857634,
#   'Advanced indexing Operations in Numpy Arrays',
#   'array.json'],
#  [0.4489109439449257,
#   'Find the minimum and maximum element in an array',
#   'array.json'],
#  [0.4470556786702475,
#   ' Day 24: Advanced Exception Handling and Raising Exceptions',
#   'exception handling.json'],
#  [0.4465093878188648, 'Sort an array using Quicksort Algorithm', 'array.json'],
#  [0.4454076547710531, ' Remove list items', 'list.json'],
#  [0.41044893022396894,
#   'Creating One Dimensional Array using Numpy',
#   'array.json'],
#  [0.40922967684127703, 'Maximum Index', 'array.json'],
#  [0.4062340643969779, 'Indentation', 'condition-pass.json'],
#  [0.4062340643969779, 'Indentation', 'condition-pass.json'],
#  [0.4032665351206579, 'Loop lists', 'list.json'],
#  [0.4032665351206579, ' Loop lists', 'list.json'],
#  [0.3996217948484469, '384 Shuffle an array', 'array.json'],
#  [0.3887722325347497, 'Peak Element', 'array.json'],
#  [0.38755537115109157, 'Filtering the lists', 'list.json'],
#  [0.38755537115109157, ' Filtering the lists', 'list.json'],
#  [0.38363866177978573, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.38363866177978573, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.3555184852554394, 'Reversing lists', 'list.json'],
#  [0.3555184852554394, ' Reversing the lists', 'list.json'],
#  [0.3540832549584261, 'Join lists', 'list.json'],
#  [0.3540832549584261, 'Join Lists', 'list.json'],
#  [0.34915914178031393, 'Sort lists', 'list.json'],
#  [0.34915914178031393, ' Sort list', 'list.json'],
#  [0.331597824114834, 'Creating a dictionary-', 'dictionary.json'],
#  [0.331597824114834, 'Creating a dictionary', 'dictionary.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'tree.json'],
#  [0.8649445449844869, 'Tuple methods', 'tuple.json'],
#  [0.8649445449844869, 'Tuple methods', 'tuple.json'],
#  [0.8600291619243805,
#   'Python | Method Overloading',
#   'oops-operator-overloading.json'],
#  [0.8535588478454843, 'Python Immediate Tutorial #1', 'oops-class.json'],
#  [0.848773981240349,
#   'Difference between Method Overloading and Method Overriding in Python',
#   'oops-operator-overloading.json'],
#  [0.8473050428192769, 'Iterating through a tuple', 'tuple.json'],
#  [0.8473050428192769, 'Iterating through a tuple', 'tuple.json'],
#  [0.8455205405842752, 'Python Classes and Obejcts', 'oops-class.json'],
#  [0.8439030329136621, 'Python Modules | Learn Coding', 'module.json'],
#  [0.8432051322603376,
#   'Explore the magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.8424245784648335, 'Python programming', 'oops-class.json'],
#  [0.8422733916029228, 'Python Regex', 'regularexpression.json'],
#  [0.8422733916029228, 'Python RegEx', 'regularexpression.json'],
#  [0.8422733916029228, 'Python RegEx', 'regularexpression.json'],
#  [0.8372729833156792, 'Changing a tuple', 'tuple.json'],
#  [0.8372729833156792, 'Changing a tuple', 'tuple.json'],
#  [0.8369770382993559,
#   'Python program that accepts a string and calculates the number of digits '
#   'and letters',
#   'loop-for.json'],
#  [0.8340994077552245,
#   'Operator Overloading & Dunder Methods | Python Tutorials For Absolute '
#   'Beginners',
#   'oops-operator-overloading.json'],
#  [0.8329799737159259,
#   'Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.8329799737159259,
#   'Python - Magic Methods ',
#   'oops-magic method-itertools.json'],
#  [0.8293737059513093,
#   'Regular Expressions | Python Tutorials For Absolute Beginners',
#   'regularexpression.json'],
#  [0.8286998792643273,
#   'Python Program for Series Calculation 1*1 + 2*2 + 3*3 +..+n | Series '
#   'Calculation Program in Python',
#   'loop-while.json'],
#  [0.826614011640078, ' Multiline strings', 'string.json'],
#  [0.826614011640078, ' Multiline strings', 'string.json'],
#  [0.8252770400724109,
#   '5 Advanced Functions in Itertools To Simplify Iterations in Python',
#   'oops-magic method-itertools.json'],
#  [0.8236242142227925, 'Built-in functions for tuple', 'tuple.json'],
#  [0.8236242142227925, 'Built-in functions for tuple', 'tuple.json'],
#  [0.8213025926085928,
#   'Python Itertools | Itertools in Python | Python Tutorial for Beginners | '
#   'Edureka',
#   'oops-magic method-itertools.json'],
#  [0.8208651342114601,
#   'Python Itertools For Advanced Iteration',
#   'oops-magic method-itertools.json'],
#  [0.8133867536482813,
#   'Regular Expressions in Python - FULL COURSE (1 HOUR) - Programming Tutorial',
#   'regularexpression.json'],
#  [0.8133200039219767,
#   'Python - Magic or Dunder Methods',
#   'oops-magic method-itertools.json'],
#  [0.8133200039219767,
#   'Dunder or magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.8129757037214098,
#   'Advance Python Series-Magic Methods In Classes',
#   'oops-magic method-itertools.json'],
#  [0.8103858676308733,
#   'Python Program to check Armstrong Number',
#   'loop-while.json'],
#  [0.8103858676308733,
#   'Python Program to Check Armstrong Number',
#   'loop-while.json'],
#  [0.8073149202515665, 'Creating string in python', 'string.json'],
#  [0.8051631276291625,
#   'Advanced Python: What Are Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.8044256641335314,
#   'Using Python External & Built In Modules | Python Tutorials For Absolute '
#   'Beginners In Hindi',
#   'module.json'],
#  [0.8040583324587841,
#   'Operator Overloading & Dunder Methods | Python Tutorials For Absolute '
#   'Beginners In Hindi #67',
#   'oops-operator-overloading.json'],
#  [0.804053746140923, 'Intermediate Programming with Python', 'module.json'],
#  [0.8021522785680533,
#   'Understanding Python: Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.7992870409753939, 'Expert Python Tutorial', 'oops-class.json'],
#  [0.79618364231245,
#   'Python Itertools Module & Its Iteration Tutorial #38',
#   'oops-magic method-itertools.json'],
#  [0.7955406843270476, 'Formatting of strings', 'string.json'],
#  [0.7955406843270476, 'Formatting of strings', 'string.json'],
#  [0.7954057546416539, 'Accessing characters in python string', 'string.json'],
#  [0.7941151831693752, 'Module in Python (Hindi)', 'module.json'],
#  [0.7940697650806728,
#   'Beginner Python Tutorial 17 - Creating a String',
#   'string.json'],
#  [0.7938767464968497,
#   '#60 Python Tutorial for Beginners | Method Overloading and Method '
#   'Overriding',
#   'oops-operator-overloading.json'],
#  [0.7932954601413236, 'Python While Loops', 'loop-while.json'],
#  [0.7928162906590843,
#   'OVERLOADING (POLYMORPHISM) - PYTHON PROGRAMMING',
#   'oops-operator-overloading.json'],
#  [0.7923164023003726, 'Python Modules Inbuilt', 'module.json'],
#  [0.7915969887275045, 'Python Classes', 'oops-class.json'],
#  [0.7914987211857906,
#   'Modules in Python Explained | Python Built in Modules | Python Tutorial for '
#   'Beginners | Simplilearn',
#   'module.json'],
#  [0.7901736806302334,
#   'Itertools - Advanced Python 07',
#   'oops-magic method-itertools.json'],
#  [0.7885725644624725, 'Python Programming | Classes', 'oops-class.json'],
#  [0.7875244864247612,
#   'What is Modules in Python - Python Tutorials for Beginners',
#   'module.json'],
#  [0.7842902237182541, 'Python Modules', 'module.json'],
#  [0.7842902237182541, 'Python Modules', 'module.json'],
#  [0.7842902237182541, 'Python - Modules', 'module.json'],
#  [0.7839500278318852,
#   'Itertools in Python - Advanced Python 07 - Programming Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.7833086632980969,
#   'Python program to check the validity of password input by users',
#   'loop-for.json'],
#  [0.7820262021012302,
#   'Introducing Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.7816747715236738,
#   'Using Modules & Pip In Python | Python Tutorials For Absolute Beginners In '
#   'Hindi #3',
#   'module.json'],
#  [0.776815908622199,
#   "HINDI BIT-PY Beginner's Python Course | Part #36 | Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.7761978108517953, 'Python : Advance built in modules', 'module.json'],
#  [0.775971347313494, 'String Introduction', 'string.json'],
#  [0.775971347313494, 'Introduction to strings', 'string.json'],
#  [0.7746213479999513,
#   'Python program to calculate the sum of first N even numbers',
#   'loop-while.json'],
#  [0.7739056031897386,
#   'What Are Python Modules? | Modules In Python | Python Tutorial For '
#   'Beginners | Edureka',
#   'module.json'],
#  [0.7734308664169582,
#   '#45 Python Tutorial for Beginners | Modules',
#   'module.json'],
#  [0.7723478129138852,
#   'Advance Python Series- Magic Methods',
#   'oops-class.json'],
#  [0.7700385900603757, 'Python Operators', 'oops-operator-overloading.json'],
#  [0.7683048855239036,
#   'Python Program to Reverse of a Number - In Hindi',
#   'loop-while.json'],
#  [0.7602285357287392,
#   'Python Intermediate Series: Python Modules',
#   'module.json'],
#  [0.7576103482834634, 'Python Objects and Classes', 'oops-class.json'],
#  [0.7576103482834634, 'Python Classes and Objects', 'oops-class.json'],
#  [0.7576103482834634, 'Python Classes & Objects', 'oops-class.json'],
#  [0.7576103482834634, 'Classes and Objects in python', 'oops-class.json'],
#  [0.7576103482834634, 'Classes and Objects in Python', 'oops-class.json'],
#  [0.7576049805528052, 'Define CLasses in Python', 'oops-class.json'],
#  [0.7574109441351277,
#   'Python Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.7574109441351277,
#   'Python Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.7574109441351277,
#   'Python - Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.7574109441351277,
#   'Overloading Operators in Python',
#   'oops-operator-overloading.json'],
#  [0.7574109441351277,
#   'Operator overloading in Python',
#   'oops-operator-overloading.json'],
#  [0.7574109441351277,
#   'Operator Overloading in Python',
#   'oops-operator-overloading.json'],
#  [0.7574109441351277,
#   'OPERATOR OVERLOADING IN PYTHON',
#   'oops-operator-overloading.json'],
#  [0.7563745687410793, 'String length', 'string.json'],
#  [0.7563745687410793, 'String length', 'string.json'],
#  [0.7556607302297865,
#   '#20 Python Tutorial for Beginners | While Loop in Python',
#   'loop-while.json'],
#  [0.7555742952355402,
#   'Novice to Advanced RegEx in Less-than 30 Minutes + Python',
#   'regularexpression.json'],
#  [0.7531550422649995,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'oops-magic method-itertools.json'],
#  [0.7530595424601929,
#   'Classes & Objects in Python | Python OOP Tutorial | Python for Beginners',
#   'oops-class.json'],
#  [0.7528728400765631,
#   'Python Program to find the sum of a Series 1/1! + 2/2! + 3/3! + 4/4! '
#   '+â€¦â€¦.+ n/n!',
#   'loop-while.json'],
#  [0.7519762035280266, 'Python Regular Expressions', 'regularexpression.json'],
#  [0.7519762035280266, 'Python - Regular Expressions', 'regularexpression.json'],
#  [0.7487552186461384, 'Tuple membership test', 'tuple.json'],
#  [0.7487552186461384, 'Tuple membership test', 'tuple.json'],
#  [0.7481601693013518,
#   'Operator Overloading in Python (Hindi)',
#   'oops-operator-overloading.json'],
#  [0.7481270635654399,
#   'Python Itertools | Hindi | Part 1 | Python for Beginner to Expert | In '
#   'Detail Explanation',
#   'oops-magic method-itertools.json'],
#  [0.7480434650831249,
#   'Python Operator Overloading OOPS',
#   'oops-operator-overloading.json'],
#  [0.7478308788223031,
#   'Operator Overloading In Python with Easy Examples',
#   'oops-operator-overloading.json'],
#  [0.7473612097388868,
#   'Top 10 Most Popular Python Libraries | Yaswanth | GeeksforGeeks',
#   'module.json'],
#  [0.7465136446741859,
#   'Advance Python Modules - How to Create & Import with dir Function',
#   'module.json'],
#  [0.746025702706613,
#   'Magic Methods in Python, by example | Using Magic Methods In Our Class '
#   'Design',
#   'oops-magic method-itertools.json'],
#  [0.7444989791673005, 'Escape sequencing in python', 'string.json'],
#  [0.7444989791673005, 'Escape sequencing in python', 'string.json'],
#  [0.7426191628279766,
#   'Python RegEx | Python Regular Expressions Tutorial | Python Tutorial | '
#   'Python Training ',
#   'regularexpression.json'],
#  [0.7415831566306534,
#   'Expert Python Tutorial #2 - Dunder/Magic Methods & The Python Data Model',
#   'oops-magic method-itertools.json'],
#  [0.7415590818710039,
#   'Functions creating iterators for efficient loopingÂ¶',
#   'oops-magic method-itertools.json'],
#  [0.7379700827575173,
#   'Python Regular Expressions Concepts',
#   'regularexpression.json'],
#  [0.7378840716470796,
#   'Python OOP Tutorials | Operator Overloading in Python | Python Operator '
#   'Overloading',
#   'oops-operator-overloading.json'],
#  [0.7375696093802663,
#   '#49 Python Tutorial for Beginners| Class and Object',
#   'oops-class.json'],
#  [0.7352845224602634, 'Advanced Python classes', 'oops-class.json'],
#  [0.7342454626535488, 'How to insert Strings into an AVL Tree', 'tree.json'],
#  [0.7332560362221866,
#   'Polymorphism in Python | Lecture 58 | Method Overloading | Method '
#   'Overriding | Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.7324905590355156,
#   'Regular Expressions (Regex) in Python',
#   'regularexpression.json'],
#  [0.7324905590355156,
#   'Python Regular Expression (RegEX)',
#   'regularexpression.json'],
#  [0.7312061760383618,
#   'Python program to find the factorial of a given number',
#   'loop-for.json'],
#  [0.7291615502911304, 'Using classes in Python', 'oops-class.json'],
#  [0.7288176939418731,
#   'Regular Expressions in Python | Python Tutorial for Beginners | Naresh IT',
#   'regularexpression.json'],
#  [0.7268669289295695,
#   'Python Modules and Packages - An Introduction',
#   'module.json'],
#  [0.7246525287542769,
#   'Python Program to Calculate and print sum of Even and Odd integers of first '
#   'Natural n Numbers #15',
#   'loop-while.json'],
#  [0.7246368788209703, 'Introduction to tuples', 'tuple.json'],
#  [0.7246368788209703, 'Introduction to tuples', 'tuple.json'],
#  [0.7235059588097428, 'Advanced Python for Data Science', 'oops-class.json'],
#  [0.72020611226726,
#   'Itertools in Python 3, By Example',
#   'oops-magic method-itertools.json'],
#  [0.7181932455469802, 'Updating tuple and deleting a tuple', 'tuple.json'],
#  [0.7181932455469802, 'Updating and Deleting a tuple', 'tuple.json'],
#  [0.7179758094283518,
#   'Object Oriented Porgramming in Python',
#   'oops-class.json'],
#  [0.7168206364515259, 'tuple Access tuple elements', 'tuple.json'],
#  [0.7168206364515259, 'Access tuple elements', 'tuple.json'],
#  [0.7126688150386108,
#   'Python RegEx: re.match(), re.search(), re.findall() with Example',
#   'regularexpression.json'],
#  [0.7125616249831849,
#   'Python modules: Exercises, Practice, Solution',
#   'module.json'],
#  [0.7111204758329218,
#   'Python program to convert the month name to a number of days',
#   'loop-for.json'],
#  [0.7110584500639671, 'tuple Creating a tuple', 'tuple.json'],
#  [0.7110584500639671, 'Creating a tuple', 'tuple.json'],
#  [0.7097626918992521,
#   "Python's Magical Itertools Module",
#   'oops-magic method-itertools.json'],
#  [0.7066639195512658,
#   'Python OOP Tutorial 5: Special (Magic/Dunder) Methods',
#   'oops-magic method-itertools.json'],
#  [0.7045545502878485,
#   'Advanced Python: Itertools Library â€” The Gem Of Python Language',
#   'oops-magic method-itertools.json'],
#  [0.7044056931635153,
#   'Advanced Python || Operator Overloading Part - 1 ',
#   'oops-operator-overloading.json'],
#  [0.7034824725846621,
#   'Python Advanced Modules Made Easy â€” Part 1',
#   'module.json'],
#  [0.7032538179246698,
#   'Frequently Asked Python Program 17: Multiply All Numbers in the List',
#   'loop-while.json'],
#  [0.7026119692817406,
#   'Top 5 Python Modules You Should Know in 2023',
#   'module.json'],
#  [0.7003684034660261,
#   'Regular Expressions (RegEx) in Python : Advanced Concepts',
#   'regularexpression.json'],
#  [0.6997040275480236,
#   'Hindi Magic/Dunder Methods In Python? | Object Oriented Programming Using '
#   'Python Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.6976703491881814,
#   'Advanced Python Programming - Regular Expressions Part 1',
#   'regularexpression.json'],
#  [0.6956179189135168,
#   '#59 Python Tutorial for Beginners | Operator Overloading | Polymorphism',
#   'oops-operator-overloading.json'],
#  [0.6952793368657701,
#   'Reverse a Number in Python using While Loop',
#   'loop-while.json'],
#  [0.6918308157577421,
#   'Python : Operator Overloading a specific type',
#   'oops-operator-overloading.json'],
#  [0.6915740047275445,
#   'Python Advanced Tutorial 4 - Regular Expressions',
#   'regularexpression.json'],
#  [0.6895145969437048,
#   'Python - Object Oriented Programming | Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.6895145969437048,
#   'Operator Overloading in Python | Object Oriented Programming in Python',
#   'oops-operator-overloading.json'],
#  [0.6887281530984851, 'Top 18 Most Useful Python Modules', 'module.json'],
#  [0.6844710449124043,
#   'Regular Expression in Python with Examples',
#   'regularexpression.json'],
#  [0.6808138983997593,
#   'What are Modules in Python and How to Define Modules in Python with '
#   'Examples',
#   'module.json'],
#  [0.6807624926950935, 'Accessing characters in string', 'string.json'],
#  [0.6785722946885667,
#   'Working with Own Modules - Python Advanced Tutorial Series - 37',
#   'module.json'],
#  [0.6773891923072141,
#   'Advanced String Searching including RegEx (Pandas Tutorials 06)',
#   'regularexpression.json'],
#  [0.6734550095484612, 'Create and Import Python Modules', 'module.json'],
#  [0.6721709398394317,
#   'Lesson - 50 : Python Advanced - Python OOPs : Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.670255006333799,
#   'Python Program to Print First 10 Natural Numbers',
#   'loop-while.json'],
#  [0.6674050905958494,
#   "A Guide to Python's Secret Superpower: Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.6659787577595533,
#   "A Guide to Python's Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.6638485458316544,
#   'Advanced Python RegEx Examples',
#   'regularexpression.json'],
#  [0.6573810786445364,
#   'Itertools in Python3',
#   'oops-magic method-itertools.json'],
#  [0.6434810705623177,
#   'Program to find the product of the given number of consecutive elements',
#   'loop-while.json'],
#  [0.6325620618929191, ' InOrder Successor and Predecessor', 'tree.json'],
#  [0.623332429338994,
#   '# 13 Operator Overloading in Python with Example',
#   'oops-operator-overloading.json'],
#  [0.6205416168188603, 'Magic Methods', 'oops-magic method-itertools.json'],
#  [0.615025129993639, 'Printing variables names and values', 'string.json'],
#  [0.615025129993639, 'Printing variable names and values', 'string.json'],
#  [0.6140853627575851,
#   'Count of Array elements greater than all elements on its left and at least '
#   'K elements on its right',
#   'tree.json'],
#  [0.6027470296707003, ' Add set items', 'set.json'],
#  [0.6027470296707003, ' Add set items', 'set.json'],
#  [0.6026300839102157,
#   'Puthon OOP Tutorial 1: Classes and Instances',
#   'oops-class.json'],
#  [0.5832674358064343, 'Set size and membership', 'set.json'],
#  [0.5832674358064343, 'Set size and membership', 'set.json'],
#  [0.5810476143183014, 'Data model', 'oops-magic method-itertools.json'],
#  [0.5392146902683933,
#   'Program to Print First 10 Natural Numbers - In Hindi',
#   'loop-while.json'],
#  [0.5334369618228834,
#   'REGEX (REGULAR EXPRESSIONS) WITH EXAMPLES IN DETAIL | Regex Tutorial',
#   'regularexpression.json'],
#  [0.5325357530696326,
#   'Regular Expressions (Regex) Tutorial: How to Match Any Pattern of Text',
#   'regularexpression.json'],
#  [0.5320343683218448,
#   'Convert a Binary Search Tree into a Skewed tree in increasing or decreasing '
#   'order',
#   'tree.json'],
#  [0.5318614254985728,
#   'Advanced Date Matching with Regex - Including leap years',
#   'regularexpression.json'],
#  [0.5216474055741279, 'Classes and Objects (OOPS)', 'oops-class.json'],
#  [0.5106232288341721, 'Advanced Regular Expressions', 'regularexpression.json'],
#  [0.5103578483243295,
#   'Skewed Binary Search Tree | Left Skewed | Right Skewed | Disadvantages of '
#   'BST | Data Structures',
#   'tree.json'],
#  [0.5059380109704184, 'What is Modular Programming?', 'module.json'],
#  [0.5025198822801599, 'Introduction to Binary Tree', 'tree.json'],
#  [0.49866662995248895, 'Basic insertion and search', 'tree.json'],
#  [0.47362130038081013, 'Inplace boolean logic', 'string.json'],
#  [0.47362130038081013, 'Inplace boolean logic', 'string.json'],
#  [0.459563838416599, 'Frozen set', 'set.json'],
#  [0.459563838416599, 'Frozen set', 'set.json'],
#  [0.45624515360015294, 'Find leaders in an array', 'tree.json'],
#  [0.4562178761128655, 'AVL Tree - Insertion and Rotations', 'tree.json'],
#  [0.456168966547397, 'Remove set items', 'set.json'],
#  [0.456168966547397, 'Remove set items', 'set.json'],
#  [0.4435635963313491, 'Level order Traversal BST-', 'tree.json'],
#  [0.4435635963313491, 'Level Order Traversal of BST', 'tree.json'],
#  [0.4399985627159687, 'Accessing sets', 'set.json'],
#  [0.4399985627159687, 'Accessing sets', 'set.json'],
#  [0.4007195262192714, 'Slicing and indexing', 'tuple.json'],
#  [0.4007195262192714, 'Slicing and indexing', 'tuple.json'],
#  [0.3968676404387817,
#   'Overloading < operator',
#   'oops-operator-overloading.json'],
#  [0.3968676404387817, 'Operator Overloading', 'oops-operator-overloading.json'],
#  [0.38611429363713223, ' Closest element in BST', 'tree.json'],
#  [0.37309372236610466, 'Inorder Traversal of BST', 'tree.json'],
#  [0.37309372236610466, 'Inorder Traversal of BST', 'tree.json'],
#  [0.3721421556225002, 'Search and Insertion', 'tree.json'],
#  [0.3627241015551863, 'Loop sets', 'set.json'],
#  [0.3627241015551863, 'Loop sets', 'set.json'],
#  [0.34597064628279894, 'Introduction to sets', 'set.json'],
#  [0.34597064628279894, 'Introduction to sets', 'set.json'],
#  [0.329008899512835, 'Introduction', 'tree.json'],
#  [0.3282534693466464, 'Join sets', 'set.json'],
#  [0.3282534693466464, 'Join sets', 'set.json'],
#  [0.31170847346029246, ' Set operations', 'set.json'],
#  [0.31170847346029246, ' Set operation', 'set.json'],
#  [0.30345773569049744, 'Preorder Traversal of BST', 'tree.json'],
#  [0.30345773569049744, 'Preorder Traversal of BST', 'tree.json'],
#  [0.30345773569049744, 'Postorder Traversal of BST', 'tree.json'],
#  [0.30345773569049744, 'Postorder Traversal of', 'tree.json'],
#  [0.24640895692768258, 'Construction of BST', 'tree.json']]

# %%
import pickle
with open('model.dat','wb') as file:
    pickle.dump(model1,file)

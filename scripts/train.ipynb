# %%
import json
from pathlib import Path
import gensim
from gensim.models import Word2Vec

from stopstem import *
import os
 

path = "C://Users//ganes//Desktop//mini//reference"
dir_list = os.listdir(path)
#print(dir_list)
matrix=[]
for i in dir_list:
    with open("../reference/"+i,'r') as data_source:
        try:
            data1 = data_source.read()
            stemmed = tokenizeAndStem(data1)
            matrix.append(stemmed)
        except:
            print(i)
        
#print(matrix)
model1 = Word2Vec(matrix, min_count = 1, window = 5, sg=1)
# Out:
# 3.11.txt
# 3.2.txt
# 3.4.txt
# 3.5.txt
# 3.6.txt
# 3.7.txt
# 3.8.txt
# 3.9.txt
# changelog.txt
# decimal.txt
# instrumentation.txt
# logging-cookbook.txt
# math.txt
# nntplib.txt
# random.txt
# stable.txt
# unicode.txt

# %%
from cosines import cacCosine
q1 = "Python Program to Print Natural Numbers Using While and For Loop in Hindi - Tutorial #22"
q2 = "Print the first 10 natural numbers using for loop"
print(model1.wv)
def sim(q1,q2):
    a1 = q1.split()
    import numpy as np
    v1 = np.array([0.0]*100)
    v2 = np.array([0.0]*100)
    c1=1
    for i in a1:
        try:
            v1+=model1.wv[i]
            c1+=1
        except:
            pass
    v1/=c1
    a2 = q2.split()
    c2=1
    for i in a2:
        try:
            v2+=model1.wv[i]
            c2+=1
        except:
            pass
    v2/=c2
    return cacCosine(list(v1),list(v2))
import os
BASE_DIR = Path(os.getcwd()).resolve().parent

def findSimilar(listOfDocs,query):
    #dic={stemmdtitle:[title,link,file]}
    dic={}
    maxi=[]
    for i in listOfDocs:
        if i[-4::]=='json':
            with open(BASE_DIR/('jsons/'+i)) as f:
                data=json.load(f)
                for j in data:
                    for k in data[j]['videos'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['videos'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
                    for k in data[j]['reading'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['reading'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
    return dic,maxi
# Out:
# KeyedVectors<vector_size=100, 29264 keys>

# %%
from pprint import pprint as p
l = os.listdir("C://Users//ganes//Desktop//mini//jsons")
dic,maxi = findSimilar(l,"how to make dictionary in python")
p(sorted(maxi,reverse=True))
# Out:
# [[0.9169132499588085, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.9169132499588085, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.913866301507448,
#   'Lambda Expression : Python tutorial 150',
#   'function-lambda.json'],
#  [0.9008612539804819,
#   'How to Use Python Lambda Functions? 6 Comprehensive Aspects',
#   'function-lambda.json'],
#  [0.8905579992350907,
#   'Python Lambda | Advanced Python | Tutorial 18',
#   'function-lambda.json'],
#  [0.8900001950140969,
#   '6. INTRODUCTION TO EXCEPTION HANDLING IN PYTHON',
#   'exception handling.json'],
#  [0.8898805352851418,
#   'Generators and Iterators in python | python tutorial',
#   'iterator-generator-decorator.json'],
#  [0.8884678101910808,
#   'Lambda Expressions - Python Tips and Tricks #5',
#   'function-lambda.json'],
#  [0.8883423099377795,
#   ' Exception handling tips in Python âš\xa0 Write better Python code part 7',
#   'exception handling.json'],
#  [0.8843368528847222,
#   '[Language skills Python] Exercise Lambda Expressions - Advanced [Tutorial]',
#   'function-lambda.json'],
#  [0.8813404974886524,
#   'Python Iterators | Iterables and Iterators in Python | Python Tutorial for '
#   'Beginners | Edureka',
#   'iterator-generator-decorator.json'],
#  [0.8812105279658283,
#   ' Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.8806736587263703,
#   ' Lambda Expressions & Anonymous Functions || Python Tutorial || Learn Pâ€¦',
#   'function-lambda.json'],
#  [0.8775512192463704,
#   ' 8. Exception handling â€” Advance Python Tutorials documentation',
#   'exception handling.json'],
#  [0.8772445258829575,
#   'Python Generators vs Iterators',
#   'iterator-generator-decorator.json'],
#  [0.8758416476204072,
#   'Lambda in Python - Advanced Python 08 - Programming Tutorial - Map Filter '
#   'Reduce',
#   'function-lambda.json'],
#  [0.8754155191363062,
#   '#61 Python Tutorial for Beginners | Iterator',
#   'iterator-generator-decorator.json'],
#  [0.8705884101031688,
#   'Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.8705884101031688,
#   ' Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.8682682797589927,
#   ' 30. Errors and Exception Handling | Python Tutorial',
#   'exception handling.json'],
#  [0.8673089827267637,
#   'Generators In Python | Python Tutorials For Absolute Beginners In Hindi #72',
#   'iterator-generator-decorator.json'],
#  [0.8645147915689377,
#   ' Exceptions in Python - Advanced Python 09 - Programming Tutorial',
#   'exception handling.json'],
#  [0.8640734541777803,
#   ' Day 24: Advanced Exception Handling and Raising Exceptions',
#   'exception handling.json'],
#  [0.8640250572964288,
#   '#62 Python Tutorial for Beginners | Generators',
#   'iterator-generator-decorator.json'],
#  [0.8622400339370694,
#   'Lambda Functions - Advanced Python 08',
#   'function-lambda.json'],
#  [0.8620518959268332,
#   'Function arguments in detail - Advanced Python 18 - Programming Tutorial',
#   'function.json'],
#  [0.86071750932889,
#   '. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.8605210466890781, 'Python Conditions', 'condition-pass.json'],
#  [0.8605210466890781, 'Python Condition', 'condition-pass.json'],
#  [0.8602855952776295,
#   'Decorators In Python | Python Tutorials For Absolute Beginners In Hindi #51',
#   'iterator-generator-decorator.json'],
#  [0.858423217796042, 'Advanced features of Python Functions', 'function.json'],
#  [0.858423217796042,
#   'Advanced Features in Python Functions | Python Functions Advanced',
#   'function.json'],
#  [0.8582607472594906,
#   'Iterators and Generators',
#   'iterator-generator-decorator.json'],
#  [0.8546137159943822,
#   'Difference Between Iterator VS Generator',
#   'iterator-generator-decorator.json'],
#  [0.853429966230757, 'Maximum Index', 'array.json'],
#  [0.852826129085134,
#   '#44 Python Tutorial for Beginners | Decorators',
#   'iterator-generator-decorator.json'],
#  [0.8509260131563308,
#   'Python 3 Programming Tutorial | #1 Introduction of Python Lambda and '
#   'Anonymous Function',
#   'function-lambda.json'],
#  [0.8505047206371842,
#   ' Advanced Python Series- Custom Exception Handling In Python',
#   'exception handling.json'],
#  [0.8493203945603092,
#   'Comparison of Iterators and Generators in python',
#   'iterator-generator-decorator.json'],
#  [0.8485189819548955, '#27 Python Tutorial for Beginners', 'array.json'],
#  [0.8485189819548955, ' #26 Python Tutorial for Beginners', 'array.json'],
#  [0.8472086419102683,
#   'Building Lambda functions with Python',
#   'function-lambda.json'],
#  [0.8452204565485771,
#   ' User-defined Exceptions in Python with Examples - GeeksforGeeks',
#   'exception handling.json'],
#  [0.8448730307411737,
#   ' Anonymous/Lambda Functions In Python | Python Tutorials For Absolute Bâ€¦',
#   'function-lambda.json'],
#  [0.8423495959909829,
#   'Find missing number in an array in python',
#   'array.json'],
#  [0.8419664345233849, 'Arrays in python: Array Advance Game', 'array.json'],
#  [0.837478768540841,
#   'Lambda and filter in Python Examples',
#   'function-lambda.json'],
#  [0.8346054621937085,
#   'Lambda Function in Python -     Example Syntax',
#   'function-lambda.json'],
#  [0.834418307028412,
#   ' Python Tutorial: Using Try/Except Blocks for Error Handling',
#   'exception handling.json'],
#  [0.8332263133730183,
#   ' Exception Handling in Python | CUET Computer Science',
#   'exception handling.json'],
#  [0.829687709858157,
#   'Lambda Functions with Practical Examples in Python',
#   'function-lambda.json'],
#  [0.8295965882569433, 'Python Lambda Expressions', 'function-lambda.json'],
#  [0.8279514259380242, 'Sort an array using Quicksort Algorithm', 'array.json'],
#  [0.8271332343102401,
#   ' Python Functions Tutorial | Working With Functions In Python | Python '
#   'Training | Eâ€¦',
#   'function.json'],
#  [0.8230416250750839, 'Arrays in python| Python for beginners', 'array.json'],
#  [0.8218357596805751, 'Introduction to if else', 'condition-pass.json'],
#  [0.8218357596805751, 'Introduction to if else', 'condition-pass.json'],
#  [0.8206317576184397,
#   " Python Functions (The Only Guide You'll Need) #12",
#   'function.json'],
#  [0.8205187708774833,
#   'Functions And Docstrings | Python Tutorials For Absolute Beginners In Hindi '
#   '#23',
#   'function.json'],
#  [0.8187926681264968,
#   'Python: Lambda, Map, Filter, Reduce Functions',
#   'function-lambda.json'],
#  [0.8182704004402975,
#   'Advanced Functional Programming in Python: lambda',
#   'function-lambda.json'],
#  [0.8175235178917211, ' Python Lambda', 'function-lambda.json'],
#  [0.8167508659306394,
#   'ANONYMOUS FUNCTIONS (LAMBDA) - PYTHON PROGRAMMING',
#   'function-lambda.json'],
#  [0.812092902510104,
#   '[Hindi] Lambda functions in python in Hindi | Advanced python in Hindi',
#   'function-lambda.json'],
#  [0.8115612023250192, 'Arrays in Python Programming', 'array.json'],
#  [0.8094969104112483, 'Find missing and repeating', 'array.json'],
#  [0.8069948139621134,
#   'Python Tutorial: Iterators and Iterables - What Are They and How Do They '
#   'Work?',
#   'iterator-generator-decorator.json'],
#  [0.8069169890021494,
#   'Advanced indexing Operations in Numpy Arrays',
#   'array.json'],
#  [0.8068653786111566,
#   'Tutorial: Lambda Functions in Python',
#   'function-lambda.json'],
#  [0.8066595152616717,
#   'Python Lambda Function | Anonymous Function In Python | Python Tutorial | '
#   'Edureka',
#   'function-lambda.json'],
#  [0.8058121679067288, 'Find missing number', 'array.json'],
#  [0.8054790570149875,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'function.json'],
#  [0.8046634570657287,
#   'Pair with the given sum in a sorted array',
#   'array.json'],
#  [0.802643502404878, 'Write a program to sort the given array', 'array.json'],
#  [0.8017522733064669,
#   'How to Use Python Lambda Functions',
#   'function-lambda.json'],
#  [0.8015999373893111,
#   ' Python Functions | Python Tutorial for Absolute Beginners #1',
#   'function.json'],
#  [0.7994907017959234,
#   'Write a program to cyclically rotate an array by one| Love Babbar DSA Sheet',
#   'array.json'],
#  [0.79884627467982,
#   'Python Try Except - GeeksforGeeks',
#   'exception handling.json'],
#  [0.7982883366959919, 'Pass statement', 'condition-pass.json'],
#  [0.7982883366959919, 'Pass statement', 'condition-pass.json'],
#  [0.7942687789210465,
#   'Python Lambda/Anonymous Functions ',
#   'function-lambda.json'],
#  [0.7940601139655136,
#   'How To Use Functions In Python (Python Tutorial #3)',
#   'function.json'],
#  [0.7938474753917132,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.7938474753917132,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.7937991813177783,
#   'Creating One Dimensional Array using Numpy',
#   'array.json'],
#  [0.7936391722371501,
#   '#42 Python Tutorial for Beginners | Anonymous Functions | Lambda',
#   'function-lambda.json'],
#  [0.7933875890422212, 'Python Functions Advanced', 'function.json'],
#  [0.7933875890422212, 'Python Advanced Functions', 'function.json'],
#  [0.7916419438632782,
#   'Lambda Functions in Python | Python Tutorial #37',
#   'function-lambda.json'],
#  [0.7906867143471078, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.7906867143471078, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.7906867143471078,
#   'Lambda Function in Python - In Hindi',
#   'function-lambda.json'],
#  [0.7868467414973278,
#   'Function Decorator in Python (Hindi)',
#   'iterator-generator-decorator.json'],
#  [0.7862086326582391,
#   ' Professional Error Handling With Python',
#   'exception handling.json'],
#  [0.7844758986107414,
#   'Decorators in Python',
#   'iterator-generator-decorator.json'],
#  [0.7841799229433859, 'Elif statement', 'condition-pass.json'],
#  [0.7841799229433859, 'Elif statement', 'condition-pass.json'],
#  [0.7822731865770446,
#   'Exception Handling in Python',
#   'exception handling.json'],
#  [0.7778153617158695,
#   'Write a program to cyclically rotate an array by one',
#   'array.json'],
#  [0.7774535769087106,
#   'Find the minimum and maximum element in an array',
#   'array.json'],
#  [0.7753184421612995, '384 Shuffle an array', 'array.json'],
#  [0.774889925506137,
#   'Intermediate Python Tutorial #5 - Lambda Functions',
#   'function-lambda.json'],
#  [0.7748048384417909, 'High order functions in Python', 'function.json'],
#  [0.7736080080956897, 'PythonDocs Python Function', 'function.json'],
#  [0.773387118485713,
#   ' Advanced Python- Exception Handling Detailed Explanation In Python',
#   'exception handling.json'],
#  [0.773041372416618,
#   'Python Intermediate: Lambda Functions',
#   'function-lambda.json'],
#  [0.772351540733423,
#   ' #32 Python Tutorial for Beginners | Functions in Python',
#   'function.json'],
#  [0.7707638863581886,
#   'Lambda Operator, filter, reduce and map',
#   'function-lambda.json'],
#  [0.7696559472918747,
#   '#3: Python lambda (anonymous) Functions | Python Best Practices',
#   'function-lambda.json'],
#  [0.7646301835759868, 'TutorialsPoint Python Functions ', 'function.json'],
#  [0.7646301835759868, 'Python Functions Edureka ', 'function.json'],
#  [0.7646301835759868, 'Python Functions ', 'function.json'],
#  [0.7646301835759868, 'Programiz Python Functions ', 'function.json'],
#  [0.7646301835759868, 'LearnPython Python Functions', 'function.json'],
#  [0.7646301835759868, 'JavaPoint Python Functions ', 'function.json'],
#  [0.7646301835759868, 'GFG Python Functions ', 'function.json'],
#  [0.763313801723384, 'Shorthand statement', 'condition-pass.json'],
#  [0.763313801723384, 'Shorthand if statement', 'condition-pass.json'],
#  [0.76217653928517, ' Max sum path in two arrays', 'array.json'],
#  [0.7577382816531205, 'Find duplicates in an array', 'array.json'],
#  [0.7568347683279271,
#   ' NZEC error in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.7313132026541147, 'Write a program to reverse an array', 'array.json'],
#  [0.7234625267484697, 'Stock buy and sell Problem', 'array.json'],
#  [0.7072695314506976, 'Nested if condition', 'condition-pass.json'],
#  [0.696477974908746, 'Count pairs with given sum', 'array.json'],
#  [0.6960560820144908, 'Subarray with given sum', 'array.json'],
#  [0.6171964319342014, 'Peak Element', 'array.json'],
#  [0.5362074428398156, 'Indentation', 'condition-pass.json'],
#  [0.5362074428398156, 'Indentation', 'condition-pass.json'],
#  [0.49360429048896426, 'Nested if Condtion', 'condition-pass.json'],
#  [nan, ' exceptions.Exception', 'exception handling.json'],
#  [0.9432467444892544,
#   'Frequently Asked Python Program 4: Print Fibonacci Series',
#   'loop-for.json'],
#  [0.9411421247338072,
#   'Frequently Asked Python Program 17: Multiply All Numbers in the List',
#   'loop-while.json'],
#  [0.9354834296956568,
#   'Python Program to Print First 10 Natural Numbers',
#   'loop-while.json'],
#  [0.9301949930560323,
#   'Python Program to Print Sum of n Odd Natural Numbers | 1+3+5+7+..+n Series '
#   'Calculation in Python',
#   'loop-for.json'],
#  [0.9278648371693815,
#   'Program to Print First 10 Natural Numbers - In Hindi',
#   'loop-while.json'],
#  [0.9136037503774128,
#   'Python program to display numbers from a list using a for loop.',
#   'loop-for.json'],
#  [0.9078643197716587,
#   'Advanced Python Series - Iterators Vs Generators',
#   'iterator-generator-decorator.json'],
#  [0.9056271646986055,
#   '4. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.9048592076621337,
#   'Python Program for Series Calculation 1*1 + 2*2 + 3*3 +..+n | Series '
#   'Calculation Program in Python',
#   'loop-while.json'],
#  [0.9031024445338831,
#   'Python program to get the Fibonacci series between 0 to 50',
#   'loop-for.json'],
#  [0.9025305363502678,
#   'Python Program to find the sum of a Series 1/1! + 2/2! + 3/3! + 4/4! '
#   '+â€¦â€¦.+ n/n!',
#   'loop-while.json'],
#  [0.8992931224444356,
#   'Itertools - Advanced Python 07',
#   'oops-magic method-itertools.json'],
#  [0.898631408396935,
#   'Object Oriented Porgramming in Python',
#   'oops-class.json'],
#  [0.8982162314864653,
#   'Python Programming 19 - Remove Elements From List within for Loop',
#   'list.json'],
#  [0.8966805757636707,
#   'Modules in Python Explained | Python Built in Modules | Python Tutorial for '
#   'Beginners | Simplilearn',
#   'module.json'],
#  [0.8943544264757167,
#   'Print the first 10 natural numbers using for loop',
#   'loop-for.json'],
#  [0.8943360801778014,
#   'Python Program to Calculate and print sum of Even and Odd integers of first '
#   'Natural n Numbers #15',
#   'loop-while.json'],
#  [0.8907310179875625,
#   'Frequently Asked Python Program 20:Check String is Palindrome or Not',
#   'loop-for.json'],
#  [0.8905946440980588,
#   'Python Itertools | Hindi | Part 1 | Python for Beginner to Expert | In '
#   'Detail Explanation',
#   'oops-magic method-itertools.json'],
#  [0.8885348752333269,
#   'Itertools in Python 3, By Example',
#   'oops-magic method-itertools.json'],
#  [0.8883648549452372,
#   'Itertools in Python3',
#   'oops-magic method-itertools.json'],
#  [0.8835117613592656,
#   'Itertools in Python - Advanced Python 07 - Programming Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.8812105279658283,
#   '[Hindi] Iterators, Iterables and Generators in python explained | Advanced '
#   'python tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.8812105279658283,
#   'Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials',
#   'iterator-generator-decorator.json'],
#  [0.8809987878734694,
#   '5 Advanced Functions in Itertools To Simplify Iterations in Python',
#   'oops-magic method-itertools.json'],
#  [0.8796962933197172,
#   'Python Program to Print Natural Numbers Using While and For Loop in Hindi - '
#   'Tutorial #22',
#   'loop-for.json'],
#  [0.8795346887415884,
#   'Python Programming - Calculate the Number of Digits and Letters in a String '
#   '- Updated 2021',
#   'loop-for.json'],
#  [0.8791585481642712,
#   'Decorators in Python - Advanced Python 13 - Programming Tutorial',
#   'iterator-generator-decorator.json'],
#  [0.8783095240274568,
#   'Python modules: Exercises, Practice, Solution',
#   'module.json'],
#  [0.8762040877748518,
#   'Python Tutorials - Namespace and Variable Scope',
#   'iterator-generator-decorator.json'],
#  [0.8756200399719958,
#   'Python program to calculate the sum of first N even numbers',
#   'loop-while.json'],
#  [0.8732543436021133,
#   'Python Advanced Modules Made Easy â€” Part 1',
#   'module.json'],
#  [0.8715159572683706,
#   '#49 Python Tutorial for Beginners| Class and Object',
#   'oops-class.json'],
#  [0.8711845327163869,
#   'Hindi Magic/Dunder Methods In Python? | Object Oriented Programming Using '
#   'Python Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.8709089516275818,
#   'Classes & Objects in Python | Python OOP Tutorial | Python for Beginners',
#   'oops-class.json'],
#  [0.8707382917612525,
#   'Top 5 Python Modules You Should Know in 2023',
#   'module.json'],
#  [0.8695492247515361,
#   'Python program to display all numbers within a range except the prime '
#   'numbers',
#   'loop-for.json'],
#  [0.8638889216948207, 'How to add an item to a list in Python', 'list.json'],
#  [0.8623868416877949,
#   'Top 10 Most Popular Python Libraries | Yaswanth | GeeksforGeeks',
#   'module.json'],
#  [0.8622104618561364,
#   'Python Programming Tutorial - Iterators (Part-1)',
#   'iterator-generator-decorator.json'],
#  [0.8618210238256595, 'Sort lists', 'list.json'],
#  [0.8618210238256595, ' Sort list', 'list.json'],
#  [0.8612934881032449, 'Define CLasses in Python', 'oops-class.json'],
#  [0.86071750932889,
#   ' Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.8604761919227052, 'Expert Python Tutorial', 'oops-class.json'],
#  [0.8599375234996839,
#   ' Try Except Exception Handling In Python | Python Tutorials For Absolute '
#   'Bâ€¦ ',
#   'exception handling.json'],
#  [0.8597944015373291,
#   'Python program to print all the even numbers within the given range',
#   'loop-for.json'],
#  [0.8585357205209863,
#   'What are Python Iterators and Generators?',
#   'iterator-generator-decorator.json'],
#  [0.8585357205209863,
#   'PYTHON ITERATORS AND GENERATORS',
#   'iterator-generator-decorator.json'],
#  [0.8585357205209863,
#   'Iterators and Generators in Python',
#   'iterator-generator-decorator.json'],
#  [0.8585357205209863,
#   'Generators & Iterators in python',
#   'iterator-generator-decorator.json'],
#  [0.8582607472594906,
#   'Iterators & Generators',
#   'iterator-generator-decorator.json'],
#  [0.8582607472594906,
#   'Generators and Iterators',
#   'iterator-generator-decorator.json'],
#  [0.8573094429321975,
#   'What are Modules in Python and How to Define Modules in Python with '
#   'Examples',
#   'module.json'],
#  [0.8571552021160518,
#   'Python program to calculate the sum of all the odd numbers within the given '
#   'range',
#   'loop-for.json'],
#  [0.8569944110584933, 'Top 18 Most Useful Python Modules', 'module.json'],
#  [0.8566311025134804,
#   'Python Itertools | Itertools in Python | Python Tutorial for Beginners | '
#   'Edureka',
#   'oops-magic method-itertools.json'],
#  [0.8559501840572782,
#   'Python Programming for Intermediate programmer',
#   'oops-class.json'],
#  [0.8548994293141454,
#   'Python Program to Count Total Odd and Even Numbers in List - In Hindi',
#   'loop-for.json'],
#  [0.8546628625929872,
#   'How to Change/Replace/Update List Items ? | List tutorial in python',
#   'list.json'],
#  [0.8542973283300898,
#   'Python program to check the validity of password input by users',
#   'loop-for.json'],
#  [0.8539488547845909,
#   'Python Itertools For Advanced Iteration',
#   'oops-magic method-itertools.json'],
#  [0.8538423484105647,
#   'Python program counts the number of even and odd numbers from a series of '
#   'numbers',
#   'loop-for.json'],
#  [0.8534964991361466,
#   'Using Python External & Built In Modules | Python Tutorials For Absolute '
#   'Beginners In Hindi',
#   'module.json'],
#  [0.8534716911278938,
#   'Accessing List using for Loop in Python (Hindi)',
#   'loop-for.json'],
#  [0.8532848485647704,
#   'Python Itertools Module & Its Iteration Tutorial #38',
#   'oops-magic method-itertools.json'],
#  [0.8530721112846089,
#   'Python Program to Print Multiplication Table of a Number ( User Input )',
#   'loop-for.json'],
#  [0.8526509712071487,
#   'Exceptions in Python || Python Tutorial || Learn Python Programming',
#   'exception handling.json'],
#  [0.8512207903239952,
#   'Iterator And Generator In Python | Python Generators And Iterators '
#   'Explained | Python | Simplilearn',
#   'iterator-generator-decorator.json'],
#  [0.8492121322496393, 'Create and Import Python Modules', 'module.json'],
#  [0.8476178866115028,
#   'Working with Own Modules - Python Advanced Tutorial Series - 37',
#   'module.json'],
#  [0.8471671457545998, 'Python Iterators', 'iterator-generator-decorator.json'],
#  [0.8468178568495188,
#   'Python program to print a multiplication table of a given number',
#   'loop-for.json'],
#  [0.8465668148872353,
#   'Python Intermediate Series: Python Modules',
#   'module.json'],
#  [0.8457910330905516,
#   'Python OOP Tutorial 5: Special (Magic/Dunder) Methods',
#   'oops-magic method-itertools.json'],
#  [0.8455107905095237,
#   'Explore the magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.8432749948609276,
#   'Check the validity of a Password in Python',
#   'loop-for.json'],
#  [0.8431083761037726, 'Python Objects and Classes', 'oops-class.json'],
#  [0.8431083761037726, 'Python Classes and Objects', 'oops-class.json'],
#  [0.8431083761037726, 'Classes and Objects in python', 'oops-class.json'],
#  [0.8431083761037726, 'Classes and Objects in Python', 'oops-class.json'],
#  [0.8425092499094334,
#   '. Python Programming Tutorial | Exception Handling in Python | '
#   'GeeksforGeâ€¦',
#   'exception handling.json'],
#  [0.8424194578266864,
#   ' Exception Handling in Python || Syntax Error vs Runtime Error',
#   'exception handling.json'],
#  [0.8391883031432861,
#   'Python Programs - Factorial Program Using for loop',
#   'loop-for.json'],
#  [0.8388375632603857,
#   'Python Program to Reverse of a Number - In Hindi',
#   'loop-while.json'],
#  [0.8376829805395788, 'Python While Loops', 'loop-while.json'],
#  [0.8357311379943626, 'Python : Advance built in modules', 'module.json'],
#  [0.8357176454535173, 'Python Modules | Learn Coding', 'module.json'],
#  [0.8346852156092214,
#   "A Guide to Python's Secret Superpower: Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.8319253113500682, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.8319253113500682, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.8313975152095195,
#   "HINDI BIT-PY Beginner's Python Course | Part #36 | Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.8300283554649839,
#   '#45 Python Tutorial for Beginners | Modules',
#   'module.json'],
#  [0.8278648452723669,
#   'How to print even numbers in the given range in Python',
#   'loop-for.json'],
#  [0.8275809228091111,
#   'Python program to find the factorial of a given number',
#   'loop-for.json'],
#  [0.8254070325909915,
#   'Understanding Python: Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.8251143740762523,
#   'Python program to find all the prime numbers in the given range- by Mahesh '
#   'Huddar',
#   'loop-for.json'],
#  [0.8241243766150357,
#   'Advance Python Modules - How to Create & Import with dir Function',
#   'module.json'],
#  [0.82365519162021, 'Python Immediate Tutorial #1', 'oops-class.json'],
#  [0.8234458800892218,
#   "Python's Magical Itertools Module",
#   'oops-magic method-itertools.json'],
#  [0.8234308145603463,
#   'Using Modules & Pip In Python | Python Tutorials For Absolute Beginners In '
#   'Hindi #3',
#   'module.json'],
#  [0.8219888413688924,
#   'Reverse a Number in Python using While Loop',
#   'loop-while.json'],
#  [0.8210871445129834,
#   'INTRODUCTION TO EXCEPTION HANDLING IN PYTHON ',
#   'exception handling.json'],
#  [0.820529588755115,
#   'What is Modules in Python - Python Tutorials for Beginners',
#   'module.json'],
#  [0.820529588755115,
#   'What Are Python Modules? | Modules In Python | Python Tutorial For '
#   'Beginners | Edureka',
#   'module.json'],
#  [0.8204560841662866,
#   'Expert Python Tutorial #2 - Dunder/Magic Methods & The Python Data Model',
#   'oops-magic method-itertools.json'],
#  [0.8180861210465142,
#   'Python Tutorial: Itertools Module - Iterator Functions for Efficient '
#   'Looping',
#   'oops-magic method-itertools.json'],
#  [0.8169962240225991,
#   'Advance Python Series- Magic Methods',
#   'oops-class.json'],
#  [0.8154503990996392,
#   'Python program that accepts a string and calculates the number of digits '
#   'and letters',
#   'loop-for.json'],
#  [0.8128603809235668,
#   'Python Tutorial: Decorators - Dynamically Alter The Functionality Of Your '
#   'Functions',
#   'iterator-generator-decorator.json'],
#  [0.812800995059543,
#   'Puthon OOP Tutorial 1: Classes and Instances',
#   'oops-class.json'],
#  [0.8124614820579186,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.8124614820579186,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.8115045667711973,
#   '  #63 Python Tutorial for Beginners | Exception Handling',
#   'exception handling.json'],
#  [0.8096064570465141,
#   'Python Program to check Armstrong Number',
#   'loop-while.json'],
#  [0.8096064570465141,
#   'Python Program to Check Armstrong Number',
#   'loop-while.json'],
#  [0.8096064570465141,
#   'Python Program to Check Armstrong Number',
#   'loop-for.json'],
#  [0.8080126510880509,
#   'Magic Methods in Python, by example | Using Magic Methods In Our Class '
#   'Design',
#   'oops-magic method-itertools.json'],
#  [0.8080096818880405,
#   '#20 Python Tutorial for Beginners | While Loop in Python',
#   'loop-while.json'],
#  [0.807846316626683,
#   'Python program to check if a given number is an Armstrong number',
#   'loop-for.json'],
#  [0.806467231793733, 'List comprehension', 'list.json'],
#  [0.806467231793733, ' List comprehension', 'list.json'],
#  [0.8060526767208173, 'Immediate Python Programming', 'oops-class.json'],
#  [0.8057104457698601, 'Using classes in Python', 'oops-class.json'],
#  [0.8054790570149875,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'oops-magic method-itertools.json'],
#  [0.8049687565743903,
#   'Python program to convert the month name to a number of days',
#   'loop-for.json'],
#  [0.8049687565743903,
#   'Python program to convert month name to a number of days',
#   'loop-for.json'],
#  [0.8049203838077013, 'Python Classes and Obejcts', 'oops-class.json'],
#  [0.8049203838077013, 'Python Classes', 'oops-class.json'],
#  [0.8017572832015702, 'Copy lists', 'list.json'],
#  [0.8017572832015702, 'Copy list', 'list.json'],
#  [0.8008869734756783,
#   'Program to find the product of the given number of consecutive elements',
#   'loop-while.json'],
#  [0.8007980402475534,
#   ' finally keyword in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.8002097903499945,
#   'Python - Magic or Dunder Methods',
#   'oops-magic method-itertools.json'],
#  [0.8002097903499945,
#   'Dunder or magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.7990533159133928,
#   'Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.7990533159133928,
#   'Python - Magic Methods ',
#   'oops-magic method-itertools.json'],
#  [0.7982883366959919, 'Pass statement', 'condition-pass.json'],
#  [0.7982883366959919, 'Pass statement', 'condition-pass.json'],
#  [0.7977133845967336, 'Merge two dictionaries', 'dictionary.json'],
#  [0.7977133845967336, 'Merge two dictionaries', 'dictionary.json'],
#  [0.7972576199790117, 'Intermediate Programming with Python', 'module.json'],
#  [0.7971498994072961, 'Creating a dictionary-', 'dictionary.json'],
#  [0.7971498994072961, 'Creating a dictionary', 'dictionary.json'],
#  [0.7965358237458917,
#   '@Decorators in Python (Advanced)',
#   'iterator-generator-decorator.json'],
#  [0.7927292562420339,
#   "A Guide to Python's Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.7895692971922385,
#   'Python program to check if a string is a palindrome or not',
#   'loop-for.json'],
#  [0.787554687380153,
#   'Immediate Python- Functions, Modules, Classes and Exceptions',
#   'oops-class.json'],
#  [0.7863552569672672,
#   'Advanced Python: Itertools Library â€” The Gem Of Python Language',
#   'oops-magic method-itertools.json'],
#  [0.7855888412491935, 'Python programming', 'oops-class.json'],
#  [0.7849522365037823,
#   'Introducing Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.7844758986107414, 'Python Decorators', 'iterator-generator-decorator.json'],
#  [0.7844758986107414, 'Python Decorator', 'iterator-generator-decorator.json'],
#  [0.7831024146582162, 'Advanced Python for Data Science', 'oops-class.json'],
#  [0.7822731865770446,
#   'Exception Handling in Python in Hindi | Python Exception Handling',
#   'exception handling.json'],
#  [0.7822731865770446,
#   ' Python Exception Handling - GeeksforGeeks',
#   'exception handling.json'],
#  [0.7814146115911749, ' Copy dictionary method', 'dictionary.json'],
#  [0.7814146115911749, ' Copy dictionary method', 'dictionary.json'],
#  [0.7808276244876049, 'Python Generators', 'iterator-generator-decorator.json'],
#  [0.7785215124739869,
#   'Python Itertools javapoint',
#   'oops-magic method-itertools.json'],
#  [0.7785215124739869,
#   'Python Itertools gfg',
#   'oops-magic method-itertools.json'],
#  [0.7774597024067095,
#   'Python Modules and Packages - An Introduction',
#   'module.json'],
#  [0.7758960591527729, 'Python Programming | Classes', 'oops-class.json'],
#  [0.7683745198399006,
#   'Advanced Python: What Are Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.7672226877087731, 'Pop dictionary method', 'dictionary.json'],
#  [0.7672226877087731, 'Pop dictionary method', 'dictionary.json'],
#  [0.7656299571127004, 'Advanced Python classes', 'oops-class.json'],
#  [0.7623593857313549, 'Change list items', 'list.json'],
#  [0.7619594840442678, 'Join lists', 'list.json'],
#  [0.7619594840442678, 'Join Lists', 'list.json'],
#  [0.7618252095551874, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.7618252095551874, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.7590130048593599, 'Nested Dictionaries', 'dictionary.json'],
#  [0.7590130048593599, ' Nested Dictionaries', 'dictionary.json'],
#  [0.7589637257548838, 'Checking for membership in lists', 'list.json'],
#  [0.7589637257548838, ' Checking for membership in lists', 'list.json'],
#  [0.7557949039543748, 'Python Modules Inbuilt', 'module.json'],
#  [0.7557949039543748, 'Python Modules', 'module.json'],
#  [0.7557949039543748, 'Python Modules', 'module.json'],
#  [0.7557949039543748, 'Python - Modules', 'module.json'],
#  [0.7557949039543748, 'Module in Python (Hindi)', 'module.json'],
#  [0.7540488328958637, 'Filtering the lists', 'list.json'],
#  [0.7540488328958637, ' Filtering the lists', 'list.json'],
#  [0.7495673919252471, 'Get dictionary method', 'dictionary.json'],
#  [0.7495673919252471, 'Get dictionary method', 'dictionary.json'],
#  [0.7490678918957377,
#   ' Accessing elements of a nested dictionary',
#   'dictionary.json'],
#  [0.7490678918957377,
#   ' Accessing elements of a nested Dictionary',
#   'dictionary.json'],
#  [0.7478908815474533, ' Remove list items', 'list.json'],
#  [0.7476576667134481, ' Add list items', 'list.json'],
#  [0.7417622473235193, 'Clear dictionary method', 'dictionary.json'],
#  [0.7417622473235193, 'Clear dictionary method', 'dictionary.json'],
#  [0.7378594335429698, ' Update dictionary method', 'dictionary.json'],
#  [0.7378594335429698, ' Update dictionary method', 'dictionary.json'],
#  [0.7326796341255305, 'Accessing elements of a dictionary', 'dictionary.json'],
#  [0.7326796341255305,
#   '. Accessing elements of a dictionary',
#   'dictionary.json'],
#  [0.7290333304060858,
#   'Advance Python Series-Magic Methods In Classes',
#   'oops-magic method-itertools.json'],
#  [0.7245531449636197, 'Reversing lists', 'list.json'],
#  [0.7245531449636197, ' Reversing the lists', 'list.json'],
#  [0.7153706445946347, 'Loop lists', 'list.json'],
#  [0.7153706445946347, ' Loop lists', 'list.json'],
#  [0.7131121369244312, 'Classes and Objects (OOPS)', 'oops-class.json'],
#  [0.708272105829516, 'What is Modular Programming?', 'module.json'],
#  [0.7048301723043904,
#   'Functions creating iterators for efficient loopingÂ¶',
#   'oops-magic method-itertools.json'],
#  [0.694115242212376, 'Data model', 'oops-magic method-itertools.json'],
#  [0.6766619982129028, 'What Are Access Lists? ', 'list.json'],
#  [0.6728750560607747, 'List methods', 'list.json'],
#  [0.6728750560607747, 'List methods', 'list.json'],
#  [0.6676647791552773, ' Access list items', 'list.json'],
#  [0.6097292478692428, 'Lambda Functions', 'function-lambda.json'],
#  [0.5903487932403636, 'Magic Methods', 'oops-magic method-itertools.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json']]

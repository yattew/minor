# %%
import json
from pathlib import Path
import gensim
from gensim.models import Word2Vec

from stopstem import *
import os
 

path = "C://Users//ganes//Desktop//mini//reference"
dir_list = os.listdir(path)
#print(dir_list)
matrix=[]
for i in dir_list:
    with open("../reference/"+i,'r') as data_source:
        try:
            data1 = data_source.read()
            stemmed = tokenizeAndStem(data1)
            matrix.append(stemmed)
        except:
            print(i)
        
#print(matrix)
model1 = Word2Vec(matrix, min_count = 1, window = 5, sg=1,epochs = 20,vector_size=100)
# Out:
# 3.11.txt
# 3.2.txt
# 3.4.txt
# 3.5.txt
# 3.6.txt
# 3.7.txt
# 3.8.txt
# 3.9.txt
# changelog.txt
# decimal.txt
# instrumentation.txt
# logging-cookbook.txt
# math.txt
# nntplib.txt
# random.txt
# stable.txt
# unicode.txt

# %%
from cosines import cacCosine

print(model1.wv)
def sim(q1,q2):
    a1 = q1.split()
    import numpy as np
    v1 = np.array([0.0]*100)
    v2 = np.array([0.0]*100)
    c1=1
    for i in a1:
        try:
            v1+=model1.wv[i]
            c1+=1
        except:
            pass
    v1/=c1
    a2 = q2.split()
    c2=1
    for i in a2:
        try:
            v2+=model1.wv[i]
            c2+=1
        except:
            pass
    v2/=c2
    return cacCosine(list(v1),list(v2))
import os
BASE_DIR = Path(os.getcwd()).resolve().parent

def findSimilar(listOfDocs,query):
    #dic={stemmdtitle:[title,link,file]}
    dic={}
    maxi=[]
    for i in listOfDocs:
        if i[-4::]=='json':
            with open(BASE_DIR/('jsons/'+i)) as f:
                data=json.load(f)
                for j in data:
                    for k in data[j]['videos'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['videos'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
                    for k in data[j]['reading'].keys():
                        tok = ' '.join(tokenizeAndStem(k))
                        dic[tok]=[k,data[j]['reading'][k],i]
                        maxi.append([sim(tok,' '.join(tokenizeAndStem(query))),k,i])
    return dic,maxi
# Out:
# KeyedVectors<vector_size=100, 29341 keys>

# %%
from pprint import pprint as p
l = os.listdir("C://Users//ganes//Desktop//mini//jsons")
q1 = "Python Program to Print Natural Numbers Using While and For Loop in Hindi - Tutorial #22"
q2 = "Print the first 10 natural numbers using for loop"
dic,maxi = findSimilar(l,"sum of first few integers")
p(sorted(maxi,reverse=True))
# Out:
# [[0.7823320455293896, 'High order functions in Python', 'function.json'],
#  [0.7177875313636869,
#   ' Professional Error Handling With Python',
#   'exception handling.json'],
#  [0.7142046962516586,
#   'Python Tutorials - Namespace and Variable Scope',
#   'iterator-generator-decorator.json'],
#  [0.7089785777366698,
#   'Functions creating iterators for efficient loopingÂ¶',
#   'oops-magic method-itertools.json'],
#  [0.7082951174901739,
#   ' Exception Handling in Python | CUET Computer Science',
#   'exception handling.json'],
#  [0.6904584218833842,
#   'Building Lambda functions with Python',
#   'function-lambda.json'],
#  [0.665906725685963,
#   ' Exception Handling in Python || Syntax Error vs Runtime Error',
#   'exception handling.json'],
#  [0.6530496067267176,
#   ' 30. Errors and Exception Handling | Python Tutorial',
#   'exception handling.json'],
#  [0.6504048314528397,
#   'Python Tutorial: Itertools Module - Iterator Functions for Efficient '
#   'Looping',
#   'oops-magic method-itertools.json'],
#  [0.6446024613341469,
#   ' NZEC error in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.6385415420964525,
#   'Python Program to Count Total Odd and Even Numbers in List - In Hindi',
#   'loop-for.json'],
#  [0.6353196780364344,
#   ' Advanced Python- Exception Handling Detailed Explanation In Python',
#   'exception handling.json'],
#  [0.6350414660119353,
#   ' finally keyword in Python - GeeksforGeeks',
#   'exception handling.json'],
#  [0.627236816575129,
#   'Python Program to Print Sum of n Odd Natural Numbers | 1+3+5+7+..+n Series '
#   'Calculation in Python',
#   'loop-for.json'],
#  [0.6269833925463628,
#   'Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.6269833925463628,
#   ' Check if a key exists in a dictionary',
#   'dictionary.json'],
#  [0.6257155819511773,
#   ' Python Functions Tutorial | Working With Functions In Python | Python '
#   'Training | Eâ€¦',
#   'function.json'],
#  [0.6235159884357685,
#   'Frequently Asked Python Program 17: Multiply All Numbers in the List',
#   'loop-while.json'],
#  [0.6220235440765718,
#   '6. INTRODUCTION TO EXCEPTION HANDLING IN PYTHON',
#   'exception handling.json'],
#  [0.6202965503184726,
#   'Program to Print First 10 Natural Numbers - In Hindi',
#   'loop-while.json'],
#  [0.618548451850441,
#   'Python Program to Print First 10 Natural Numbers',
#   'loop-while.json'],
#  [0.618054639466352,
#   'Python program counts the number of even and odd numbers from a series of '
#   'numbers',
#   'loop-for.json'],
#  [0.6175273361803836,
#   'Frequently Asked Python Program 20:Check String is Palindrome or Not',
#   'loop-for.json'],
#  [0.6169080472156275,
#   'Python Tutorial: Iterators and Iterables - What Are They and How Do They '
#   'Work?',
#   'iterator-generator-decorator.json'],
#  [0.6159315713638308,
#   'Python Program to Calculate and print sum of Even and Odd integers of first '
#   'Natural n Numbers #15',
#   'loop-while.json'],
#  [0.6109259483801289,
#   'Lesson - 50 : Python Advanced - Python OOPs : Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.6108233755454291,
#   'Frequently Asked Python Program 4: Print Fibonacci Series',
#   'loop-for.json'],
#  [0.6090349774675051,
#   'Python Itertools | Hindi | Part 1 | Python for Beginner to Expert | In '
#   'Detail Explanation',
#   'oops-magic method-itertools.json'],
#  [0.6076767897192311,
#   'Advanced Python || Operator Overloading Part - 1 ',
#   'oops-operator-overloading.json'],
#  [0.6070538483208369,
#   'Python - Object Oriented Programming | Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.6070538483208369,
#   'Operator Overloading in Python | Object Oriented Programming in Python',
#   'oops-operator-overloading.json'],
#  [0.606028463417367,
#   'INTRODUCTION TO EXCEPTION HANDLING IN PYTHON ',
#   'exception handling.json'],
#  [0.6053865337456921,
#   'Functions And Docstrings | Python Tutorials For Absolute Beginners In Hindi '
#   '#23',
#   'function.json'],
#  [0.6043388379437149, 'Advanced features of Python Functions', 'function.json'],
#  [0.6043388379437149,
#   'Advanced Features in Python Functions | Python Functions Advanced',
#   'function.json'],
#  [0.6037087985212151,
#   'Lambda Functions - Advanced Python 08',
#   'function-lambda.json'],
#  [0.603282029442636,
#   'Working with Own Modules - Python Advanced Tutorial Series - 37',
#   'module.json'],
#  [0.5971541778849696,
#   'Python Iterators | Iterables and Iterators in Python | Python Tutorial for '
#   'Beginners | Edureka',
#   'iterator-generator-decorator.json'],
#  [0.59599149461162,
#   'Python Advanced Modules Made Easy â€” Part 1',
#   'module.json'],
#  [0.5958998088579484,
#   '#59 Python Tutorial for Beginners | Operator Overloading | Polymorphism',
#   'oops-operator-overloading.json'],
#  [0.5945845379483881,
#   '4. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.5928190352360814,
#   '5 Advanced Functions in Itertools To Simplify Iterations in Python',
#   'oops-magic method-itertools.json'],
#  [0.5922959001316558,
#   'Python : Operator Overloading a specific type',
#   'oops-operator-overloading.json'],
#  [0.5904386429510105,
#   'Advanced Functional Programming in Python: lambda',
#   'function-lambda.json'],
#  [0.5897491278016203,
#   'Advanced indexing Operations in Numpy Arrays',
#   'array.json'],
#  [0.5888525685635998,
#   '. Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.5888525685635998,
#   ' Exception Handling and Builtin Exception in Python (Hindi)',
#   'exception handling.json'],
#  [0.5856215376063062,
#   'Python program to display all numbers within a range except the prime '
#   'numbers',
#   'loop-for.json'],
#  [0.584470306659723,
#   'Python program to calculate the sum of all the odd numbers within the given '
#   'range',
#   'loop-for.json'],
#  [0.5834232594424341,
#   '# 13 Operator Overloading in Python with Example',
#   'oops-operator-overloading.json'],
#  [0.5817765797332318,
#   'Advanced Python Series - Iterators Vs Generators',
#   'iterator-generator-decorator.json'],
#  [0.5796018523951576,
#   'Modules in Python Explained | Python Built in Modules | Python Tutorial for '
#   'Beginners | Simplilearn',
#   'module.json'],
#  [0.5791369931723399,
#   '[Hindi] Lambda functions in python in Hindi | Advanced python in Hindi',
#   'function-lambda.json'],
#  [0.5787589598828456,
#   'Advance Python Modules - How to Create & Import with dir Function',
#   'module.json'],
#  [0.5767341010588983, 'How to add an item to a list in Python', 'list.json'],
#  [0.5766932029260673,
#   'Function arguments in detail - Advanced Python 18 - Programming Tutorial',
#   'function.json'],
#  [0.5750776767549993,
#   'Operator Overloading & Dunder Methods | Python Tutorials For Absolute '
#   'Beginners',
#   'oops-operator-overloading.json'],
#  [0.5744672023098196, 'Python Functions Advanced', 'function.json'],
#  [0.5744672023098196, 'Python Advanced Functions', 'function.json'],
#  [0.5744209846197347,
#   'What is Modules in Python - Python Tutorials for Beginners',
#   'module.json'],
#  [0.573816615523692,
#   'What Are Python Modules? | Modules In Python | Python Tutorial For '
#   'Beginners | Edureka',
#   'module.json'],
#  [0.570935822514391,
#   'Difference Between Iterator VS Generator',
#   'iterator-generator-decorator.json'],
#  [0.569527525379442,
#   '[Language skills Python] Exercise Lambda Expressions - Advanced [Tutorial]',
#   'function-lambda.json'],
#  [0.5682827229502221,
#   '#61 Python Tutorial for Beginners | Iterator',
#   'iterator-generator-decorator.json'],
#  [0.5677330545542448,
#   ' Day 24: Advanced Exception Handling and Raising Exceptions',
#   'exception handling.json'],
#  [0.567731059964393,
#   'Polymorphism in Python | Lecture 58 | Method Overloading | Method '
#   'Overriding | Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.5673639948443321,
#   'Python Operator Overloading OOPS',
#   'oops-operator-overloading.json'],
#  [0.5668311118589235, 'Advanced Python for Data Science', 'oops-class.json'],
#  [0.5666454550507474,
#   'Python Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.5666454550507474,
#   'Python Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.5666454550507474,
#   'Python - Operator Overloading',
#   'oops-operator-overloading.json'],
#  [0.5666454550507474,
#   'Overloading Operators in Python',
#   'oops-operator-overloading.json'],
#  [0.5666454550507474,
#   'Operator overloading in Python',
#   'oops-operator-overloading.json'],
#  [0.5666454550507474,
#   'Operator Overloading in Python',
#   'oops-operator-overloading.json'],
#  [0.5666454550507474,
#   'OPERATOR OVERLOADING IN PYTHON',
#   'oops-operator-overloading.json'],
#  [0.5657404018872553,
#   'Operator Overloading in Python (Hindi)',
#   'oops-operator-overloading.json'],
#  [0.5655049570596961,
#   'Python 3 Programming Tutorial | #1 Introduction of Python Lambda and '
#   'Anonymous Function',
#   'function-lambda.json'],
#  [0.5644931276753319,
#   'Lambda Functions with Practical Examples in Python',
#   'function-lambda.json'],
#  [0.5640209289523187,
#   'ANONYMOUS FUNCTIONS (LAMBDA) - PYTHON PROGRAMMING',
#   'function-lambda.json'],
#  [0.563116181389398,
#   'Python OOP Tutorials | Operator Overloading in Python | Python Operator '
#   'Overloading',
#   'oops-operator-overloading.json'],
#  [0.5617043176423545,
#   ' 8. Exception handling â€” Advance Python Tutorials documentation',
#   'exception handling.json'],
#  [0.5616628316063902,
#   '. Python Programming Tutorial | Exception Handling in Python | '
#   'GeeksforGeâ€¦',
#   'exception handling.json'],
#  [0.5615848277215345,
#   '  #63 Python Tutorial for Beginners | Exception Handling',
#   'exception handling.json'],
#  [0.560723691761539,
#   'Lambda Function in Python - In Hindi',
#   'function-lambda.json'],
#  [0.5603956231746122,
#   'Immediate Python- Functions, Modules, Classes and Exceptions',
#   'oops-class.json'],
#  [0.5596544488705236,
#   'Top 5 Python Modules You Should Know in 2023',
#   'module.json'],
#  [0.5589673211506659, 'Arrays in python| Python for beginners', 'array.json'],
#  [0.5579928448923377,
#   ' Exceptions in Python - Advanced Python 09 - Programming Tutorial',
#   'exception handling.json'],
#  [0.5579664025869883,
#   ' Advanced Python Series- Custom Exception Handling In Python',
#   'exception handling.json'],
#  [0.5571169377646027, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.5571169377646027, 'Python Lambda Functions', 'function-lambda.json'],
#  [0.5570969941915572, 'LearnPython Python Functions', 'function.json'],
#  [0.5570642505580324,
#   ' Python Exception Handling - GeeksforGeeks',
#   'exception handling.json'],
#  [0.55676613530942,
#   'Python Programming Tutorial - Iterators (Part-1)',
#   'iterator-generator-decorator.json'],
#  [0.5567490679186535,
#   'Python Generators vs Iterators',
#   'iterator-generator-decorator.json'],
#  [0.5566235620825474,
#   ' Anonymous/Lambda Functions In Python | Python Tutorials For Absolute Bâ€¦',
#   'function-lambda.json'],
#  [0.5562109913134002,
#   'How to Use Python Lambda Functions? 6 Comprehensive Aspects',
#   'function-lambda.json'],
#  [0.5555765065409549,
#   'Exception Handling in Python',
#   'exception handling.json'],
#  [0.5555235478578303,
#   'Exception Handling in Python in Hindi | Python Exception Handling',
#   'exception handling.json'],
#  [0.5554601435159526,
#   'Operator Overloading & Dunder Methods | Python Tutorials For Absolute '
#   'Beginners In Hindi #67',
#   'oops-operator-overloading.json'],
#  [0.555007393371635,
#   'Python Lambda | Advanced Python | Tutorial 18',
#   'function-lambda.json'],
#  [0.5546583487418685,
#   'Python Programming - Calculate the Number of Digits and Letters in a String '
#   '- Updated 2021',
#   'loop-for.json'],
#  [0.5544891970647667,
#   'Advanced Python Programming - Regular Expressions Part 1',
#   'regularexpression.json'],
#  [0.5519417547463386,
#   ' Python Functions | Python Tutorial for Absolute Beginners #1',
#   'function.json'],
#  [0.5514489509929479,
#   'Python Program for Series Calculation 1*1 + 2*2 + 3*3 +..+n | Series '
#   'Calculation Program in Python',
#   'loop-while.json'],
#  [0.5512617240414985,
#   'Python Tutorial: Decorators - Dynamically Alter The Functionality Of Your '
#   'Functions',
#   'iterator-generator-decorator.json'],
#  [0.5509530250370206,
#   'Tutorial: Lambda Functions in Python',
#   'function-lambda.json'],
#  [0.5505267489116471,
#   'Operator Overloading In Python with Easy Examples',
#   'oops-operator-overloading.json'],
#  [0.5490662419965999, 'Lambda Functions', 'function-lambda.json'],
#  [0.5484316390747274,
#   'Python Lambda/Anonymous Functions ',
#   'function-lambda.json'],
#  [0.548315359221038,
#   'Python Lambda Function | Anonymous Function In Python | Python Tutorial | '
#   'Edureka',
#   'function-lambda.json'],
#  [0.5477775997265305,
#   'Check the validity of a Password in Python',
#   'loop-for.json'],
#  [0.5471545618189054,
#   'Top 10 Most Popular Python Libraries | Yaswanth | GeeksforGeeks',
#   'module.json'],
#  [0.546619253616178,
#   'Python Itertools For Advanced Iteration',
#   'oops-magic method-itertools.json'],
#  [0.5466124660233863,
#   'Lambda in Python - Advanced Python 08 - Programming Tutorial - Map Filter '
#   'Reduce',
#   'function-lambda.json'],
#  [0.5464031117977545,
#   'Python: Lambda, Map, Filter, Reduce Functions',
#   'function-lambda.json'],
#  [0.5463632378757737,
#   '#42 Python Tutorial for Beginners | Anonymous Functions | Lambda',
#   'function-lambda.json'],
#  [0.5462793408517609,
#   ' Python Tutorial: Using Try/Except Blocks for Error Handling',
#   'exception handling.json'],
#  [0.5459985256454596,
#   'Decorators in Python - Advanced Python 13 - Programming Tutorial',
#   'iterator-generator-decorator.json'],
#  [0.5459818043261084,
#   'Python modules: Exercises, Practice, Solution',
#   'module.json'],
#  [0.545918264305771,
#   'Iterators and Generators',
#   'iterator-generator-decorator.json'],
#  [0.545918264305771,
#   'Iterators & Generators',
#   'iterator-generator-decorator.json'],
#  [0.545918264305771,
#   'Generators and Iterators',
#   'iterator-generator-decorator.json'],
#  [0.5456356060039441,
#   '#45 Python Tutorial for Beginners | Modules',
#   'module.json'],
#  [0.5453839969384289,
#   'OVERLOADING (POLYMORPHISM) - PYTHON PROGRAMMING',
#   'oops-operator-overloading.json'],
#  [0.5453780889622949, ' Add set items', 'set.json'],
#  [0.545143491541858, 'Nested if Condtion', 'condition-pass.json'],
#  [0.5447935174008027, 'TutorialsPoint Python Functions ', 'function.json'],
#  [0.5445116321523328,
#   'Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials',
#   'iterator-generator-decorator.json'],
#  [0.5440549952146232, 'Python Iterators', 'iterator-generator-decorator.json'],
#  [0.5436486416056384, 'Python Operators', 'oops-operator-overloading.json'],
#  [0.5431366635176181,
#   'Novice to Advanced RegEx in Less-than 30 Minutes + Python',
#   'regularexpression.json'],
#  [0.5426503136398416,
#   'Python Intermediate: Lambda Functions',
#   'function-lambda.json'],
#  [0.5421642710782114,
#   'Python program that accepts a string and calculates the number of digits '
#   'and letters',
#   'loop-for.json'],
#  [0.5414017030681747,
#   ' Exception handling tips in Python âš\xa0 Write better Python code part 7',
#   'exception handling.json'],
#  [0.5411154586676592,
#   '[Hindi] Iterators, Iterables and Generators in python explained | Advanced '
#   'python tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.5411154586676592,
#   ' Iterators, Iterables and Generators in python explained | Advanced python '
#   'tutorials in Hindi',
#   'iterator-generator-decorator.json'],
#  [0.5410195740963175,
#   'Python program to check the validity of password input by users',
#   'loop-for.json'],
#  [0.540877515917102, ' exceptions.Exception', 'exception handling.json'],
#  [0.5401984844214778, 'Programiz Python Functions ', 'function.json'],
#  [0.5401444360319659, 'Arrays in python: Array Advance Game', 'array.json'],
#  [0.5396977242515669,
#   ' Try Except Exception Handling In Python | Python Tutorials For Absolute '
#   'Bâ€¦ ',
#   'exception handling.json'],
#  [0.539200582523889, 'Python Functions Edureka ', 'function.json'],
#  [0.5389406844304797,
#   ' #32 Python Tutorial for Beginners | Functions in Python',
#   'function.json'],
#  [0.5378323715462328,
#   ' Lambda Expressions & Anonymous Functions || Python Tutorial || Learn Pâ€¦',
#   'function-lambda.json'],
#  [0.5376714087299094,
#   'Generators and Iterators in python | python tutorial',
#   'iterator-generator-decorator.json'],
#  [0.537428896683743,
#   'Python program to check if a given number is an Armstrong number',
#   'loop-for.json'],
#  [0.536983693687966,
#   'Itertools in Python - Advanced Python 07 - Programming Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.5363970415554586, 'PythonDocs Python Function', 'function.json'],
#  [0.5362418141401073,
#   'Advanced Date Matching with Regex - Including leap years',
#   'regularexpression.json'],
#  [0.5353169299200465,
#   'Python Advanced Tutorial 4 - Regular Expressions',
#   'regularexpression.json'],
#  [0.5351910658456753, 'GFG Python Functions ', 'function.json'],
#  [0.5346402363164572, ' Add list items', 'list.json'],
#  [0.5344286134691968, 'Python Conditions', 'condition-pass.json'],
#  [0.5344286134691968, 'Python Condition', 'condition-pass.json'],
#  [0.5343855930041992,
#   'Object Oriented Porgramming in Python',
#   'oops-class.json'],
#  [0.5338473554323838,
#   'Regular Expressions in Python - FULL COURSE (1 HOUR) - Programming Tutorial',
#   'regularexpression.json'],
#  [0.5337577651838332,
#   'Python Program to Reverse of a Number - In Hindi',
#   'loop-while.json'],
#  [0.5333521933916422, 'Python Functions ', 'function.json'],
#  [0.5332266502167071,
#   'Program to find the product of the given number of consecutive elements',
#   'loop-while.json'],
#  [0.5330510701185774,
#   'Python program to find all the prime numbers in the given range- by Mahesh '
#   'Huddar',
#   'loop-for.json'],
#  [0.5330321040136312,
#   'Exceptions in Python || Python Tutorial || Learn Python Programming',
#   'exception handling.json'],
#  [0.5325991350319287,
#   'Python program to calculate the sum of first N even numbers',
#   'loop-while.json'],
#  [0.5323440370318842,
#   'Function Decorator in Python (Hindi)',
#   'iterator-generator-decorator.json'],
#  [0.5322289160282246,
#   'Lambda Function in Python -     Example Syntax',
#   'function-lambda.json'],
#  [0.530839684232406,
#   'Python program to print a multiplication table of a given number',
#   'loop-for.json'],
#  [0.5306079386867654,
#   'Print the first 10 natural numbers using for loop',
#   'loop-for.json'],
#  [0.5305696063732286,
#   'Comparison of Iterators and Generators in python',
#   'iterator-generator-decorator.json'],
#  [0.529665565657214,
#   'Itertools - Advanced Python 07',
#   'oops-magic method-itertools.json'],
#  [0.5280755188380399,
#   '#3: Python lambda (anonymous) Functions | Python Best Practices',
#   'function-lambda.json'],
#  [0.5278466167918164,
#   'Regular Expressions | Python Tutorials For Absolute Beginners',
#   'regularexpression.json'],
#  [0.5263274527517233, 'Python : Advance built in modules', 'module.json'],
#  [0.5260208450346328,
#   'Iterator And Generator In Python | Python Generators And Iterators '
#   'Explained | Python | Simplilearn',
#   'iterator-generator-decorator.json'],
#  [0.5252214907027618, 'JavaPoint Python Functions ', 'function.json'],
#  [0.5248143988452587,
#   'Python Program to check Armstrong Number',
#   'loop-while.json'],
#  [0.5248143988452587,
#   'Python Program to Check Armstrong Number',
#   'loop-while.json'],
#  [0.5248143988452587,
#   'Python Program to Check Armstrong Number',
#   'loop-for.json'],
#  [0.5240662412535089, ' Max sum path in two arrays', 'array.json'],
#  [0.5238092340468545,
#   'What are Python Iterators and Generators?',
#   'iterator-generator-decorator.json'],
#  [0.5238092340468545,
#   'PYTHON ITERATORS AND GENERATORS',
#   'iterator-generator-decorator.json'],
#  [0.5238092340468545,
#   'Iterators and Generators in Python',
#   'iterator-generator-decorator.json'],
#  [0.5238092340468545,
#   'Generators & Iterators in python',
#   'iterator-generator-decorator.json'],
#  [0.5234478360479231,
#   'Python Itertools Module & Its Iteration Tutorial #38',
#   'oops-magic method-itertools.json'],
#  [0.5229651362613722,
#   'Using Python External & Built In Modules | Python Tutorials For Absolute '
#   'Beginners In Hindi',
#   'module.json'],
#  [0.5228172855880637,
#   'Python Modules and Packages - An Introduction',
#   'module.json'],
#  [0.5227332393381056,
#   'Python Program to Print Multiplication Table of a Number ( User Input )',
#   'loop-for.json'],
#  [0.5221228075880555,
#   'Generators In Python | Python Tutorials For Absolute Beginners In Hindi #72',
#   'iterator-generator-decorator.json'],
#  [0.5211966708432503,
#   'Python program to find the factorial of a given number',
#   'loop-for.json'],
#  [0.520913674560277,
#   'Python program to convert the month name to a number of days',
#   'loop-for.json'],
#  [0.520913674560277,
#   'Python program to convert month name to a number of days',
#   'loop-for.json'],
#  [0.5199087110116811,
#   'Advanced Python: Itertools Library â€” The Gem Of Python Language',
#   'oops-magic method-itertools.json'],
#  [0.5184504366219567, 'Count pairs with given sum', 'array.json'],
#  [0.5180962364845868,
#   'Lambda Functions in Python | Python Tutorial #37',
#   'function-lambda.json'],
#  [0.5173905345232972,
#   'Python RegEx: re.match(), re.search(), re.findall() with Example',
#   'regularexpression.json'],
#  [0.5171349635438076,
#   'Classes & Objects in Python | Python OOP Tutorial | Python for Beginners',
#   'oops-class.json'],
#  [0.5169548856331827,
#   'Decorators In Python | Python Tutorials For Absolute Beginners In Hindi #51',
#   'iterator-generator-decorator.json'],
#  [0.5161657158353631,
#   'Python OOP Tutorial 5: Special (Magic/Dunder) Methods',
#   'oops-magic method-itertools.json'],
#  [0.5154916576422514,
#   'Python Intermediate Series: Python Modules',
#   'module.json'],
#  [0.5147658959197211,
#   'Write a program to cyclically rotate an array by one| Love Babbar DSA Sheet',
#   'array.json'],
#  [0.514378676921381,
#   'Hindi Magic/Dunder Methods In Python? | Object Oriented Programming Using '
#   'Python Tutorial',
#   'oops-magic method-itertools.json'],
#  [0.5140138000041998,
#   'Intermediate Python Tutorial #5 - Lambda Functions',
#   'function-lambda.json'],
#  [0.512647356173309,
#   'Python program to print all the even numbers within the given range',
#   'loop-for.json'],
#  [0.5114374724459002,
#   '#62 Python Tutorial for Beginners | Generators',
#   'iterator-generator-decorator.json'],
#  [0.5108322273738501, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.5108322273738501, 'Introduction to python dictionaries', 'dictionary.json'],
#  [0.5087427534384633,
#   'Write a program to cyclically rotate an array by one',
#   'array.json'],
#  [0.507606962655998,
#   '#60 Python Tutorial for Beginners | Method Overloading and Method '
#   'Overriding',
#   'oops-operator-overloading.json'],
#  [0.5072548514309646, '#27 Python Tutorial for Beginners', 'array.json'],
#  [0.5072548514309646, ' #26 Python Tutorial for Beginners', 'array.json'],
#  [0.5068509785278797,
#   'Python Itertools | Itertools in Python | Python Tutorial for Beginners | '
#   'Edureka',
#   'oops-magic method-itertools.json'],
#  [0.5063760489864138, 'Nested if condition', 'condition-pass.json'],
#  [0.5035980925923421,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.5035980925923421,
#   ' Exceptions in Python | Python Programming Tutorial',
#   'exception handling.json'],
#  [0.5031575371943148,
#   'Regular Expressions in Python | Python Tutorial for Beginners | Naresh IT',
#   'regularexpression.json'],
#  [0.5028740902194233,
#   'Python Program to find the sum of a Series 1/1! + 2/2! + 3/3! + 4/4! '
#   '+â€¦â€¦.+ n/n!',
#   'loop-while.json'],
#  [0.5023831128317229, 'Create and Import Python Modules', 'module.json'],
#  [0.5023304292757867,
#   'Find missing number in an array in python',
#   'array.json'],
#  [0.5017716461983428,
#   "HINDI BIT-PY Beginner's Python Course | Part #36 | Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.5014541406404301,
#   '#44 Python Tutorial for Beginners | Decorators',
#   'iterator-generator-decorator.json'],
#  [0.500691771583048,
#   'Lambda Expression : Python tutorial 150',
#   'function-lambda.json'],
#  [0.500532506846704, 'Write a program to sort the given array', 'array.json'],
#  [0.5003954064398063,
#   '#49 Python Tutorial for Beginners| Class and Object',
#   'oops-class.json'],
#  [0.49767296920203474,
#   'Lambda Operator, filter, reduce and map',
#   'function-lambda.json'],
#  [0.49648253998942743,
#   'Python Program to Print Natural Numbers Using While and For Loop in Hindi - '
#   'Tutorial #22',
#   'loop-for.json'],
#  [0.4958440547897045,
#   ' User-defined Exceptions in Python with Examples - GeeksforGeeks',
#   'exception handling.json'],
#  [0.49435649441295915,
#   'What are Modules in Python and How to Define Modules in Python with '
#   'Examples',
#   'module.json'],
#  [0.49420367042529856,
#   'Python program to get the Fibonacci series between 0 to 50',
#   'loop-for.json'],
#  [0.49338683230032193,
#   "Python's Magical Itertools Module",
#   'oops-magic method-itertools.json'],
#  [0.4930555081782548,
#   'Advance Python Series- Magic Methods',
#   'oops-class.json'],
#  [0.49273514088872783,
#   'Using Modules & Pip In Python | Python Tutorials For Absolute Beginners In '
#   'Hindi #3',
#   'module.json'],
#  [0.49266863961356355,
#   '@Decorators in Python (Advanced)',
#   'iterator-generator-decorator.json'],
#  [0.4921425625539242,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'oops-magic method-itertools.json'],
#  [0.4921425625539242,
#   'Magic Methods & Dunder - Advanced Python Tutorial #1',
#   'function.json'],
#  [0.4918859394297531,
#   'REGEX (REGULAR EXPRESSIONS) WITH EXAMPLES IN DETAIL | Regex Tutorial',
#   'regularexpression.json'],
#  [0.4908596681281985, 'Top 18 Most Useful Python Modules', 'module.json'],
#  [0.49075060358987055,
#   'Python program to display numbers from a list using a for loop.',
#   'loop-for.json'],
#  [0.49039340129606834,
#   'How to Use Python Lambda Functions',
#   'function-lambda.json'],
#  [0.48960227224351266,
#   'Advanced Regular Expressions',
#   'regularexpression.json'],
#  [0.48860660273904855,
#   'Difference between Method Overloading and Method Overriding in Python',
#   'oops-operator-overloading.json'],
#  [0.4885185050900828,
#   'Advanced String Searching including RegEx (Pandas Tutorials 06)',
#   'regularexpression.json'],
#  [0.48832339482340537, '384 Shuffle an array', 'array.json'],
#  [0.4875314284671974, 'Maximum Index', 'array.json'],
#  [0.4855692925205025,
#   'Explore the magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.48446148945837136,
#   'Lambda and filter in Python Examples',
#   'function-lambda.json'],
#  [0.482964553984487,
#   'Advanced Python: What Are Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.48241939574745796, 'Arrays in Python Programming', 'array.json'],
#  [0.48204812286339643,
#   'Regular Expressions (RegEx) in Python : Advanced Concepts',
#   'regularexpression.json'],
#  [0.482006431529387, 'Python Modules | Learn Coding', 'module.json'],
#  [0.4814757661117479,
#   'Python Programming for Intermediate programmer',
#   'oops-class.json'],
#  [0.4809172099764112,
#   'Pair with the given sum in a sorted array',
#   'array.json'],
#  [0.4801787411536654,
#   "A Guide to Python's Secret Superpower: Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.4800886980359636, 'Python Modules Inbuilt', 'module.json'],
#  [0.4796893385679672, 'Immediate Python Programming', 'oops-class.json'],
#  [0.4796872529646971, 'Introduction to if else', 'condition-pass.json'],
#  [0.4796872529646971, 'Introduction to if else', 'condition-pass.json'],
#  [0.4787061895095468, 'Join sets', 'set.json'],
#  [0.4787061895095468, 'Join sets', 'set.json'],
#  [0.4784753647848859,
#   'Python Programming 19 - Remove Elements From List within for Loop',
#   'list.json'],
#  [0.4775223887608782,
#   'Python | Method Overloading',
#   'oops-operator-overloading.json'],
#  [0.47731230635979355, 'Write a program to reverse an array', 'array.json'],
#  [0.4754546466579045,
#   'Itertools in Python 3, By Example',
#   'oops-magic method-itertools.json'],
#  [0.4742858487030956,
#   'Python program to check if a string is a palindrome or not',
#   'loop-for.json'],
#  [0.47403377998891805,
#   'Understanding Python: Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.47376859703613444,
#   " Python Functions (The Only Guide You'll Need) #12",
#   'function.json'],
#  [0.4734630969684458, 'Expert Python Tutorial', 'oops-class.json'],
#  [0.4730874992393497,
#   'Overloading < operator',
#   'oops-operator-overloading.json'],
#  [0.4730874992393497, 'Operator Overloading', 'oops-operator-overloading.json'],
#  [0.47072458723045213,
#   'Expert Python Tutorial #2 - Dunder/Magic Methods & The Python Data Model',
#   'oops-magic method-itertools.json'],
#  [0.4697502185407554,
#   'How to print even numbers in the given range in Python',
#   'loop-for.json'],
#  [0.46957002844290713, 'Module in Python (Hindi)', 'module.json'],
#  [0.46836765788469154, 'Python Modules', 'module.json'],
#  [0.46836765788469154, 'Python Modules', 'module.json'],
#  [0.46836765788469154, 'Python - Modules', 'module.json'],
#  [0.4683628949115802,
#   'Python RegEx | Python Regular Expressions Tutorial | Python Tutorial | '
#   'Python Training ',
#   'regularexpression.json'],
#  [0.46620790080874414, 'Python Classes and Obejcts', 'oops-class.json'],
#  [0.46562960126628006,
#   'Puthon OOP Tutorial 1: Classes and Instances',
#   'oops-class.json'],
#  [0.4656020849195639, 'Python Immediate Tutorial #1', 'oops-class.json'],
#  [0.46551677664616525, 'Intermediate Programming with Python', 'module.json'],
#  [0.46526140546486494,
#   'Find the minimum and maximum element in an array',
#   'array.json'],
#  [0.46510170719196353,
#   'Advanced Python RegEx Examples',
#   'regularexpression.json'],
#  [0.46430000026738566, 'Introduction to sets', 'set.json'],
#  [0.46430000026738566, 'Introduction to sets', 'set.json'],
#  [0.46424995716912865, 'Find missing number', 'array.json'],
#  [0.463827009645273,
#   'Python Try Except - GeeksforGeeks',
#   'exception handling.json'],
#  [0.4583307660822587, ' Python Lambda', 'function-lambda.json'],
#  [0.456869270471122,
#   'Creating One Dimensional Array using Numpy',
#   'array.json'],
#  [0.45267256528918925, 'What is Modular Programming?', 'module.json'],
#  [0.4522502375437201,
#   'Lambda Expressions - Python Tips and Tricks #5',
#   'function-lambda.json'],
#  [0.4519700665295842, 'Subarray with given sum', 'array.json'],
#  [0.4488953668801806,
#   'How To Use Functions In Python (Python Tutorial #3)',
#   'function.json'],
#  [0.4488400151692365,
#   'Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.4488400151692365,
#   'Python - Magic Methods ',
#   'oops-magic method-itertools.json'],
#  [0.4484688265546841,
#   'Python - Magic or Dunder Methods',
#   'oops-magic method-itertools.json'],
#  [0.4484688265546841,
#   'Dunder or magic methods in Python',
#   'oops-magic method-itertools.json'],
#  [0.44824431084392746, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.44824431084392746, ' Adding elements to a dictionary', 'dictionary.json'],
#  [0.447352813856965,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.447352813856965,
#   ' Python Exception Handling Using try, except and finally statement',
#   'exception handling.json'],
#  [0.44505035718441127, ' Copy dictionary method', 'dictionary.json'],
#  [0.44505035718441127, ' Copy dictionary method', 'dictionary.json'],
#  [0.44460985056226976,
#   '#20 Python Tutorial for Beginners | While Loop in Python',
#   'loop-while.json'],
#  [0.443873855459451,
#   "A Guide to Python's Magic Methods",
#   'oops-magic method-itertools.json'],
#  [0.443857596931654, 'Python programming', 'oops-class.json'],
#  [0.4421741737480219,
#   'Introducing Python Magic Methods',
#   'oops-magic method-itertools.json'],
#  [0.4413896363051156,
#   'How to Change/Replace/Update List Items ? | List tutorial in python',
#   'list.json'],
#  [0.43964209252621067, 'Find duplicates in an array', 'array.json'],
#  [0.4394960072073362, 'Merge two dictionaries', 'dictionary.json'],
#  [0.4394960072073362, 'Merge two dictionaries', 'dictionary.json'],
#  [0.43707387935314274,
#   ' Accessing elements of a nested dictionary',
#   'dictionary.json'],
#  [0.43707387935314274,
#   ' Accessing elements of a nested Dictionary',
#   'dictionary.json'],
#  [0.43663395549280226,
#   'Regular Expression in Python with Examples',
#   'regularexpression.json'],
#  [0.4357968770723684,
#   'Advance Python Series-Magic Methods In Classes',
#   'oops-magic method-itertools.json'],
#  [0.4348174182818169,
#   'Regular Expressions (Regex) in Python',
#   'regularexpression.json'],
#  [0.4348174182818169,
#   'Python Regular Expression (RegEX)',
#   'regularexpression.json'],
#  [0.43369244308061494, 'Python Objects and Classes', 'oops-class.json'],
#  [0.43369244308061494, 'Python Classes and Objects', 'oops-class.json'],
#  [0.43369244308061494, 'Python Classes & Objects', 'oops-class.json'],
#  [0.43369244308061494, 'Classes and Objects in python', 'oops-class.json'],
#  [0.43369244308061494, 'Classes and Objects in Python', 'oops-class.json'],
#  [0.43226621256931635,
#   'Reverse a Number in Python using While Loop',
#   'loop-while.json'],
#  [0.431571597051806, 'Python Lambda Expressions', 'function-lambda.json'],
#  [0.42685425279338884, 'Advanced Python classes', 'oops-class.json'],
#  [0.4267211421974252, 'Copy lists', 'list.json'],
#  [0.4267211421974252, 'Copy list', 'list.json'],
#  [0.4254410798053033,
#   'Regular Expressions (Regex) Tutorial: How to Match Any Pattern of Text',
#   'regularexpression.json'],
#  [0.4234242133779052, 'Sort an array using Quicksort Algorithm', 'array.json'],
#  [0.42270508765866605, 'Find missing and repeating', 'array.json'],
#  [0.42227505413641153, 'Python Regular Expressions', 'regularexpression.json'],
#  [0.42227505413641153,
#   'Python - Regular Expressions',
#   'regularexpression.json'],
#  [0.4218012659574389,
#   'Python Regular Expressions Concepts',
#   'regularexpression.json'],
#  [0.42106792106483576, 'Join lists', 'list.json'],
#  [0.42106792106483576, 'Join Lists', 'list.json'],
#  [0.4180362799557363, 'Elif statement', 'condition-pass.json'],
#  [0.4180362799557363, 'Elif statement', 'condition-pass.json'],
#  [0.41743039647850033,
#   'Itertools in Python3',
#   'oops-magic method-itertools.json'],
#  [0.41583028121385396, 'Python Programming | Classes', 'oops-class.json'],
#  [0.412781439032911, 'Python Generators', 'iterator-generator-decorator.json'],
#  [0.40950891485770197, 'Peak Element', 'array.json'],
#  [0.4094108855736743,
#   'Python Itertools javapoint',
#   'oops-magic method-itertools.json'],
#  [0.4066374825833559, 'Define CLasses in Python', 'oops-class.json'],
#  [0.405920035291742,
#   'Python Programs - Factorial Program Using for loop',
#   'loop-for.json'],
#  [0.40479582995891833, 'Nested Dictionaries', 'dictionary.json'],
#  [0.40479582995891833, ' Nested Dictionaries', 'dictionary.json'],
#  [0.4041408180479599,
#   'Magic Methods in Python, by example | Using Magic Methods In Our Class '
#   'Design',
#   'oops-magic method-itertools.json'],
#  [0.40076153261805864,
#   'Python Itertools gfg',
#   'oops-magic method-itertools.json'],
#  [0.3984148865612559, 'Python Regex', 'regularexpression.json'],
#  [0.3984148865612559, 'Python RegEx', 'regularexpression.json'],
#  [0.3984148865612559, 'Python RegEx', 'regularexpression.json'],
#  [0.3982211582806614, 'Python Decorators', 'iterator-generator-decorator.json'],
#  [0.3982211582806614, 'Python Decorator', 'iterator-generator-decorator.json'],
#  [0.3982211582806614,
#   'Decorators in Python',
#   'iterator-generator-decorator.json'],
#  [0.3892105413637907, 'Accessing elements of a dictionary', 'dictionary.json'],
#  [0.3892105413637907,
#   '. Accessing elements of a dictionary',
#   'dictionary.json'],
#  [0.38663222538842706, 'Pop dictionary method', 'dictionary.json'],
#  [0.38663222538842706, 'Pop dictionary method', 'dictionary.json'],
#  [0.3847259312067828, 'Checking for membership in lists', 'list.json'],
#  [0.3847259312067828, ' Checking for membership in lists', 'list.json'],
#  [0.3840146003524074, 'Clear dictionary method', 'dictionary.json'],
#  [0.3840146003524074, 'Clear dictionary method', 'dictionary.json'],
#  [0.3790923296730653, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.3790923296730653, 'Nested dictionaries with for loops', 'dictionary.json'],
#  [0.376798633180848, 'Python Classes', 'oops-class.json'],
#  [0.37539883819890735, 'Python While Loops', 'loop-while.json'],
#  [0.37215681944963036, 'Stock buy and sell Problem', 'array.json'],
#  [0.3657881747089678, 'Classes and Objects (OOPS)', 'oops-class.json'],
#  [0.364351781978353,
#   'Accessing List using for Loop in Python (Hindi)',
#   'loop-for.json'],
#  [0.36225297768828574, 'Data model', 'oops-magic method-itertools.json'],
#  [0.3604482992979914, 'Sort lists', 'list.json'],
#  [0.3604482992979914, ' Sort list', 'list.json'],
#  [0.3602894720290385, 'Remove set items', 'set.json'],
#  [0.3528106561135864, 'List comprehension', 'list.json'],
#  [0.3528106561135864, ' List comprehension', 'list.json'],
#  [0.347689912180993, 'Magic Methods', 'oops-magic method-itertools.json'],
#  [0.3467644780959959, 'Shorthand statement', 'condition-pass.json'],
#  [0.3467644780959959, 'Shorthand if statement', 'condition-pass.json'],
#  [0.33467748334871045, 'Creating a dictionary-', 'dictionary.json'],
#  [0.33467748334871045, 'Creating a dictionary', 'dictionary.json'],
#  [0.33384780979037426, ' Update dictionary method', 'dictionary.json'],
#  [0.33384780979037426, ' Update dictionary method', 'dictionary.json'],
#  [0.33225821991232585, 'Change list items', 'list.json'],
#  [0.3301876617102152, 'Get dictionary method', 'dictionary.json'],
#  [0.3301876617102152, 'Get dictionary method', 'dictionary.json'],
#  [0.3297244696873759, 'Reversing lists', 'list.json'],
#  [0.3297244696873759, ' Reversing the lists', 'list.json'],
#  [0.3236943031384635, 'Accessing sets', 'set.json'],
#  [0.3236943031384635, 'Accessing sets', 'set.json'],
#  [0.31958135679833277, ' Remove list items', 'list.json'],
#  [0.31376479885476244, ' Access list items', 'list.json'],
#  [0.30586438706678476, 'Pass statement', 'condition-pass.json'],
#  [0.30586438706678476, 'Pass statement', 'condition-pass.json'],
#  [0.30586438706678476, 'Pass statement', 'condition-pass.json'],
#  [0.30586438706678476, 'Pass statement', 'condition-pass.json'],
#  [0.30464306816743103, 'Filtering the lists', 'list.json'],
#  [0.30464306816743103, ' Filtering the lists', 'list.json'],
#  [0.2845190059635386, 'What Are Access Lists? ', 'list.json'],
#  [0.2799693266690806, 'Loop sets', 'set.json'],
#  [0.2799693266690806, 'Loop sets', 'set.json'],
#  [0.26780183589928414, 'Indentation', 'condition-pass.json'],
#  [0.26780183589928414, 'Indentation', 'condition-pass.json'],
#  [0.2665737425723336, 'List methods', 'list.json'],
#  [0.2665737425723336, 'List methods', 'list.json'],
#  [0.24781599368185167, 'Loop lists', 'list.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [nan, '', 'template.json'],
#  [0.8853679086497555, 'Introduction to tuples', 'tuple.json'],
#  [0.8853679086497555, 'Introduction to tuples', 'tuple.json'],
#  [0.8338570061235386, 'Iterating through a tuple', 'tuple.json'],
#  [0.8338570061235386, 'Iterating through a tuple', 'tuple.json'],
#  [0.7962849620523935, 'tuple Creating a tuple', 'tuple.json'],
#  [0.7962849620523935, 'Creating a tuple', 'tuple.json'],
#  [0.7862022916230792, 'Built-in functions for tuple', 'tuple.json'],
#  [0.7862022916230792, 'Built-in functions for tuple', 'tuple.json'],
#  [0.7796634323410947, 'Tuple membership test', 'tuple.json'],
#  [0.7796634323410947, 'Tuple membership test', 'tuple.json'],
#  [0.7711400324662215, 'Changing a tuple', 'tuple.json'],
#  [0.7711400324662215, 'Changing a tuple', 'tuple.json'],
#  [0.7583032671725781, 'Tuple methods', 'tuple.json'],
#  [0.7583032671725781, 'Tuple methods', 'tuple.json'],
#  [0.7102160510817486, 'tuple Access tuple elements', 'tuple.json'],
#  [0.7102160510817486, 'Access tuple elements', 'tuple.json'],
#  [0.6512349933019119, 'Updating tuple and deleting a tuple', 'tuple.json'],
#  [0.6512349933019119, 'Updating and Deleting a tuple', 'tuple.json'],
#  [0.5996311764570661, 'Set size and membership', 'set.json'],
#  [0.5996311764570661, 'Set size and membership', 'set.json'],
#  [0.5860964822961457, 'Accessing characters in python string', 'string.json'],
#  [0.5762949655160456, ' Multiline strings', 'string.json'],
#  [0.5762949655160456, ' Multiline strings', 'string.json'],
#  [0.5611833359663909, 'Accessing characters in string', 'string.json'],
#  [0.5479258472594492,
#   'Beginner Python Tutorial 17 - Creating a String',
#   'string.json'],
#  [0.5453780889622949, ' Add set items', 'set.json'],
#  [0.522866076556539, 'Inplace boolean logic', 'string.json'],
#  [0.522866076556539, 'Inplace boolean logic', 'string.json'],
#  [0.4756802345918321, 'Escape sequencing in python', 'string.json'],
#  [0.4756802345918321, 'Escape sequencing in python', 'string.json'],
#  [0.4693243494524051, 'String Introduction', 'string.json'],
#  [0.4693243494524051, 'Introduction to strings', 'string.json'],
#  [0.46351518789442386, 'Slicing and indexing', 'tuple.json'],
#  [0.46351518789442386, 'Slicing and indexing', 'tuple.json'],
#  [0.4485662224588263, 'Printing variables names and values', 'string.json'],
#  [0.4485662224588263, 'Printing variable names and values', 'string.json'],
#  [0.4467548622759818, ' Set operations', 'set.json'],
#  [0.4467548622759818, ' Set operation', 'set.json'],
#  [0.44633332568095485, 'Reversing a string in python', 'string.json'],
#  [0.44633332568095485, ' Reversing a string in python', 'string.json'],
#  [0.4433675319754912, 'Variables in string', 'string.json'],
#  [0.4433675319754912, 'Variables in string', 'string.json'],
#  [0.4361977632503097, 'Creating string in python', 'string.json'],
#  [0.4208442362791126, 'String slicing in python', 'string.json'],
#  [0.4208442362791126, ' String slicing in python', 'string.json'],
#  [0.4100913329094017, 'String length', 'string.json'],
#  [0.4100913329094017, 'String length', 'string.json'],
#  [0.37221797870492174, 'Frozen set', 'set.json'],
#  [0.37221797870492174, 'Frozen set', 'set.json'],
#  [0.3602894720290385, 'Remove set items', 'set.json'],
#  [0.3385765043392999, 'Using classes in Python', 'oops-class.json'],
#  [0.291902361961627, 'Formatting of strings', 'string.json'],
#  [0.291902361961627, 'Formatting of strings', 'string.json'],
#  [0.24781599368185167, ' Loop lists', 'list.json']]

# %%
import pickle
with open('model.dat','wb') as file:
    pickle.dump(model1,file)
